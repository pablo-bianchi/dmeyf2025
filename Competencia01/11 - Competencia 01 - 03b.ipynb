# %% [markdown]
# # Tarea para el Hogar 04

# %% [markdown]
# ##  1. Big Picture

# %% [markdown]
# LightGBM es el algoritmo estado del arte para datasets estructurados.
# <br> La Bayesian Optimization es el estado del arte para optimización de hiperparámetros
# <br> Las soluciones a las tres competencias de la asignatura contendrán LightGBMs y Bayesian Optimizations
# <br> LightGBM ha aumentado en forma no darwiniana sus hiperparámetros en los últimos ocho años; no todos los existentes son útiles.
# <br> Es necesario lograr entender cuales son los hiperparámetros relevantes de LightGBM

# %% [markdown]
# ## 2. Hiperparámetros del LightGBM

# %% [markdown]
# Los objetivos de esta tarea son:
#
#
# *   Aumentar la rentabilidad de la campaña de marketing de retención proactiva de clientes.
# *   Generar un mejor modelo optimizando sus hiperparámetros
# *   Conceptual : investigar los mas relevantes hiperparámetros de LightGBM
# *   Familiarizarse con la Bayesian Optimization, sus largos tiempos de corrida y opciones para reducirlos
# *   Familiarizarse con el uso de máquinas virtuales de Google Colab
# *   Ver un pipeline completo de optimización de hiperparámetros y puesta en producción

# %% [markdown]
# LightGBM cuenta con mas de 60 hiperparámetros, siendo posible utilizar 40 al mismo tiempo, aunque no razonable.
# <br> La documentación oficial de los hiperparámetros de LightGBM es  https://lightgbm.readthedocs.io/en/latest/Parameters.html#core-parameters

# %% [markdown]
# Se lo alerta sobre que una Optimizacion Bayesiana lleva varias horas de corrida, y usted deberá correr VARIAS optimizaciones para descubrir cuales parámetros conviene optimizar.
# <br> A pesar que la próxima clase es recien en viernes 01 de agosto, inicie la tarea con tiempo, aprenda a planificar estratégicamente sus corridas como un@ científ@  de datos.

# %% [markdown]
# Es necesario investigar cuales son los hiperparámetros de LightGBM que vale la pena optimizar en una Bayesian Optimization, ya que los realmente utiles son apenas un reducido subconjunto.
# <br>Usted deberá investigar cuales son los hiperparámetros mas relevantes de LightGBM, su primer alternativa es preguntándole a su amigo con capacidades especiales ChatGPT o sus endogámicos familiares Claude, DeepSeek, Gemini, Grok, etc
# <br> La segunda alternativa es la propia documentación de LightGBM  https://lightgbm.readthedocs.io/en/latest/Parameters-Tuning.html

# %% [markdown]
# Adicionalmente podra buscar información como la que proveen esta diminuta muestra aleatoria de artículos ligeros:
# *  https://medium.com/@sarahzouinina/a-deep-dive-into-lightgbm-how-to-choose-and-tune-parameters-7c584945842e
# *  https://www.kaggle.com/code/somang1418/tuning-hyperparameters-under-10-minutes-lgbm
# *  https://towardsdatascience.com/beginners-guide-to-the-must-know-lightgbm-hyperparameters-a0005a812702/
#
#
# <br>  La muestra anterior se brinda a modo de ejemplo, usted deberá buscar muuuuchas  fuentes adicionales de información
# <br> Tenga presente que LightGBM es el estado del arte en modelado predictivo para datasets estructurado, que son el 90% del trabajo del 95% de los Data Scientists en Argentina.

# %% [markdown]
# El desafío de esta tarea es:
# * Qué hiperparparámetros conviene optimizar?  Las recomendaciones de los artículos ligeros es siempre sensata?  Sus autores realmente hicieron experimentos o son siemplemente escritores de entretenimiento carente de base científica?
# * Elegidos los hiperparámetros, cual es el  <desde, hasta> que se debe utilizar en la Bayesian Optimization ?
# * Realmente vale la pena optimizar 10 o 16 hiperparámetros al mismo tiempo ?  No resulta contraproducente una búsqueda en un espacio de tal alta dimensionalidad ?

# %% [markdown]
# #### 2.1  Seteo del ambiente en Google Colab

# %% [markdown]
# Esta parte se debe correr con el runtime en Python3
# <br>Ir al menu, Runtime -> Change Runtime Type -> Runtime type ->  **Python 3**

# %% [markdown]
# Conectar la virtual machine donde esta corriendo Google Colab con el  Google Drive, para poder tener persistencia de archivos

# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %% [markdown]
# Para correr la siguiente celda es fundamental en Arranque en Frio haber copiado el archivo kaggle.json al Google Drive, en la carpeta indicada en el instructivo
#
# <br>los siguientes comando estan en shell script de Linux
# *   Crear las carpetas en el Google Drive
# *   "instalar" el archivo kaggle.json desde el Google Drive a la virtual machine para que pueda ser utilizado por la libreria  kaggle de Python
# *   Bajar el  **dataset_pequeno**  al  Google Drive  y tambien al disco local de la virtual machine que esta corriendo Google Colab

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dmeyf" /content/buckets/b1


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/dmeyf2025-e4a2/competencia_01_crudo.csv"
archivo_destino="/content/datasets/competencia_01_crudo.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/competencia_01_crudo.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ## Generacion de la clase_ternaria

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %%
require( "data.table" )

# leo el dataset
dataset <- fread("/content/datasets/competencia_01_crudo.csv" )

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
    "pos" = .I,
    numero_de_cliente,
    periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 ) ]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
    shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente ]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
    ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
    clase_ternaria := "BAJA+1" ]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
    & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
    clase_ternaria := "BAJA+2" ]


# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)
# Out:
# Loading required package: data.table

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  202101   BAJA+1            622
# 2  202101   BAJA+2            825
# 3  202101   CONTINUA       160080
# 4  202102   BAJA+1            831
# 5  202102   BAJA+2           1032
# 6  202102   CONTINUA       160292
# 7  202103   BAJA+1           1039
# 8  202103   BAJA+2            951
# 9  202103   CONTINUA       161119
# 10 202104   BAJA+1            955
# 11 202104   BAJA+2           1130
# 12 202104   CONTINUA       161333
# 13 202105   NA             162783
# 14 202105   BAJA+1           1134
# 15 202106   NA             164313

# %% [markdown]
# ## Tratamiento al dataset

# %% [markdown]
# ### Creación de features

# %% [markdown]
# Creación de lags y delta lags

# %%
max_lag <- 1

# selecciono automáticamente todas las columnas numéricas, excepto id y fecha
campos_laguear <- setdiff(
  names(dataset)[sapply(dataset, is.numeric)],
  c("numero_de_cliente", "foto_mes")
)

cat("Máximo lag posible:", max_lag, "\n")
cat("Campos a laggear:", paste(campos_laguear, collapse=", "), "\n")

# genero los lags (ya lo tenías)
dataset[, paste0(rep(campos_laguear, each = max_lag), "_lag", 1:max_lag) :=
          shift(.SD, n = 1:max_lag, type = "lag"),
        by = numero_de_cliente,
        .SDcols = campos_laguear]

# genero los delta lags como var - lagX
for (campo in campos_laguear) {
  for (k in 1:max_lag) {
    dataset[, (paste0(campo, "_delta", k)) :=
              get(campo) - get(paste0(campo, "_lag", k))]
  }
}
# Out:
# Máximo lag posible: 1
# Campos a laggear: active_quarter, cliente_vip, internet, cliente_edad, cliente_antiguedad, mrentabilidad, mrentabilidad_annual, mcomisiones, mactivos_margen, mpasivos_margen, cproductos, tcuentas, ccuenta_corriente, mcuenta_corriente_adicional, mcuenta_corriente, ccaja_ahorro, mcaja_ahorro, mcaja_ahorro_adicional, mcaja_ahorro_dolares, cdescubierto_preacordado, mcuentas_saldo, ctarjeta_debito, ctarjeta_debito_transacciones, mautoservicio, ctarjeta_visa, ctarjeta_visa_transacciones, mtarjeta_visa_consumo, ctarjeta_master, ctarjeta_master_transacciones, mtarjeta_master_consumo, cprestamos_personales, mprestamos_personales, cprestamos_prendarios, mprestamos_prendarios, cprestamos_hipotecarios, mprestamos_hipotecarios, cplazo_fijo, mplazo_fijo_dolares, mplazo_fijo_pesos, cinversion1, minversion1_pesos, minversion1_dolares, cinversion2, minversion2, cseguro_vida, cseguro_auto, cseguro_vivienda, cseguro_accidentes_personales, ccaja_seguridad, cpayroll_trx, mpayroll, mpayroll2, cpayroll2_trx, ccuenta_debitos_automaticos, mcuenta_debitos_automaticos, ctarjeta_visa_debitos_automaticos, mttarjeta_visa_debitos_automaticos, ctarjeta_master_debitos_automaticos, mttarjeta_master_debitos_automaticos, cpagodeservicios, mpagodeservicios, cpagomiscuentas, mpagomiscuentas, ccajeros_propios_descuentos, mcajeros_propios_descuentos, ctarjeta_visa_descuentos, mtarjeta_visa_descuentos, ctarjeta_master_descuentos, mtarjeta_master_descuentos, ccomisiones_mantenimiento, mcomisiones_mantenimiento, ccomisiones_otras, mcomisiones_otras, cforex, cforex_buy, mforex_buy, cforex_sell, mforex_sell, ctransferencias_recibidas, mtransferencias_recibidas, ctransferencias_emitidas, mtransferencias_emitidas, cextraccion_autoservicio, mextraccion_autoservicio, ccheques_depositados, mcheques_depositados, ccheques_emitidos, mcheques_emitidos, ccheques_depositados_rechazados, mcheques_depositados_rechazados, ccheques_emitidos_rechazados, mcheques_emitidos_rechazados, tcallcenter, ccallcenter_transacciones, thomebanking, chomebanking_transacciones, ccajas_transacciones, ccajas_consultas, ccajas_depositos, ccajas_extracciones, ccajas_otras, catm_trx, matm, catm_trx_other, matm_other, ctrx_quarter, tmobile_app, cmobile_app_trx, Master_delinquency, Master_status, Master_mfinanciacion_limite, Master_Fvencimiento, Master_Finiciomora, Master_msaldototal, Master_msaldopesos, Master_msaldodolares, Master_mconsumospesos, Master_mconsumosdolares, Master_mlimitecompra, Master_madelantopesos, Master_madelantodolares, Master_fultimo_cierre, Master_mpagado, Master_mpagospesos, Master_mpagosdolares, Master_fechaalta, Master_mconsumototal, Master_cconsumos, Master_cadelantosefectivo, Master_mpagominimo, Visa_delinquency, Visa_status, Visa_mfinanciacion_limite, Visa_Fvencimiento, Visa_Finiciomora, Visa_msaldototal, Visa_msaldopesos, Visa_msaldodolares, Visa_mconsumospesos, Visa_mconsumosdolares, Visa_mlimitecompra, Visa_madelantopesos, Visa_madelantodolares, Visa_fultimo_cierre, Visa_mpagado, Visa_mpagospesos, Visa_mpagosdolares, Visa_fechaalta, Visa_mconsumototal, Visa_cconsumos, Visa_cadelantosefectivo, Visa_mpagominimo

# %% [markdown]
# Lo guardo

# %%
fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Oct 08 05:29:34 AM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  735454 39.3   1454474    77.7   1454474   77.7
# Vcells 1402934 10.8 351853335  2684.5 394915815 3013.0

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %% [markdown]
# Esta parte lleva varios minutos la primera vez en Google Colab

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: parallel
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings
#
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %%
PARAM <- list()
PARAM$experimento <- 'C01-03b'
PARAM$semilla_primigenia <- 170029

# %%
# training y future
PARAM$train <- c(202101, 202102, 202103, 202104)
PARAM$train_final <- c(202101, 202102, 202103, 202104)
PARAM$future <- c(202106)
PARAM$test <- c(202104)
PARAM$semilla_kaggle <- 314159
PARAM$cortes <- seq(6000, 19000, by= 500)

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.05

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "dart", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  makeIntegerParam("num_iterations", lower= 8L, upper= 2048L),
  makeNumericParam("learning_rate", lower= 0.01, upper= 0.3),
  makeNumericParam("feature_fraction", lower= 0.1, upper= 1.0),
  makeIntegerParam("num_leaves", lower= 8L, upper= 2048L),
  makeIntegerParam("min_data_in_leaf", lower= 100L, upper= 8000L),
  makeNumericParam("min_sum_hessian_in_leaf", lower= 0.1, upper= 10),
  makeIntegerParam("max_bin", lower= 32, upper= 255),
  makeIntegerParam("min_data_in_bin", lower= 1L, upper= 100L),
  makeIntegerParam("max_cat_threshold", lower= 1L, upper= 100L),
  makeIntegerParam("bagging_freq", lower= 0L, upper= 10L),
  makeNumericParam("bagging_fraction", lower= 0.1, upper= 1),
  makeNumericParam("path_smooth", lower= 0, upper= 10),
  makeNumericParam("lambda_l1", lower= 0, upper= 10),
  makeNumericParam("lambda_l2", lower= 0, upper= 20),
  makeNumericParam("min_gain_to_split", lower= 0, upper= 0.5)
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 50 # iteraciones bayesianas

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed, "L'Ecuyer-CMRG")

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# iniciliazo el dataset de realidad, para medir ganancia
realidad_inicializar <- function( pfuture, pparam) {

  # datos para verificar la ganancia
  drealidad <- pfuture[, list(numero_de_cliente, foto_mes, clase_ternaria)]

  particionar(drealidad,
    division= c(3, 7),
    agrupa= "clase_ternaria",
    seed= PARAM$semilla_kaggle
  )

  return( drealidad )
}

# %%
# evaluo ganancia en los datos de la realidad

realidad_evaluar <- function( prealidad, pprediccion) {

  prealidad[ pprediccion,
    on= c("numero_de_cliente", "foto_mes"),
    predicted:= i.Predicted
  ]

  tbl <- prealidad[, list("qty"=.N), list(fold, predicted, clase_ternaria)]

  res <- list()
  res$public  <- tbl[fold==1 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.3
  res$private <- tbl[fold==2 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.7
  res$total <- tbl[predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]

  prealidad[, predicted:=NULL]
  return( res )
}

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/competencia_01.csv.gz", stringsAsFactors= TRUE)

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in%  PARAM$train &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 39403
# [1] 458

# %% [markdown]
# 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Wed Oct 08 05:38:21 AM 2025 AUC 0.916251606149606
#
# Wed Oct 08 05:39:21 AM 2025 AUC 0.929559609537632
#
# Wed Oct 08 05:40:22 AM 2025 AUC 0.911738906193884
#
# Wed Oct 08 05:43:03 AM 2025 AUC 0.932671507752893
#
# Wed Oct 08 05:43:41 AM 2025 AUC 0.906065213835546
#
# Wed Oct 08 05:45:16 AM 2025 AUC 0.921004435862209
#
# Wed Oct 08 05:46:20 AM 2025 AUC 0.922115246914844
#
# Wed Oct 08 05:47:06 AM 2025 AUC 0.927313457821039
#
# Wed Oct 08 05:48:00 AM 2025 AUC 0.930164473019112
#
# Wed Oct 08 05:48:31 AM 2025 AUC 0.892786371947851
#
# Wed Oct 08 05:49:14 AM 2025 AUC 0.918210386867986
#
# Wed Oct 08 05:49:24 AM 2025 AUC 0.929043830023733
#
# Wed Oct 08 05:49:58 AM 2025 AUC 0.895835275663433
#
# Wed Oct 08 05:50:05 AM 2025 AUC 0.911751221366931
#
# Wed Oct 08 05:53:30 AM 2025 AUC 0.929150252166217
#
# Wed Oct 08 05:55:11 AM 2025 AUC 0.93237704597376
#
# Wed Oct 08 05:55:28 AM 2025 AUC 0.919300238230271
#
# Wed Oct 08 05:55:36 AM 2025 AUC 0.5
#
# Wed Oct 08 05:56:17 AM 2025 AUC 0.896458579471034
#
# Wed Oct 08 05:58:33 AM 2025 AUC 0.92899656557182
#
# Wed Oct 08 06:00:01 AM 2025 AUC 0.909897587920185
#
# Wed Oct 08 06:00:44 AM 2025 AUC 0.908483149100323
#
# Wed Oct 08 06:01:36 AM 2025 AUC 0.896580506645167
#
# Wed Oct 08 06:01:40 AM 2025 AUC 0.868367014426585
#
# Wed Oct 08 06:02:51 AM 2025 AUC 0.5
#
# Wed Oct 08 06:04:32 AM 2025 AUC 0.890355472790124
#
# Wed Oct 08 06:06:28 AM 2025 AUC 0.918321570851051
#
# Wed Oct 08 06:07:49 AM 2025 AUC 0.921222302786721
#
# Wed Oct 08 06:08:29 AM 2025 AUC 0.898692516274824
#
# Wed Oct 08 06:09:33 AM 2025 AUC 0.901617185311876
#
# Wed Oct 08 06:10:17 AM 2025 AUC 0.930871238927098
#
# Wed Oct 08 06:10:20 AM 2025 AUC 0.901252144746244
#
# Wed Oct 08 06:10:25 AM 2025 AUC 0.914859861958672
#
# Wed Oct 08 06:13:31 AM 2025 AUC 0.92685836345923
#
# Wed Oct 08 06:13:57 AM 2025 AUC 0.5
#
# Wed Oct 08 06:14:38 AM 2025 AUC 0.906953869508035
#
# Wed Oct 08 06:15:00 AM 2025 AUC 0.910422251431136
#
# Wed Oct 08 06:18:47 AM 2025 AUC 0.933129574794014
#
# Wed Oct 08 06:19:17 AM 2025 AUC 0.905450025295468
#
# Wed Oct 08 06:19:31 AM 2025 AUC 0.915274875891198
#
# Wed Oct 08 06:20:26 AM 2025 AUC 0.931040399185542
#
# Wed Oct 08 06:25:48 AM 2025 AUC 0.935386508441545
#
# Wed Oct 08 06:28:26 AM 2025 AUC 0.922315991436685
#
# Wed Oct 08 06:30:36 AM 2025 AUC 0.923055128997869
#
# Wed Oct 08 06:30:38 AM 2025 AUC 0.869770655649427
#
# Wed Oct 08 06:32:20 AM 2025 AUC 0.912776550156062
#
# Wed Oct 08 06:32:36 AM 2025 AUC 0.91507543798693
#
# Wed Oct 08 06:34:58 AM 2025 AUC 0.93107914523638
#
# Wed Oct 08 06:35:02 AM 2025 AUC 0.5
#
# Wed Oct 08 06:36:58 AM 2025 AUC 0.915811223799037
#
# Wed Oct 08 06:37:38 AM 2025 AUC 0.5
#
# Wed Oct 08 06:37:40 AM 2025 AUC 0.5
#
# Wed Oct 08 06:37:59 AM 2025 AUC 0.891639988048135
#
# Wed Oct 08 06:38:57 AM 2025 AUC 0.91389378436599
#
# Wed Oct 08 06:41:24 AM 2025 AUC 0.928708286758891
#
# Wed Oct 08 06:43:31 AM 2025 AUC 0.922659889795094
#
# Wed Oct 08 06:45:19 AM 2025 AUC 0.937400431490363
#
# Wed Oct 08 06:45:28 AM 2025 AUC 0.928546243027801
#
# Wed Oct 08 06:46:27 AM 2025 AUC 0.5
#
# Wed Oct 08 06:48:10 AM 2025 AUC 0.918660313078276
#
# [mbo] 0: num_iterations=809; learning_rate=0.0985; feature_fraction=0.518; num_leaves=865; min_data_in_leaf=5600; min_sum_hessian_in_leaf=3.84; max_bin=89; min_data_in_bin=67; max_cat_threshold=61; bagging_freq=7; bagging_fraction=0.82; path_smooth=6.66; lambda_l1=5.44; lambda_l2=8.63; min_gain_to_split=0.341 : y = 0.916 : 60.6 secs : initdesign
#
# [mbo] 0: num_iterations=606; learning_rate=0.209; feature_fraction=0.503; num_leaves=1134; min_data_in_leaf=2967; min_sum_hessian_in_leaf=3.93; max_bin=148; min_data_in_bin=43; max_cat_threshold=48; bagging_freq=0; bagging_fraction=0.613; path_smooth=4.58; lambda_l1=0.81; lambda_l2=8.31; min_gain_to_split=0.148 : y = 0.93 : 59.8 secs : initdesign
#
# [mbo] 0: num_iterations=1598; learning_rate=0.163; feature_fraction=0.652; num_leaves=816; min_data_in_leaf=5433; min_sum_hessian_in_leaf=4.9; max_bin=168; min_data_in_bin=26; max_cat_threshold=47; bagging_freq=4; bagging_fraction=0.518; path_smooth=3.19; lambda_l1=6.03; lambda_l2=10.8; min_gain_to_split=0.0468 : y = 0.912 : 60.9 secs : initdesign
#
# [mbo] 0: num_iterations=1350; learning_rate=0.125; feature_fraction=0.397; num_leaves=1303; min_data_in_leaf=1688; min_sum_hessian_in_leaf=5.59; max_bin=116; min_data_in_bin=71; max_cat_threshold=63; bagging_freq=5; bagging_fraction=0.879; path_smooth=2.61; lambda_l1=4.7; lambda_l2=5.79; min_gain_to_split=0.125 : y = 0.933 : 161.1 secs : initdesign
#
# [mbo] 0: num_iterations=674; learning_rate=0.114; feature_fraction=0.32; num_leaves=1720; min_data_in_leaf=4486; min_sum_hessian_in_leaf=6.73; max_bin=176; min_data_in_bin=70; max_cat_threshold=40; bagging_freq=7; bagging_fraction=0.441; path_smooth=4.26; lambda_l1=7.93; lambda_l2=3.05; min_gain_to_split=0.263 : y = 0.906 : 37.9 secs : initdesign
#
# [mbo] 0: num_iterations=1430; learning_rate=0.149; feature_fraction=0.594; num_leaves=134; min_data_in_leaf=3809; min_sum_hessian_in_leaf=5.87; max_bin=87; min_data_in_bin=53; max_cat_threshold=73; bagging_freq=6; bagging_fraction=0.572; path_smooth=2.78; lambda_l1=4.34; lambda_l2=7.52; min_gain_to_split=0.25 : y = 0.921 : 95.7 secs : initdesign
#
# [mbo] 0: num_iterations=1151; learning_rate=0.184; feature_fraction=0.632; num_leaves=1453; min_data_in_leaf=4125; min_sum_hessian_in_leaf=6.01; max_bin=138; min_data_in_bin=38; max_cat_threshold=89; bagging_freq=9; bagging_fraction=0.647; path_smooth=8.95; lambda_l1=0.882; lambda_l2=4.7; min_gain_to_split=0.23 : y = 0.922 : 64.0 secs : initdesign
#
# [mbo] 0: num_iterations=561; learning_rate=0.0773; feature_fraction=0.788; num_leaves=1907; min_data_in_leaf=1874; min_sum_hessian_in_leaf=5.41; max_bin=101; min_data_in_bin=31; max_cat_threshold=27; bagging_freq=8; bagging_fraction=0.816; path_smooth=2.49; lambda_l1=3.18; lambda_l2=10.4; min_gain_to_split=0.0537 : y = 0.927 : 45.8 secs : initdesign
#
# [mbo] 0: num_iterations=471; learning_rate=0.24; feature_fraction=0.191; num_leaves=1380; min_data_in_leaf=255; min_sum_hessian_in_leaf=2.04; max_bin=163; min_data_in_bin=11; max_cat_threshold=66; bagging_freq=2; bagging_fraction=0.42; path_smooth=8.67; lambda_l1=3.85; lambda_l2=4.36; min_gain_to_split=0.401 : y = 0.93 : 53.6 secs : initdesign
#
# [mbo] 0: num_iterations=1095; learning_rate=0.133; feature_fraction=0.799; num_leaves=1245; min_data_in_leaf=3539; min_sum_hessian_in_leaf=3.39; max_bin=194; min_data_in_bin=23; max_cat_threshold=30; bagging_freq=6; bagging_fraction=0.252; path_smooth=9.56; lambda_l1=5.99; lambda_l2=15.2; min_gain_to_split=0.368 : y = 0.893 : 31.0 secs : initdesign
#
# [mbo] 0: num_iterations=765; learning_rate=0.109; feature_fraction=0.87; num_leaves=1007; min_data_in_leaf=4338; min_sum_hessian_in_leaf=0.723; max_bin=126; min_data_in_bin=6; max_cat_threshold=22; bagging_freq=1; bagging_fraction=0.689; path_smooth=3.67; lambda_l1=6.21; lambda_l2=7.78; min_gain_to_split=0.274 : y = 0.918 : 43.0 secs : initdesign
#
# [mbo] 0: num_iterations=159; learning_rate=0.204; feature_fraction=0.772; num_leaves=1228; min_data_in_leaf=981; min_sum_hessian_in_leaf=7.33; max_bin=80; min_data_in_bin=4; max_cat_threshold=95; bagging_freq=7; bagging_fraction=0.668; path_smooth=2; lambda_l1=5.82; lambda_l2=11.7; min_gain_to_split=0.278 : y = 0.929 : 10.3 secs : initdesign
#
# [mbo] 0: num_iterations=1022; learning_rate=0.256; feature_fraction=0.808; num_leaves=1471; min_data_in_leaf=6425; min_sum_hessian_in_leaf=1.86; max_bin=238; min_data_in_bin=92; max_cat_threshold=34; bagging_freq=1; bagging_fraction=0.458; path_smooth=1.11; lambda_l1=3.75; lambda_l2=11.7; min_gain_to_split=0.448 : y = 0.896 : 33.7 secs : initdesign
#
# [mbo] 0: num_iterations=194; learning_rate=0.247; feature_fraction=0.655; num_leaves=643; min_data_in_leaf=7473; min_sum_hessian_in_leaf=9.06; max_bin=159; min_data_in_bin=55; max_cat_threshold=59; bagging_freq=8; bagging_fraction=0.839; path_smooth=5.89; lambda_l1=6.81; lambda_l2=8.88; min_gain_to_split=0.187 : y = 0.912 : 7.5 secs : initdesign
#
# [mbo] 0: num_iterations=2033; learning_rate=0.0605; feature_fraction=0.35; num_leaves=1049; min_data_in_leaf=1373; min_sum_hessian_in_leaf=8.37; max_bin=243; min_data_in_bin=56; max_cat_threshold=50; bagging_freq=2; bagging_fraction=0.478; path_smooth=4.39; lambda_l1=5.28; lambda_l2=10.3; min_gain_to_split=0.0385 : y = 0.929 : 204.7 secs : initdesign
#
# [mbo] 0: num_iterations=980; learning_rate=0.194; feature_fraction=0.15; num_leaves=284; min_data_in_leaf=1250; min_sum_hessian_in_leaf=3; max_bin=32; min_data_in_bin=75; max_cat_threshold=68; bagging_freq=7; bagging_fraction=0.888; path_smooth=5.77; lambda_l1=8.36; lambda_l2=0.579; min_gain_to_split=0.0897 : y = 0.932 : 100.8 secs : initdesign
#
# [mbo] 0: num_iterations=281; learning_rate=0.179; feature_fraction=0.26; num_leaves=434; min_data_in_leaf=3930; min_sum_hessian_in_leaf=7.39; max_bin=236; min_data_in_bin=51; max_cat_threshold=6; bagging_freq=6; bagging_fraction=0.775; path_smooth=3.86; lambda_l1=2.02; lambda_l2=17.3; min_gain_to_split=0.24 : y = 0.919 : 17.4 secs : initdesign
#
# [mbo] 0: num_iterations=951; learning_rate=0.12; feature_fraction=0.614; num_leaves=734; min_data_in_leaf=4910; min_sum_hessian_in_leaf=9.61; max_bin=47; min_data_in_bin=36; max_cat_threshold=45; bagging_freq=4; bagging_fraction=0.127; path_smooth=4.76; lambda_l1=7.26; lambda_l2=2.06; min_gain_to_split=0.316 : y = 0.5 : 7.9 secs : initdesign
#
# [mbo] 0: num_iterations=1199; learning_rate=0.224; feature_fraction=0.89; num_leaves=1788; min_data_in_leaf=5640; min_sum_hessian_in_leaf=3.5; max_bin=108; min_data_in_bin=49; max_cat_threshold=97; bagging_freq=1; bagging_fraction=0.408; path_smooth=3.56; lambda_l1=4.04; lambda_l2=12.3; min_gain_to_split=0.18 : y = 0.896 : 41.1 secs : initdesign
#
# [mbo] 0: num_iterations=1494; learning_rate=0.272; feature_fraction=0.222; num_leaves=990; min_data_in_leaf=2150; min_sum_hessian_in_leaf=8.91; max_bin=187; min_data_in_bin=17; max_cat_threshold=57; bagging_freq=3; bagging_fraction=0.717; path_smooth=3.37; lambda_l1=9.66; lambda_l2=13.4; min_gain_to_split=0.296 : y = 0.929 : 136.4 secs : initdesign
#
# [mbo] 0: num_iterations=1459; learning_rate=0.0139; feature_fraction=0.751; num_leaves=910; min_data_in_leaf=5303; min_sum_hessian_in_leaf=4.17; max_bin=153; min_data_in_bin=63; max_cat_threshold=13; bagging_freq=7; bagging_fraction=0.943; path_smooth=6.29; lambda_l1=7.54; lambda_l2=16.9; min_gain_to_split=0.416 : y = 0.91 : 87.3 secs : initdesign
#
# [mbo] 0: num_iterations=723; learning_rate=0.155; feature_fraction=0.333; num_leaves=1874; min_data_in_leaf=6817; min_sum_hessian_in_leaf=8.54; max_bin=80; min_data_in_bin=30; max_cat_threshold=3; bagging_freq=5; bagging_fraction=0.677; path_smooth=7.77; lambda_l1=9.04; lambda_l2=2.95; min_gain_to_split=0.0777 : y = 0.908 : 43.0 secs : initdesign
#
# [mbo] 0: num_iterations=1689; learning_rate=0.0313; feature_fraction=0.735; num_leaves=1192; min_data_in_leaf=4230; min_sum_hessian_in_leaf=6.09; max_bin=129; min_data_in_bin=95; max_cat_threshold=16; bagging_freq=6; bagging_fraction=0.34; path_smooth=4.01; lambda_l1=9.42; lambda_l2=15.8; min_gain_to_split=0.00196 : y = 0.897 : 52.8 secs : initdesign
#
# [mbo] 0: num_iterations=527; learning_rate=0.157; feature_fraction=0.677; num_leaves=211; min_data_in_leaf=2831; min_sum_hessian_in_leaf=2.28; max_bin=41; min_data_in_bin=15; max_cat_threshold=58; bagging_freq=10; bagging_fraction=0.175; path_smooth=1.69; lambda_l1=6.61; lambda_l2=17.7; min_gain_to_split=0.224 : y = 0.868 : 3.6 secs : initdesign
#
# [mbo] 0: num_iterations=2002; learning_rate=0.0387; feature_fraction=0.383; num_leaves=937; min_data_in_leaf=7613; min_sum_hessian_in_leaf=5.22; max_bin=94; min_data_in_bin=9; max_cat_threshold=76; bagging_freq=6; bagging_fraction=0.304; path_smooth=0.462; lambda_l1=2.5; lambda_l2=12.7; min_gain_to_split=0.159 : y = 0.5 : 70.5 secs : initdesign
#
# [mbo] 0: num_iterations=1785; learning_rate=0.221; feature_fraction=0.298; num_leaves=1359; min_data_in_leaf=5131; min_sum_hessian_in_leaf=0.859; max_bin=136; min_data_in_bin=62; max_cat_threshold=86; bagging_freq=4; bagging_fraction=0.341; path_smooth=8.56; lambda_l1=8.15; lambda_l2=18.5; min_gain_to_split=0.47 : y = 0.89 : 101.9 secs : initdesign
#
# [mbo] 0: num_iterations=1614; learning_rate=0.23; feature_fraction=0.408; num_leaves=333; min_data_in_leaf=1982; min_sum_hessian_in_leaf=4.84; max_bin=211; min_data_in_bin=34; max_cat_threshold=81; bagging_freq=8; bagging_fraction=0.245; path_smooth=5.47; lambda_l1=1.59; lambda_l2=15.3; min_gain_to_split=0.291 : y = 0.918 : 115.7 secs : initdesign
#
# [mbo] 0: num_iterations=1030; learning_rate=0.286; feature_fraction=0.457; num_leaves=413; min_data_in_leaf=7173; min_sum_hessian_in_leaf=9.73; max_bin=185; min_data_in_bin=89; max_cat_threshold=51; bagging_freq=0; bagging_fraction=0.799; path_smooth=7.57; lambda_l1=4.24; lambda_l2=3.89; min_gain_to_split=0.496 : y = 0.921 : 80.7 secs : initdesign
#
# [mbo] 0: num_iterations=849; learning_rate=0.0557; feature_fraction=0.599; num_leaves=1576; min_data_in_leaf=6710; min_sum_hessian_in_leaf=6.32; max_bin=211; min_data_in_bin=77; max_cat_threshold=93; bagging_freq=9; bagging_fraction=0.581; path_smooth=0.528; lambda_l1=1.04; lambda_l2=6.17; min_gain_to_split=0.465 : y = 0.899 : 40.3 secs : initdesign
#
# [mbo] 0: num_iterations=1669; learning_rate=0.0454; feature_fraction=0.995; num_leaves=517; min_data_in_leaf=6319; min_sum_hessian_in_leaf=5.11; max_bin=188; min_data_in_bin=47; max_cat_threshold=100; bagging_freq=3; bagging_fraction=0.546; path_smooth=9.13; lambda_l1=1.4; lambda_l2=13.9; min_gain_to_split=0.333 : y = 0.902 : 63.6 secs : initdesign
#
# [mbo] 0: num_iterations=449; learning_rate=0.237; feature_fraction=0.926; num_leaves=577; min_data_in_leaf=1100; min_sum_hessian_in_leaf=4.44; max_bin=225; min_data_in_bin=73; max_cat_threshold=75; bagging_freq=1; bagging_fraction=0.598; path_smooth=6.45; lambda_l1=0.0661; lambda_l2=7.04; min_gain_to_split=0.257 : y = 0.931 : 44.7 secs : initdesign
#
# [mbo] 0: num_iterations=78; learning_rate=0.244; feature_fraction=0.904; num_leaves=1625; min_data_in_leaf=7850; min_sum_hessian_in_leaf=2.58; max_bin=45; min_data_in_bin=41; max_cat_threshold=70; bagging_freq=9; bagging_fraction=0.738; path_smooth=8.12; lambda_l1=2.88; lambda_l2=17.5; min_gain_to_split=0.432 : y = 0.901 : 2.6 secs : initdesign
#
# [mbo] 0: num_iterations=60; learning_rate=0.0934; feature_fraction=0.102; num_leaves=702; min_data_in_leaf=228; min_sum_hessian_in_leaf=2.81; max_bin=231; min_data_in_bin=81; max_cat_threshold=38; bagging_freq=2; bagging_fraction=0.29; path_smooth=2.02; lambda_l1=4.52; lambda_l2=6.39; min_gain_to_split=0.356 : y = 0.915 : 5.0 secs : initdesign
#
# [mbo] 0: num_iterations=1958; learning_rate=0.169; feature_fraction=0.534; num_leaves=478; min_data_in_leaf=4758; min_sum_hessian_in_leaf=6.65; max_bin=146; min_data_in_bin=59; max_cat_threshold=28; bagging_freq=5; bagging_fraction=0.967; path_smooth=8.48; lambda_l1=1.3; lambda_l2=11; min_gain_to_split=0.0208 : y = 0.927 : 185.9 secs : initdesign
#
# [mbo] 0: num_iterations=712; learning_rate=0.0638; feature_fraction=0.356; num_leaves=1506; min_data_in_leaf=3451; min_sum_hessian_in_leaf=7.94; max_bin=248; min_data_in_bin=1; max_cat_threshold=55; bagging_freq=4; bagging_fraction=0.19; path_smooth=1.21; lambda_l1=6.87; lambda_l2=14.6; min_gain_to_split=0.122 : y = 0.5 : 26.1 secs : initdesign
#
# [mbo] 0: num_iterations=1316; learning_rate=0.136; feature_fraction=0.843; num_leaves=172; min_data_in_leaf=2445; min_sum_hessian_in_leaf=0.176; max_bin=196; min_data_in_bin=100; max_cat_threshold=88; bagging_freq=2; bagging_fraction=0.216; path_smooth=1.64; lambda_l1=7.76; lambda_l2=9.54; min_gain_to_split=0.203 : y = 0.907 : 41.1 secs : initdesign
#
# [mbo] 0: num_iterations=408; learning_rate=0.0869; feature_fraction=0.188; num_leaves=854; min_data_in_leaf=5829; min_sum_hessian_in_leaf=4.32; max_bin=98; min_data_in_bin=28; max_cat_threshold=43; bagging_freq=4; bagging_fraction=0.854; path_smooth=0.154; lambda_l1=8.2; lambda_l2=6.8; min_gain_to_split=0.361 : y = 0.91 : 22.2 secs : initdesign
#
# [mbo] 0: num_iterations=1747; learning_rate=0.0507; feature_fraction=0.432; num_leaves=1759; min_data_in_leaf=1568; min_sum_hessian_in_leaf=0.413; max_bin=36; min_data_in_bin=85; max_cat_threshold=64; bagging_freq=0; bagging_fraction=0.101; path_smooth=6.13; lambda_l1=3.49; lambda_l2=1.42; min_gain_to_split=0.0652 : y = 0.933 : 226.2 secs : initdesign
#
# [mbo] 0: num_iterations=885; learning_rate=0.294; feature_fraction=0.698; num_leaves=1915; min_data_in_leaf=6601; min_sum_hessian_in_leaf=2.15; max_bin=219; min_data_in_bin=20; max_cat_threshold=1; bagging_freq=8; bagging_fraction=0.563; path_smooth=5.55; lambda_l1=2.72; lambda_l2=9.77; min_gain_to_split=0.211 : y = 0.905 : 30.5 secs : initdesign
#
# [mbo] 0: num_iterations=239; learning_rate=0.218; feature_fraction=0.429; num_leaves=63; min_data_in_leaf=3262; min_sum_hessian_in_leaf=1.45; max_bin=157; min_data_in_bin=67; max_cat_threshold=4; bagging_freq=5; bagging_fraction=0.49; path_smooth=9.69; lambda_l1=8.88; lambda_l2=9.16; min_gain_to_split=0.0251 : y = 0.915 : 14.0 secs : initdesign
#
# [mbo] 0: num_iterations=646; learning_rate=0.145; feature_fraction=0.715; num_leaves=665; min_data_in_leaf=519; min_sum_hessian_in_leaf=8.1; max_bin=58; min_data_in_bin=98; max_cat_threshold=14; bagging_freq=2; bagging_fraction=0.394; path_smooth=7.86; lambda_l1=3.61; lambda_l2=19.1; min_gain_to_split=0.2 : y = 0.931 : 55.4 secs : initdesign
#
# [mbo] 0: num_iterations=1885; learning_rate=0.126; feature_fraction=0.573; num_leaves=1546; min_data_in_leaf=744; min_sum_hessian_in_leaf=1.67; max_bin=172; min_data_in_bin=48; max_cat_threshold=78; bagging_freq=2; bagging_fraction=0.924; path_smooth=5.22; lambda_l1=8.8; lambda_l2=3.34; min_gain_to_split=0.392 : y = 0.935 : 321.1 secs : initdesign
#
# [mbo] 0: num_iterations=1877; learning_rate=0.192; feature_fraction=0.477; num_leaves=790; min_data_in_leaf=7068; min_sum_hessian_in_leaf=9.46; max_bin=252; min_data_in_bin=22; max_cat_threshold=8; bagging_freq=0; bagging_fraction=0.702; path_smooth=3.17; lambda_l1=5.15; lambda_l2=15; min_gain_to_split=0.433 : y = 0.922 : 158.6 secs : initdesign
#
# [mbo] 0: num_iterations=1525; learning_rate=0.0794; feature_fraction=0.47; num_leaves=1830; min_data_in_leaf=3777; min_sum_hessian_in_leaf=9.33; max_bin=57; min_data_in_bin=94; max_cat_threshold=84; bagging_freq=10; bagging_fraction=0.753; path_smooth=6.93; lambda_l1=4.88; lambda_l2=1.84; min_gain_to_split=0.158 : y = 0.923 : 129.4 secs : initdesign
#
# [mbo] 0: num_iterations=10; learning_rate=0.0419; feature_fraction=0.701; num_leaves=2034; min_data_in_leaf=1516; min_sum_hessian_in_leaf=2.55; max_bin=124; min_data_in_bin=40; max_cat_threshold=33; bagging_freq=9; bagging_fraction=0.152; path_smooth=7.09; lambda_l1=0.502; lambda_l2=0.292; min_gain_to_split=0.301 : y = 0.87 : 2.1 secs : initdesign
#
# [mbo] 0: num_iterations=1246; learning_rate=0.0287; feature_fraction=0.554; num_leaves=247; min_data_in_leaf=4682; min_sum_hessian_in_leaf=3.17; max_bin=120; min_data_in_bin=3; max_cat_threshold=91; bagging_freq=9; bagging_fraction=0.767; path_smooth=5.01; lambda_l1=0.402; lambda_l2=1.04; min_gain_to_split=0.167 : y = 0.913 : 102.0 secs : initdesign
#
# [mbo] 0: num_iterations=330; learning_rate=0.281; feature_fraction=0.126; num_leaves=1087; min_data_in_leaf=2598; min_sum_hessian_in_leaf=6.42; max_bin=69; min_data_in_bin=33; max_cat_threshold=84; bagging_freq=4; bagging_fraction=0.381; path_smooth=4.92; lambda_l1=5.59; lambda_l2=19.5; min_gain_to_split=0.00866 : y = 0.915 : 15.9 secs : initdesign
#
# [mbo] 0: num_iterations=1562; learning_rate=0.28; feature_fraction=0.852; num_leaves=588; min_data_in_leaf=3235; min_sum_hessian_in_leaf=4.58; max_bin=72; min_data_in_bin=8; max_cat_threshold=42; bagging_freq=0; bagging_fraction=0.474; path_smooth=8.19; lambda_l1=7.01; lambda_l2=4.11; min_gain_to_split=0.0989 : y = 0.931 : 142.4 secs : initdesign
#
# [mbo] 0: num_iterations=922; learning_rate=0.186; feature_fraction=0.975; num_leaves=83; min_data_in_leaf=5921; min_sum_hessian_in_leaf=8.3; max_bin=179; min_data_in_bin=58; max_cat_threshold=24; bagging_freq=6; bagging_fraction=0.231; path_smooth=0.256; lambda_l1=2.47; lambda_l2=12.5; min_gain_to_split=0.104 : y = 0.5 : 4.0 secs : initdesign
#
# [mbo] 0: num_iterations=1932; learning_rate=0.298; feature_fraction=0.161; num_leaves=362; min_data_in_leaf=3045; min_sum_hessian_in_leaf=9.85; max_bin=62; min_data_in_bin=96; max_cat_threshold=36; bagging_freq=10; bagging_fraction=0.32; path_smooth=2.24; lambda_l1=1.78; lambda_l2=18.1; min_gain_to_split=0.385 : y = 0.916 : 116.4 secs : initdesign
#
# [mbo] 0: num_iterations=1183; learning_rate=0.0693; feature_fraction=0.236; num_leaves=1687; min_data_in_leaf=5042; min_sum_hessian_in_leaf=0.518; max_bin=73; min_data_in_bin=87; max_cat_threshold=11; bagging_freq=10; bagging_fraction=0.195; path_smooth=0.72; lambda_l1=8.65; lambda_l2=16.6; min_gain_to_split=0.347 : y = 0.5 : 39.3 secs : initdesign
#
# [mbo] 0: num_iterations=264; learning_rate=0.0243; feature_fraction=0.829; num_leaves=551; min_data_in_leaf=6270; min_sum_hessian_in_leaf=1.4; max_bin=142; min_data_in_bin=86; max_cat_threshold=19; bagging_freq=1; bagging_fraction=0.27; path_smooth=9.86; lambda_l1=9.69; lambda_l2=16.1; min_gain_to_split=0.457 : y = 0.5 : 2.2 secs : initdesign
#
# [mbo] 0: num_iterations=376; learning_rate=0.172; feature_fraction=0.209; num_leaves=1121; min_data_in_leaf=7237; min_sum_hessian_in_leaf=6.89; max_bin=106; min_data_in_bin=24; max_cat_threshold=98; bagging_freq=1; bagging_fraction=0.533; path_smooth=9.37; lambda_l1=1.94; lambda_l2=5.55; min_gain_to_split=0.42 : y = 0.892 : 18.7 secs : initdesign
#
# [mbo] 0: num_iterations=1108; learning_rate=0.106; feature_fraction=0.964; num_leaves=1989; min_data_in_leaf=7911; min_sum_hessian_in_leaf=7.64; max_bin=206; min_data_in_bin=65; max_cat_threshold=72; bagging_freq=5; bagging_fraction=0.899; path_smooth=6.81; lambda_l1=7.39; lambda_l2=18.8; min_gain_to_split=0.115 : y = 0.914 : 58.3 secs : initdesign
#
# [mbo] 0: num_iterations=1378; learning_rate=0.0881; feature_fraction=0.541; num_leaves=36; min_data_in_leaf=809; min_sum_hessian_in_leaf=7.16; max_bin=200; min_data_in_bin=18; max_cat_threshold=20; bagging_freq=10; bagging_fraction=0.363; path_smooth=2.99; lambda_l1=9.93; lambda_l2=14; min_gain_to_split=0.486 : y = 0.929 : 147.2 secs : initdesign
#
# [mbo] 0: num_iterations=1816; learning_rate=0.258; feature_fraction=0.143; num_leaves=227; min_data_in_leaf=6136; min_sum_hessian_in_leaf=0.948; max_bin=248; min_data_in_bin=77; max_cat_threshold=79; bagging_freq=3; bagging_fraction=0.93; path_smooth=1.4; lambda_l1=3.07; lambda_l2=5.19; min_gain_to_split=0.318 : y = 0.923 : 127.0 secs : initdesign
#
# [mbo] 0: num_iterations=517; learning_rate=0.263; feature_fraction=0.916; num_leaves=1665; min_data_in_leaf=472; min_sum_hessian_in_leaf=8.68; max_bin=229; min_data_in_bin=82; max_cat_threshold=10; bagging_freq=10; bagging_fraction=0.979; path_smooth=7.3; lambda_l1=0.261; lambda_l2=13.1; min_gain_to_split=0.482 : y = 0.937 : 108.4 secs : initdesign
#
# [mbo] 0: num_iterations=141; learning_rate=0.271; feature_fraction=0.943; num_leaves=1290; min_data_in_leaf=2702; min_sum_hessian_in_leaf=3.71; max_bin=50; min_data_in_bin=80; max_cat_threshold=53; bagging_freq=5; bagging_fraction=0.998; path_smooth=0.974; lambda_l1=6.4; lambda_l2=2.5; min_gain_to_split=0.0697 : y = 0.929 : 8.5 secs : initdesign
#
# [mbo] 0: num_iterations=1734; learning_rate=0.199; feature_fraction=0.267; num_leaves=1960; min_data_in_leaf=7489; min_sum_hessian_in_leaf=7.72; max_bin=215; min_data_in_bin=44; max_cat_threshold=22; bagging_freq=8; bagging_fraction=0.13; path_smooth=9.31; lambda_l1=9.23; lambda_l2=0.74; min_gain_to_split=0.381 : y = 0.5 : 59.1 secs : initdesign
#
# [mbo] 0: num_iterations=1287; learning_rate=0.0193; feature_fraction=0.286; num_leaves=1409; min_data_in_leaf=2262; min_sum_hessian_in_leaf=1.16; max_bin=113; min_data_in_bin=14; max_cat_threshold=31; bagging_freq=3; bagging_fraction=0.633; path_smooth=7.36; lambda_l1=2.3; lambda_l2=19.9; min_gain_to_split=0.137 : y = 0.919 : 103.0 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Wed Oct 08 06:50:48 AM 2025 AUC 0.92933223685575
#
# [mbo] 1: num_iterations=1638; learning_rate=0.21; feature_fraction=0.819; num_leaves=1174; min_data_in_leaf=659; min_sum_hessian_in_leaf=3.04; max_bin=90; min_data_in_bin=75; max_cat_threshold=46; bagging_freq=7; bagging_fraction=0.37; path_smooth=8.57; lambda_l1=7.03; lambda_l2=12.5; min_gain_to_split=0.079 : y = 0.929 : 156.8 secs : infill_ei
#
# Wed Oct 08 06:52:26 AM 2025 AUC 0.926764553136986
#
# [mbo] 2: num_iterations=1256; learning_rate=0.245; feature_fraction=0.676; num_leaves=686; min_data_in_leaf=1467; min_sum_hessian_in_leaf=4.37; max_bin=250; min_data_in_bin=42; max_cat_threshold=61; bagging_freq=7; bagging_fraction=0.424; path_smooth=5.97; lambda_l1=8.02; lambda_l2=19.7; min_gain_to_split=0.415 : y = 0.927 : 96.9 secs : infill_ei
#
# Wed Oct 08 06:55:21 AM 2025 AUC 0.92852645896176
#
# [mbo] 3: num_iterations=1664; learning_rate=0.19; feature_fraction=0.732; num_leaves=546; min_data_in_leaf=374; min_sum_hessian_in_leaf=0.554; max_bin=210; min_data_in_bin=67; max_cat_threshold=97; bagging_freq=2; bagging_fraction=0.261; path_smooth=7.55; lambda_l1=7.34; lambda_l2=7.63; min_gain_to_split=0.337 : y = 0.929 : 174.6 secs : infill_ei
#
# Wed Oct 08 06:56:19 AM 2025 AUC 0.915754429384899
#
# [mbo] 4: num_iterations=1360; learning_rate=0.177; feature_fraction=0.848; num_leaves=1139; min_data_in_leaf=3584; min_sum_hessian_in_leaf=0.779; max_bin=136; min_data_in_bin=74; max_cat_threshold=62; bagging_freq=6; bagging_fraction=0.39; path_smooth=9.75; lambda_l1=5.73; lambda_l2=16.3; min_gain_to_split=0.474 : y = 0.916 : 56.5 secs : infill_ei
#
# Wed Oct 08 06:59:20 AM 2025 AUC 0.930250993953463
#
# [mbo] 5: num_iterations=1682; learning_rate=0.152; feature_fraction=0.116; num_leaves=256; min_data_in_leaf=524; min_sum_hessian_in_leaf=3.32; max_bin=156; min_data_in_bin=96; max_cat_threshold=59; bagging_freq=8; bagging_fraction=0.364; path_smooth=7.18; lambda_l1=3.89; lambda_l2=18; min_gain_to_split=0.176 : y = 0.93 : 180.8 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana.RDATA.
#
# Wed Oct 08 07:00:23 AM 2025 AUC 0.9188343442969
#
# [mbo] 6: num_iterations=1262; learning_rate=0.204; feature_fraction=0.842; num_leaves=1376; min_data_in_leaf=2135; min_sum_hessian_in_leaf=1.05; max_bin=161; min_data_in_bin=70; max_cat_threshold=12; bagging_freq=7; bagging_fraction=0.297; path_smooth=8.12; lambda_l1=5.06; lambda_l2=16.3; min_gain_to_split=0.241 : y = 0.919 : 61.8 secs : infill_ei
#
# Wed Oct 08 07:02:03 AM 2025 AUC 0.922680652749408
#
# [mbo] 7: num_iterations=1649; learning_rate=0.209; feature_fraction=0.629; num_leaves=1458; min_data_in_leaf=2908; min_sum_hessian_in_leaf=6.37; max_bin=166; min_data_in_bin=98; max_cat_threshold=23; bagging_freq=1; bagging_fraction=0.479; path_smooth=5.56; lambda_l1=8.32; lambda_l2=15.2; min_gain_to_split=0.165 : y = 0.923 : 99.3 secs : infill_ei
#
# Wed Oct 08 07:02:45 AM 2025 AUC 0.932224705892535
#
# [mbo] 8: num_iterations=340; learning_rate=0.181; feature_fraction=0.237; num_leaves=173; min_data_in_leaf=121; min_sum_hessian_in_leaf=2.4; max_bin=171; min_data_in_bin=54; max_cat_threshold=80; bagging_freq=8; bagging_fraction=0.448; path_smooth=3.32; lambda_l1=7.08; lambda_l2=10; min_gain_to_split=0.181 : y = 0.932 : 40.8 secs : infill_ei
#
# Wed Oct 08 07:04:01 AM 2025 AUC 0.920475433573971
#
# [mbo] 9: num_iterations=1452; learning_rate=0.259; feature_fraction=0.852; num_leaves=1327; min_data_in_leaf=2061; min_sum_hessian_in_leaf=2.23; max_bin=174; min_data_in_bin=25; max_cat_threshold=90; bagging_freq=7; bagging_fraction=0.307; path_smooth=9.31; lambda_l1=1.43; lambda_l2=15.6; min_gain_to_split=0.26 : y = 0.92 : 74.5 secs : infill_ei
#
# Wed Oct 08 07:06:31 AM 2025 AUC 0.931927042611529
#
# [mbo] 10: num_iterations=1141; learning_rate=0.0773; feature_fraction=0.796; num_leaves=1171; min_data_in_leaf=459; min_sum_hessian_in_leaf=4.07; max_bin=195; min_data_in_bin=83; max_cat_threshold=19; bagging_freq=4; bagging_fraction=0.423; path_smooth=4.8; lambda_l1=4.8; lambda_l2=3.73; min_gain_to_split=0.103 : y = 0.932 : 149.9 secs : infill_ei
#
# Wed Oct 08 07:09:23 AM 2025 AUC 0.930064333741526
#
# [mbo] 11: num_iterations=1096; learning_rate=0.221; feature_fraction=0.639; num_leaves=166; min_data_in_leaf=144; min_sum_hessian_in_leaf=3.19; max_bin=173; min_data_in_bin=16; max_cat_threshold=18; bagging_freq=8; bagging_fraction=0.277; path_smooth=9.32; lambda_l1=4.73; lambda_l2=17.3; min_gain_to_split=0.296 : y = 0.93 : 170.8 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Wed Oct 08 07:09:48 AM 2025 AUC 0.925123738270988
#
# [mbo] 12: num_iterations=469; learning_rate=0.178; feature_fraction=0.804; num_leaves=1016; min_data_in_leaf=1895; min_sum_hessian_in_leaf=4.27; max_bin=84; min_data_in_bin=31; max_cat_threshold=32; bagging_freq=9; bagging_fraction=0.474; path_smooth=6.58; lambda_l1=5.61; lambda_l2=3.36; min_gain_to_split=0.209 : y = 0.925 : 23.6 secs : infill_ei
#
# Wed Oct 08 07:11:04 AM 2025 AUC 0.933131989247638
#
# [mbo] 13: num_iterations=732; learning_rate=0.259; feature_fraction=0.734; num_leaves=715; min_data_in_leaf=2074; min_sum_hessian_in_leaf=5.62; max_bin=172; min_data_in_bin=34; max_cat_threshold=57; bagging_freq=4; bagging_fraction=0.936; path_smooth=6.98; lambda_l1=5.99; lambda_l2=5.33; min_gain_to_split=0.233 : y = 0.933 : 75.1 secs : infill_ei
#
# Wed Oct 08 07:14:53 AM 2025 AUC 0.933064552036761
#
# [mbo] 14: num_iterations=1523; learning_rate=0.0834; feature_fraction=0.798; num_leaves=804; min_data_in_leaf=332; min_sum_hessian_in_leaf=6.93; max_bin=182; min_data_in_bin=65; max_cat_threshold=11; bagging_freq=5; bagging_fraction=0.484; path_smooth=8.8; lambda_l1=8.23; lambda_l2=15.1; min_gain_to_split=0.342 : y = 0.933 : 228.3 secs : infill_ei
#
# Wed Oct 08 07:17:19 AM 2025 AUC 0.925631967495499
#
# [mbo] 15: num_iterations=1622; learning_rate=0.211; feature_fraction=0.416; num_leaves=551; min_data_in_leaf=2659; min_sum_hessian_in_leaf=6.92; max_bin=210; min_data_in_bin=63; max_cat_threshold=38; bagging_freq=4; bagging_fraction=0.581; path_smooth=7.13; lambda_l1=3.09; lambda_l2=12.7; min_gain_to_split=0.104 : y = 0.926 : 145.0 secs : infill_ei
#
# Wed Oct 08 07:17:23 AM 2025 AUC 0.920694273488544
#
# [mbo] 16: num_iterations=30; learning_rate=0.26; feature_fraction=0.237; num_leaves=1390; min_data_in_leaf=267; min_sum_hessian_in_leaf=3.82; max_bin=214; min_data_in_bin=86; max_cat_threshold=38; bagging_freq=5; bagging_fraction=0.375; path_smooth=4.26; lambda_l1=0.887; lambda_l2=11.3; min_gain_to_split=0.345 : y = 0.921 : 2.9 secs : infill_ei
#
# Wed Oct 08 07:18:51 AM 2025 AUC 0.931618016834396
#
# [mbo] 17: num_iterations=706; learning_rate=0.162; feature_fraction=0.133; num_leaves=909; min_data_in_leaf=234; min_sum_hessian_in_leaf=7.73; max_bin=42; min_data_in_bin=97; max_cat_threshold=33; bagging_freq=4; bagging_fraction=0.461; path_smooth=5.49; lambda_l1=4.82; lambda_l2=17.3; min_gain_to_split=0.00969 : y = 0.932 : 86.4 secs : infill_ei
#
# Wed Oct 08 07:19:46 AM 2025 AUC 0.927947426868975
#
# [mbo] 18: num_iterations=692; learning_rate=0.243; feature_fraction=0.801; num_leaves=1665; min_data_in_leaf=3457; min_sum_hessian_in_leaf=5.99; max_bin=186; min_data_in_bin=80; max_cat_threshold=58; bagging_freq=5; bagging_fraction=0.906; path_smooth=5.21; lambda_l1=5.89; lambda_l2=8.05; min_gain_to_split=0.358 : y = 0.928 : 54.4 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Wed Oct 08 07:21:37 AM 2025 AUC 0.922031554718389
#
# [mbo] 19: num_iterations=1877; learning_rate=0.0421; feature_fraction=0.812; num_leaves=766; min_data_in_leaf=1888; min_sum_hessian_in_leaf=8.16; max_bin=135; min_data_in_bin=89; max_cat_threshold=13; bagging_freq=9; bagging_fraction=0.397; path_smooth=6.72; lambda_l1=7.99; lambda_l2=14.6; min_gain_to_split=0.0222 : y = 0.922 : 109.9 secs : infill_ei
#
# Wed Oct 08 07:22:56 AM 2025 AUC 0.915086885398714
#
# [mbo] 20: num_iterations=1816; learning_rate=0.292; feature_fraction=0.626; num_leaves=1664; min_data_in_leaf=4825; min_sum_hessian_in_leaf=4; max_bin=182; min_data_in_bin=71; max_cat_threshold=90; bagging_freq=2; bagging_fraction=0.488; path_smooth=5.26; lambda_l1=5.64; lambda_l2=11.6; min_gain_to_split=0.2 : y = 0.915 : 78.0 secs : infill_ei
#
# Wed Oct 08 07:26:06 AM 2025 AUC 0.933709604669123
#
# [mbo] 21: num_iterations=1595; learning_rate=0.112; feature_fraction=0.788; num_leaves=1069; min_data_in_leaf=1648; min_sum_hessian_in_leaf=4.23; max_bin=71; min_data_in_bin=29; max_cat_threshold=43; bagging_freq=0; bagging_fraction=0.348; path_smooth=7.93; lambda_l1=8.79; lambda_l2=18.7; min_gain_to_split=0.27 : y = 0.934 : 189.1 secs : infill_ei
#
# Wed Oct 08 07:29:33 AM 2025 AUC 0.931008160859723
#
# [mbo] 22: num_iterations=1553; learning_rate=0.266; feature_fraction=0.698; num_leaves=138; min_data_in_leaf=195; min_sum_hessian_in_leaf=1.39; max_bin=78; min_data_in_bin=25; max_cat_threshold=59; bagging_freq=7; bagging_fraction=0.337; path_smooth=4.66; lambda_l1=5.59; lambda_l2=17.3; min_gain_to_split=0.352 : y = 0.931 : 206.0 secs : infill_ei
#
# Wed Oct 08 07:32:03 AM 2025 AUC 0.92962768255393
#
# [mbo] 23: num_iterations=1659; learning_rate=0.177; feature_fraction=0.771; num_leaves=491; min_data_in_leaf=2716; min_sum_hessian_in_leaf=4.04; max_bin=166; min_data_in_bin=57; max_cat_threshold=42; bagging_freq=2; bagging_fraction=0.799; path_smooth=3.72; lambda_l1=5.36; lambda_l2=1.96; min_gain_to_split=0.26 : y = 0.93 : 148.2 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Wed Oct 08 07:34:02 AM 2025 AUC 0.915672423846061
#
# [mbo] 24: num_iterations=1758; learning_rate=0.198; feature_fraction=0.525; num_leaves=53; min_data_in_leaf=2587; min_sum_hessian_in_leaf=2.32; max_bin=70; min_data_in_bin=33; max_cat_threshold=62; bagging_freq=7; bagging_fraction=0.28; path_smooth=8.62; lambda_l1=6.39; lambda_l2=8.62; min_gain_to_split=0.478 : y = 0.916 : 118.5 secs : infill_ei
#
# Wed Oct 08 07:34:48 AM 2025 AUC 0.925031756586333
#
# [mbo] 25: num_iterations=524; learning_rate=0.102; feature_fraction=0.104; num_leaves=296; min_data_in_leaf=951; min_sum_hessian_in_leaf=6.15; max_bin=217; min_data_in_bin=28; max_cat_threshold=31; bagging_freq=2; bagging_fraction=0.519; path_smooth=6.65; lambda_l1=1.88; lambda_l2=6.7; min_gain_to_split=0.455 : y = 0.925 : 44.7 secs : infill_ei
#
# Wed Oct 08 07:36:04 AM 2025 AUC 0.933820094014185
#
# [mbo] 26: num_iterations=544; learning_rate=0.153; feature_fraction=0.767; num_leaves=1353; min_data_in_leaf=589; min_sum_hessian_in_leaf=5.36; max_bin=177; min_data_in_bin=55; max_cat_threshold=40; bagging_freq=5; bagging_fraction=0.764; path_smooth=6.39; lambda_l1=6.94; lambda_l2=8.42; min_gain_to_split=0.388 : y = 0.934 : 74.7 secs : infill_ei
#
# Wed Oct 08 07:37:04 AM 2025 AUC 0.92607331011829
#
# [mbo] 27: num_iterations=964; learning_rate=0.215; feature_fraction=0.781; num_leaves=1797; min_data_in_leaf=1493; min_sum_hessian_in_leaf=5.93; max_bin=43; min_data_in_bin=32; max_cat_threshold=47; bagging_freq=3; bagging_fraction=0.406; path_smooth=9.18; lambda_l1=4.79; lambda_l2=18.7; min_gain_to_split=0.393 : y = 0.926 : 59.4 secs : infill_ei
#
# Wed Oct 08 07:38:07 AM 2025 AUC 0.917242704459503
#
# [mbo] 28: num_iterations=1263; learning_rate=0.219; feature_fraction=0.831; num_leaves=1352; min_data_in_leaf=6206; min_sum_hessian_in_leaf=4.28; max_bin=211; min_data_in_bin=49; max_cat_threshold=73; bagging_freq=1; bagging_fraction=0.683; path_smooth=5.81; lambda_l1=4.12; lambda_l2=9.87; min_gain_to_split=0.336 : y = 0.917 : 62.1 secs : infill_ei
#
# Wed Oct 08 07:41:01 AM 2025 AUC 0.92568408088892
#
# [mbo] 29: num_iterations=1218; learning_rate=0.166; feature_fraction=0.756; num_leaves=338; min_data_in_leaf=106; min_sum_hessian_in_leaf=0.629; max_bin=209; min_data_in_bin=52; max_cat_threshold=85; bagging_freq=5; bagging_fraction=0.141; path_smooth=5.16; lambda_l1=3.33; lambda_l2=3.32; min_gain_to_split=0.0834 : y = 0.926 : 172.3 secs : infill_ei
#
# Wed Oct 08 07:42:52 AM 2025 AUC 0.924199623456847
#
# [mbo] 30: num_iterations=1656; learning_rate=0.048; feature_fraction=0.845; num_leaves=1551; min_data_in_leaf=2389; min_sum_hessian_in_leaf=6.39; max_bin=112; min_data_in_bin=80; max_cat_threshold=27; bagging_freq=2; bagging_fraction=0.566; path_smooth=4.68; lambda_l1=9.69; lambda_l2=14.4; min_gain_to_split=0.00236 : y = 0.924 : 109.9 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Wed Oct 08 07:45:02 AM 2025 AUC 0.917807672305786
#
# [mbo] 31: num_iterations=1748; learning_rate=0.178; feature_fraction=0.487; num_leaves=1310; min_data_in_leaf=3262; min_sum_hessian_in_leaf=3.5; max_bin=220; min_data_in_bin=12; max_cat_threshold=38; bagging_freq=5; bagging_fraction=0.384; path_smooth=9.33; lambda_l1=7.97; lambda_l2=12.1; min_gain_to_split=0.384 : y = 0.918 : 129.4 secs : infill_ei
#
# Wed Oct 08 07:46:41 AM 2025 AUC 0.923142406037785
#
# [mbo] 32: num_iterations=1187; learning_rate=0.218; feature_fraction=0.552; num_leaves=638; min_data_in_leaf=1960; min_sum_hessian_in_leaf=2.69; max_bin=121; min_data_in_bin=94; max_cat_threshold=90; bagging_freq=1; bagging_fraction=0.368; path_smooth=4.47; lambda_l1=7.24; lambda_l2=12.5; min_gain_to_split=0.0111 : y = 0.923 : 97.3 secs : infill_ei
#
# Wed Oct 08 07:49:12 AM 2025 AUC 0.929501821424524
#
# [mbo] 33: num_iterations=1482; learning_rate=0.135; feature_fraction=0.219; num_leaves=839; min_data_in_leaf=712; min_sum_hessian_in_leaf=6.02; max_bin=218; min_data_in_bin=100; max_cat_threshold=94; bagging_freq=4; bagging_fraction=0.394; path_smooth=4.99; lambda_l1=5.6; lambda_l2=17.7; min_gain_to_split=0.432 : y = 0.93 : 149.4 secs : infill_ei
#
# Wed Oct 08 07:50:46 AM 2025 AUC 0.931101005788816
#
# [mbo] 34: num_iterations=730; learning_rate=0.117; feature_fraction=0.537; num_leaves=1885; min_data_in_leaf=558; min_sum_hessian_in_leaf=0.174; max_bin=152; min_data_in_bin=70; max_cat_threshold=91; bagging_freq=1; bagging_fraction=0.36; path_smooth=6.28; lambda_l1=1.57; lambda_l2=1.29; min_gain_to_split=0.199 : y = 0.931 : 92.9 secs : infill_ei
#
# Wed Oct 08 07:53:14 AM 2025 AUC 0.93338644326172
#
# [mbo] 35: num_iterations=1133; learning_rate=0.0952; feature_fraction=0.725; num_leaves=823; min_data_in_leaf=1054; min_sum_hessian_in_leaf=8.57; max_bin=226; min_data_in_bin=43; max_cat_threshold=74; bagging_freq=3; bagging_fraction=0.704; path_smooth=5.12; lambda_l1=2.32; lambda_l2=11.4; min_gain_to_split=0.354 : y = 0.933 : 146.5 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesiana.RDATA.
#
# Wed Oct 08 07:54:10 AM 2025 AUC 0.921188555595202
#
# [mbo] 36: num_iterations=1131; learning_rate=0.194; feature_fraction=0.952; num_leaves=94; min_data_in_leaf=1227; min_sum_hessian_in_leaf=0.657; max_bin=57; min_data_in_bin=37; max_cat_threshold=80; bagging_freq=9; bagging_fraction=0.225; path_smooth=1.92; lambda_l1=3.34; lambda_l2=11.9; min_gain_to_split=0.177 : y = 0.921 : 55.0 secs : infill_ei
#
# Wed Oct 08 07:54:24 AM 2025 AUC 0.921991034897082
#
# [mbo] 37: num_iterations=188; learning_rate=0.196; feature_fraction=0.545; num_leaves=1283; min_data_in_leaf=2316; min_sum_hessian_in_leaf=3.06; max_bin=214; min_data_in_bin=68; max_cat_threshold=82; bagging_freq=2; bagging_fraction=0.524; path_smooth=2.77; lambda_l1=5.55; lambda_l2=2.93; min_gain_to_split=0.342 : y = 0.922 : 12.7 secs : infill_ei
#
# Wed Oct 08 07:54:32 AM 2025 AUC 0.923892388425872
#
# [mbo] 38: num_iterations=94; learning_rate=0.189; feature_fraction=0.222; num_leaves=35; min_data_in_leaf=103; min_sum_hessian_in_leaf=0.258; max_bin=90; min_data_in_bin=81; max_cat_threshold=99; bagging_freq=9; bagging_fraction=0.201; path_smooth=3.66; lambda_l1=5.18; lambda_l2=19; min_gain_to_split=0.354 : y = 0.924 : 6.9 secs : infill_ei
#
# Wed Oct 08 07:57:02 AM 2025 AUC 0.93254839028441
#
# [mbo] 39: num_iterations=1193; learning_rate=0.116; feature_fraction=0.325; num_leaves=990; min_data_in_leaf=825; min_sum_hessian_in_leaf=6.13; max_bin=85; min_data_in_bin=34; max_cat_threshold=61; bagging_freq=2; bagging_fraction=0.615; path_smooth=7.87; lambda_l1=7.61; lambda_l2=2.06; min_gain_to_split=0.136 : y = 0.933 : 148.4 secs : infill_ei
#
# Wed Oct 08 08:01:39 AM 2025 AUC 0.93394358484798
#
# [mbo] 40: num_iterations=1850; learning_rate=0.213; feature_fraction=0.35; num_leaves=850; min_data_in_leaf=1209; min_sum_hessian_in_leaf=9; max_bin=210; min_data_in_bin=47; max_cat_threshold=25; bagging_freq=8; bagging_fraction=0.905; path_smooth=6.14; lambda_l1=2.94; lambda_l2=5.37; min_gain_to_split=0.474 : y = 0.934 : 276.5 secs : infill_ei
#
# Wed Oct 08 08:03:04 AM 2025 AUC 0.936046778316859
#
# [mbo] 41: num_iterations=539; learning_rate=0.215; feature_fraction=0.55; num_leaves=1282; min_data_in_leaf=560; min_sum_hessian_in_leaf=3.04; max_bin=54; min_data_in_bin=64; max_cat_threshold=43; bagging_freq=8; bagging_fraction=0.966; path_smooth=3.12; lambda_l1=3.61; lambda_l2=11.5; min_gain_to_split=0.442 : y = 0.936 : 83.1 secs : infill_ei
#
# Wed Oct 08 08:05:47 AM 2025 AUC 0.925763650814734
#
# [mbo] 42: num_iterations=1992; learning_rate=0.273; feature_fraction=0.112; num_leaves=149; min_data_in_leaf=1714; min_sum_hessian_in_leaf=9.43; max_bin=52; min_data_in_bin=78; max_cat_threshold=43; bagging_freq=8; bagging_fraction=0.461; path_smooth=4.64; lambda_l1=2.11; lambda_l2=15.3; min_gain_to_split=0.495 : y = 0.926 : 162.4 secs : infill_ei
#
# Saved the current state after iteration 43 in the file bayesiana.RDATA.
#
# Wed Oct 08 08:07:06 AM 2025 AUC 0.911984253587628
#
# [mbo] 43: num_iterations=1168; learning_rate=0.0635; feature_fraction=0.154; num_leaves=1217; min_data_in_leaf=3907; min_sum_hessian_in_leaf=6.09; max_bin=167; min_data_in_bin=46; max_cat_threshold=33; bagging_freq=3; bagging_fraction=0.523; path_smooth=9.59; lambda_l1=6.52; lambda_l2=14.7; min_gain_to_split=0.103 : y = 0.912 : 76.9 secs : infill_ei
#
# Wed Oct 08 08:07:31 AM 2025 AUC 0.91741795964646
#
# [mbo] 44: num_iterations=655; learning_rate=0.24; feature_fraction=0.892; num_leaves=181; min_data_in_leaf=1748; min_sum_hessian_in_leaf=2.33; max_bin=86; min_data_in_bin=5; max_cat_threshold=41; bagging_freq=10; bagging_fraction=0.237; path_smooth=9.62; lambda_l1=7.04; lambda_l2=18.6; min_gain_to_split=0.439 : y = 0.917 : 24.5 secs : infill_ei
#
# Wed Oct 08 08:09:28 AM 2025 AUC 0.932568919162974
#
# [mbo] 45: num_iterations=1180; learning_rate=0.206; feature_fraction=0.716; num_leaves=1214; min_data_in_leaf=2469; min_sum_hessian_in_leaf=1; max_bin=71; min_data_in_bin=24; max_cat_threshold=86; bagging_freq=0; bagging_fraction=0.526; path_smooth=8.07; lambda_l1=5.45; lambda_l2=18.9; min_gain_to_split=0.2 : y = 0.933 : 114.7 secs : infill_ei
#
# Wed Oct 08 08:10:03 AM 2025 AUC 0.92880271394867
#
# [mbo] 46: num_iterations=432; learning_rate=0.249; feature_fraction=0.488; num_leaves=222; min_data_in_leaf=1298; min_sum_hessian_in_leaf=5.14; max_bin=56; min_data_in_bin=6; max_cat_threshold=54; bagging_freq=5; bagging_fraction=0.58; path_smooth=8.33; lambda_l1=7.81; lambda_l2=16.2; min_gain_to_split=0.0911 : y = 0.929 : 34.4 secs : infill_ei
#
# Wed Oct 08 08:14:42 AM 2025 AUC 0.936456199953229
#
# [mbo] 47: num_iterations=1521; learning_rate=0.193; feature_fraction=0.834; num_leaves=1683; min_data_in_leaf=666; min_sum_hessian_in_leaf=8.34; max_bin=102; min_data_in_bin=31; max_cat_threshold=47; bagging_freq=8; bagging_fraction=0.954; path_smooth=7.04; lambda_l1=3.5; lambda_l2=14.8; min_gain_to_split=0.307 : y = 0.936 : 277.3 secs : infill_ei
#
# Wed Oct 08 08:18:59 AM 2025 AUC 0.933547160258461
#
# [mbo] 48: num_iterations=1593; learning_rate=0.111; feature_fraction=0.475; num_leaves=424; min_data_in_leaf=301; min_sum_hessian_in_leaf=6.88; max_bin=189; min_data_in_bin=92; max_cat_threshold=19; bagging_freq=10; bagging_fraction=0.492; path_smooth=3.49; lambda_l1=6.72; lambda_l2=10.9; min_gain_to_split=0.461 : y = 0.934 : 255.2 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Wed Oct 08 08:24:35 AM 2025 AUC 0.937466629685963
#
# [mbo] 49: num_iterations=1704; learning_rate=0.0767; feature_fraction=0.554; num_leaves=377; min_data_in_leaf=685; min_sum_hessian_in_leaf=0.449; max_bin=56; min_data_in_bin=100; max_cat_threshold=73; bagging_freq=0; bagging_fraction=0.163; path_smooth=6.23; lambda_l1=1.82; lambda_l2=1.95; min_gain_to_split=0.117 : y = 0.937 : 335.0 secs : infill_ei
#
# Wed Oct 08 08:26:19 AM 2025 AUC 0.924622343584957
#
# [mbo] 50: num_iterations=1520; learning_rate=0.15; feature_fraction=0.695; num_leaves=902; min_data_in_leaf=943; min_sum_hessian_in_leaf=1.92; max_bin=200; min_data_in_bin=58; max_cat_threshold=68; bagging_freq=8; bagging_fraction=0.244; path_smooth=8.9; lambda_l1=2.84; lambda_l2=15.1; min_gain_to_split=0.448 : y = 0.925 : 102.5 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"          "learning_rate"
#  [3] "feature_fraction"        "num_leaves"
#  [5] "min_data_in_leaf"        "min_sum_hessian_in_leaf"
#  [7] "max_bin"                 "min_data_in_bin"
#  [9] "max_cat_threshold"       "bagging_freq"
# [11] "bagging_fraction"        "path_smooth"
# [13] "lambda_l1"               "lambda_l2"
# [15] "min_gain_to_split"       "y"
# [17] "dob"                     "eol"
# [19] "error.message"           "exec.time"
# [21] "ei"                      "error.model"
# [23] "train.time"              "prop.type"
# [25] "propose.time"            "se"
# [27] "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate feature_fraction num_leaves min_data_in_leaf
#             <int>         <num>            <num>      <int>            <int>
# 1:           1704    0.07671277        0.5542874        377              685
#    min_sum_hessian_in_leaf max_bin min_data_in_bin max_cat_threshold
#                      <num>   <int>           <int>             <int>
# 1:               0.4487854      56             100                73
#    bagging_freq bagging_fraction path_smooth lambda_l1 lambda_l2
#           <int>            <num>       <num>     <num>     <num>
# 1:            0        0.1634749     6.23026  1.815345  1.952391
#    min_gain_to_split
#                <num>
# 1:         0.1174785
# [1] 0.9374666

# %%
# Entrenar en 202101-202103
param_test <- modifyList(PARAM$lgbm$param_fijos,
                         PARAM$out$lgbm$mejores_hiperparametros)

modelo_test <- lgb.train(
  data = dtrain,
  param = param_test
)

# Predecir en 202104
dataset_test <- dataset[foto_mes == 202104]
dataset_test[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

prediccion_test <- predict(
  modelo_test,
  data.matrix(dataset_test[, campos_buenos, with = FALSE])
)

# Crear tabla de predicción
tb_test <- dataset_test[, .(numero_de_cliente, foto_mes)]
tb_test[, prob := prediccion_test]

# Inicializar realidad para test
drealidad_test <- realidad_inicializar(dataset_test, PARAM)

# Calcular ganancias usando realidad_evaluar
resultados_cortes <- data.table()
setorder(tb_test, -prob)

for(envios in PARAM$cortes) {

  tb_test[, Predicted := 0L]
  tb_test[1:envios, Predicted := 1L]

  res <- realidad_evaluar(drealidad_test, tb_test)

  resultados_cortes <- rbind(resultados_cortes,
                             data.table(
                               envios = envios,
                               ganancia_total = res$total,
                               ganancia_public = res$public,
                               ganancia_private = res$private,
                               ganancia_por_envio = res$total / envios
                             ))

  options(scipen = 999)
  cat("Envios=", envios, "\t",
      " TOTAL=", res$total,
      "  Public=", res$public,
      " Private=", res$private,
      "\n",
      sep = "")
}
# Out:
# Envios=6000	 TOTAL=524000000  Public=482533333 Private=541771429
# Envios=6500	 TOTAL=543600000  Public=509533333 Private=558200000
# Envios=7000	 TOTAL=561600000  Public=524466667 Private=577514286
# Envios=7500	 TOTAL=573200000  Public=541400000 Private=586828571
# Envios=8000	 TOTAL=579200000  Public=544600000 Private=594028571
# Envios=8500	 TOTAL=590000000  Public=558466667 Private=603514286
# Envios=9000	 TOTAL=600000000  Public=568733333 Private=613400000
# Envios=9500	 TOTAL=604400000  Public=587066667 Private=611828571
# Envios=10000	 TOTAL=611200000  Public=599933333 Private=616028571
# Envios=10500	 TOTAL=611600000  Public=594266667 Private=619028571
# Envios=11000	 TOTAL=610400000  Public=587666667 Private=620142857
# Envios=11500	 TOTAL=610000000  Public=588200000 Private=619342857
# Envios=12000	 TOTAL=607200000  Public=583266667 Private=617457143
# Envios=12500	 TOTAL=607600000  Public=586666667 Private=616571429
# Envios=13000	 TOTAL=606400000  Public=589333333 Private=613714286
# Envios=13500	 TOTAL=600400000  Public=587733333 Private=605828571
# Envios=14000	 TOTAL=592000000  Public=583200000 Private=595771429
# Envios=14500	 TOTAL=588400000  Public=572333333 Private=595285714
# Envios=15000	 TOTAL=580000000  Public=564733333 Private=586542857
# Envios=15500	 TOTAL=573200000  Public=555266667 Private=580885714
# Envios=16000	 TOTAL=567200000  Public=550066667 Private=574542857
# Envios=16500	 TOTAL=559600000  Public=547600000 Private=564742857
# Envios=17000	 TOTAL=550400000  Public=539066667 Private=555257143
# Envios=17500	 TOTAL=542800000  Public=532533333 Private=547200000
# Envios=18000	 TOTAL=535200000  Public=522866667 Private=540485714
# Envios=18500	 TOTAL=526000000  Public=515733333 Private=530400000
# Envios=19000	 TOTAL=516800000  Public=506133333 Private=521371429

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la  optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train_final]
dataset_train[,.N,clase_ternaria]
# Out:
#   clase_ternaria N
# 1 BAJA+1           3447
# 2 BAJA+2           3938
# 3 CONTINUA       642824

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "dart"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 170029
#
# $max_depth
# [1] -1
#
# $min_gain_to_split
# [1] 0.1174785
#
# $min_sum_hessian_in_leaf
# [1] 0.4487854
#
# $lambda_l1
# [1] 1.815345
#
# $lambda_l2
# [1] 1.952391
#
# $max_bin
# [1] 56
#
# $bagging_fraction
# [1] 0.1634749
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1704
#
# $learning_rate
# [1] 0.07671277
#
# $feature_fraction
# [1] 0.5542874
#
# $num_leaves
# [1] 377
#
# $min_data_in_leaf
# [1] 685
#
# $min_data_in_bin
# [1] 100
#
# $max_cat_threshold
# [1] 73
#
# $bagging_freq
# [1] 0
#
# $path_smooth
# [1] 6.23026

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria y mucho menos cross validation.

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
# entreno LightGBM

modelo_final <- lgb.train(
  data= dtrain_final,
  param= param_normalizado
)

# %%
# ahora imprimo la importancia de variables

tb_importancia <- as.data.table(lgb.importance(modelo_final))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...
lgb.save(modelo_final, "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes %in% PARAM$future]

# aplico el modelo a los datos nuevos
prediccion <- predict(
  modelo_final,
  data.matrix(dfuture[, campos_buenos, with= FALSE])
)

# %%
# inicilizo el dataset  drealidad
drealidad <- realidad_inicializar( dfuture, PARAM)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
PARAM$cortes
# Out:
#  [1]  6000  6500  7000  7500  8000  8500  9000  9500 10000 10500 11000 11500
# [13] 12000 12500 13000 13500 14000 14500 15000 15500 16000 16500 17000 17500
# [25] 18000 18500 19000

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marco los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  # res <- realidad_evaluar( drealidad, tb_prediccion)

  # options(scipen = 999)
  # cat( "Envios=", envios, "\t",
  #   " TOTAL=", res$total,
  #   "  Public=", res$public,
  #   " Private=", res$private,
  #   "\n",
  #   sep= ""
  # )

}

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Wed Oct 08 08:44:24 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
