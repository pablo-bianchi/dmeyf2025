# %%
# primero establecer el Runtime de Python 3
from google.colab import drive
drive.mount('/content/.drive')
# Out:
# Mounted at /content/.drive

# %%
%%shell

mkdir -p "/content/.drive/My Drive/dmeyf"
mkdir -p "/content/buckets"
ln -s "/content/.drive/My Drive/dmeyf" /content/buckets/b1


mkdir -p /content/buckets/b1/exp
mkdir -p /content/buckets/b1/datasets
mkdir -p /content/datasets



archivo_origen="https://storage.googleapis.com/open-courses/dmeyf2025-e4a2/competencia_01_crudo.csv"
archivo_destino="/content/datasets/competencia_01_crudo.csv"
archivo_destino_bucket="/content/buckets/b1/datasets/competencia_01_crudo.csv"

if ! test -f $archivo_destino_bucket; then
  wget  $archivo_origen  -O $archivo_destino_bucket
fi


if ! test -f $archivo_destino; then
  cp  $archivo_destino_bucket  $archivo_destino
fi

# %% [markdown]
# ## 1 Dataset

# %% [markdown]
# ### 1.1 Feature Engineering

# %% [markdown]
# ### 1.1.1 Generacion de la clase_ternaria

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %%
require( "data.table" )

# leo el dataset
dataset <- fread("/content/datasets/competencia_01_crudo.csv" )

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
    "pos" = .I,
    numero_de_cliente,
    periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 ) ]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
    shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente ]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
    ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
    clase_ternaria := "BAJA+1" ]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
    & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
    clase_ternaria := "BAJA+2" ]


# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)
# Out:
# Loading required package: data.table

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  202101   BAJA+1            622
# 2  202101   BAJA+2            825
# 3  202101   CONTINUA       160080
# 4  202102   BAJA+1            831
# 5  202102   BAJA+2           1032
# 6  202102   CONTINUA       160292
# 7  202103   BAJA+1           1039
# 8  202103   BAJA+2            951
# 9  202103   CONTINUA       161119
# 10 202104   BAJA+1            955
# 11 202104   BAJA+2           1130
# 12 202104   CONTINUA       161333
# 13 202105   NA             162783
# 14 202105   BAJA+1           1134
# 15 202106   NA             164313

# %% [markdown]
# ### 1.1.3 Creación de lags y delta lags

# %%
max_lag <- 1

# selecciono automáticamente todas las columnas numéricas, excepto id y fecha
campos_laguear <- setdiff(
  names(dataset)[sapply(dataset, is.numeric)],
  c("numero_de_cliente", "foto_mes")
)

cat("Máximo lag posible:", max_lag, "\n")
cat("Campos a laggear:", paste(campos_laguear, collapse=", "), "\n")

# genero los lags (ya lo tenías)
dataset[, paste0(rep(campos_laguear, each = max_lag), "_lag", 1:max_lag) :=
          shift(.SD, n = 1:max_lag, type = "lag"),
        by = numero_de_cliente,
        .SDcols = campos_laguear]

# genero los delta lags como var - lagX
for (campo in campos_laguear) {
  for (k in 1:max_lag) {
    dataset[, (paste0(campo, "_delta", k)) :=
              get(campo) - get(paste0(campo, "_lag", k))]
  }
}
# Out:
# Máximo lag posible: 1
# Campos a laggear: active_quarter, cliente_vip, internet, cliente_edad, cliente_antiguedad, mrentabilidad, mrentabilidad_annual, mcomisiones, mactivos_margen, mpasivos_margen, cproductos, tcuentas, ccuenta_corriente, mcuenta_corriente_adicional, mcuenta_corriente, ccaja_ahorro, mcaja_ahorro, mcaja_ahorro_adicional, mcaja_ahorro_dolares, cdescubierto_preacordado, mcuentas_saldo, ctarjeta_debito, ctarjeta_debito_transacciones, mautoservicio, ctarjeta_visa, ctarjeta_visa_transacciones, mtarjeta_visa_consumo, ctarjeta_master, ctarjeta_master_transacciones, mtarjeta_master_consumo, cprestamos_personales, mprestamos_personales, cprestamos_prendarios, mprestamos_prendarios, cprestamos_hipotecarios, mprestamos_hipotecarios, cplazo_fijo, mplazo_fijo_dolares, mplazo_fijo_pesos, cinversion1, minversion1_pesos, minversion1_dolares, cinversion2, minversion2, cseguro_vida, cseguro_auto, cseguro_vivienda, cseguro_accidentes_personales, ccaja_seguridad, cpayroll_trx, mpayroll, mpayroll2, cpayroll2_trx, ccuenta_debitos_automaticos, mcuenta_debitos_automaticos, ctarjeta_visa_debitos_automaticos, mttarjeta_visa_debitos_automaticos, ctarjeta_master_debitos_automaticos, mttarjeta_master_debitos_automaticos, cpagodeservicios, mpagodeservicios, cpagomiscuentas, mpagomiscuentas, ccajeros_propios_descuentos, mcajeros_propios_descuentos, ctarjeta_visa_descuentos, mtarjeta_visa_descuentos, ctarjeta_master_descuentos, mtarjeta_master_descuentos, ccomisiones_mantenimiento, mcomisiones_mantenimiento, ccomisiones_otras, mcomisiones_otras, cforex, cforex_buy, mforex_buy, cforex_sell, mforex_sell, ctransferencias_recibidas, mtransferencias_recibidas, ctransferencias_emitidas, mtransferencias_emitidas, cextraccion_autoservicio, mextraccion_autoservicio, ccheques_depositados, mcheques_depositados, ccheques_emitidos, mcheques_emitidos, ccheques_depositados_rechazados, mcheques_depositados_rechazados, ccheques_emitidos_rechazados, mcheques_emitidos_rechazados, tcallcenter, ccallcenter_transacciones, thomebanking, chomebanking_transacciones, ccajas_transacciones, ccajas_consultas, ccajas_depositos, ccajas_extracciones, ccajas_otras, catm_trx, matm, catm_trx_other, matm_other, ctrx_quarter, tmobile_app, cmobile_app_trx, Master_delinquency, Master_status, Master_mfinanciacion_limite, Master_Fvencimiento, Master_Finiciomora, Master_msaldototal, Master_msaldopesos, Master_msaldodolares, Master_mconsumospesos, Master_mconsumosdolares, Master_mlimitecompra, Master_madelantopesos, Master_madelantodolares, Master_fultimo_cierre, Master_mpagado, Master_mpagospesos, Master_mpagosdolares, Master_fechaalta, Master_mconsumototal, Master_cconsumos, Master_cadelantosefectivo, Master_mpagominimo, Visa_delinquency, Visa_status, Visa_mfinanciacion_limite, Visa_Fvencimiento, Visa_Finiciomora, Visa_msaldototal, Visa_msaldopesos, Visa_msaldodolares, Visa_mconsumospesos, Visa_mconsumosdolares, Visa_mlimitecompra, Visa_madelantopesos, Visa_madelantodolares, Visa_fultimo_cierre, Visa_mpagado, Visa_mpagospesos, Visa_mpagosdolares, Visa_fechaalta, Visa_mconsumototal, Visa_cconsumos, Visa_cadelantosefectivo, Visa_mpagominimo

# %%
fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Fri Oct 10 10:33:01 PM 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  728230 38.9   1454471    77.7   1454471   77.7
# Vcells 1383573 10.6 351853324  2684.5 338914398 2585.8

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %% [markdown]
# Esta parte lleva varios minutos la primera vez en Google Colab

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: parallel
#
# Loading required package: R.utils
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘R.utils’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘R.oo’, ‘R.methodsS3’
#
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings
#
#
# Loading required package: primes
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘primes’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘rlist’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘XML’
#
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘lightgbm’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘DiceKriging’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Warning message in library(package, lib.loc = lib.loc, character.only = TRUE, logical.return = TRUE, :
# “there is no package called ‘mlrMBO’”
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘fastmatch’, ‘RcppArmadillo’, ‘mlr’, ‘ParamHelpers’, ‘smoof’, ‘BBmisc’, ‘checkmate’, ‘lhs’, ‘parallelMap’
#
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %% [markdown]
# #### Nombre experimento y semilla

# %%
PARAM <- list()
PARAM$experimento <- 'C01-38i'
PARAM$semilla_primigenia <- 170029

# %% [markdown]
# #### Seteo meses

# %%
# training y future
PARAM$train <- c(202101, 202102, 202103)  # Para BO
PARAM$train_final <- c(202101, 202102, 202103, 202104)  # Para modelo final
PARAM$future <- c(202106)  # CAMBIO PRINCIPAL
PARAM$test <- c(202104)  # Nuevo: para validar hiperparámetros
PARAM$semilla_kaggle <- 314159
PARAM$cortes <- seq(6000, 19000, by= 500)

# %% [markdown]
# #### Undersampling

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.1

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  # Iteraciones / tasa de aprendizaje
  makeIntegerParam("num_iterations", lower = 8L, upper = 2048L),
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.3),

  # Complejidad del árbol
  makeIntegerParam("num_leaves", lower = 8L, upper = 2048L),
  makeIntegerParam("max_depth", lower = -1L, upper = 30L),
  makeIntegerParam("min_data_in_leaf", lower = 1L, upper = 6000L),
  makeNumericParam("min_split_gain", lower = 0.0, upper = 0.3),

  # Submuestreo de features y filas
  makeNumericParam("feature_fraction", lower = 0.1, upper = 1.0),
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1.0),
  makeIntegerParam("bagging_freq", lower = 1L, upper = 10L),

  # Regularización L1/L2
  makeNumericParam("lambda_l1", lower = 0.0, upper = 5.0),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 5.0)

  # (Opcional, si querés experimentar con tipos de boosting)
  # makeDiscreteParam("boosting_type", values = c("gbdt", "dart", "goss"))
)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 30 # iteraciones bayesianas

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed, "L'Ecuyer-CMRG")

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# iniciliazo el dataset de realidad, para medir ganancia
realidad_inicializar <- function( pfuture, pparam) {

  # datos para verificar la ganancia
  drealidad <- pfuture[, list(numero_de_cliente, foto_mes, clase_ternaria)]

  particionar(drealidad,
    division= c(3, 7),
    agrupa= "clase_ternaria",
    seed= PARAM$semilla_kaggle
  )

  return( drealidad )
}

# %%
# evaluo ganancia en los datos de la realidad

realidad_evaluar <- function( prealidad, pprediccion) {

  prealidad[ pprediccion,
    on= c("numero_de_cliente", "foto_mes"),
    predicted:= i.Predicted
  ]

  tbl <- prealidad[, list("qty"=.N), list(fold, predicted, clase_ternaria)]

  res <- list()
  res$public  <- tbl[fold==1 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.3
  res$private <- tbl[fold==2 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.7
  res$total <- tbl[predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]

  prealidad[, predicted:=NULL]
  return( res )
}

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/competencia_01.csv.gz", stringsAsFactors= TRUE)

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in%  PARAM$train &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 53386
# [1] 458

# %% [markdown]
# ### 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# ### 2.2.6 Corrida Bayesian Optimization

# %%
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Computing y column(s) for design. Not provided.
#
# Fri Oct 10 10:43:30 PM 2025 AUC 0.92859800706342
#
# Fri Oct 10 10:43:51 PM 2025 AUC 0.925849948588146
#
# Fri Oct 10 10:44:57 PM 2025 AUC 0.927809062227831
#
# Fri Oct 10 10:46:18 PM 2025 AUC 0.921342076049131
#
# Fri Oct 10 10:48:08 PM 2025 AUC 0.930962288333518
#
# Fri Oct 10 10:50:40 PM 2025 AUC 0.929388422637312
#
# Fri Oct 10 10:51:18 PM 2025 AUC 0.927892887490165
#
# Fri Oct 10 10:52:21 PM 2025 AUC 0.92595181518895
#
# Fri Oct 10 10:53:35 PM 2025 AUC 0.92859756829846
#
# Fri Oct 10 10:53:47 PM 2025 AUC 0.926789515416793
#
# Fri Oct 10 10:55:02 PM 2025 AUC 0.930030425099124
#
# Fri Oct 10 10:55:58 PM 2025 AUC 0.932073926894001
#
# Fri Oct 10 10:57:32 PM 2025 AUC 0.930774685125216
#
# Fri Oct 10 10:57:37 PM 2025 AUC 0.913988349014384
#
# Fri Oct 10 10:57:53 PM 2025 AUC 0.92539428981984
#
# Fri Oct 10 10:58:31 PM 2025 AUC 0.932271595098738
#
# Fri Oct 10 10:59:56 PM 2025 AUC 0.923398045788997
#
# Fri Oct 10 11:01:31 PM 2025 AUC 0.929714875646967
#
# Fri Oct 10 11:03:42 PM 2025 AUC 0.928261375877307
#
# Fri Oct 10 11:05:29 PM 2025 AUC 0.935283519705959
#
# Fri Oct 10 11:06:33 PM 2025 AUC 0.929615749474629
#
# Fri Oct 10 11:07:01 PM 2025 AUC 0.92764910424619
#
# Fri Oct 10 11:08:07 PM 2025 AUC 0.931217087134557
#
# Fri Oct 10 11:08:49 PM 2025 AUC 0.929429949873575
#
# Fri Oct 10 11:10:16 PM 2025 AUC 0.928626696369847
#
# Fri Oct 10 11:10:54 PM 2025 AUC 0.927877298120281
#
# Fri Oct 10 11:12:58 PM 2025 AUC 0.925808679063778
#
# Fri Oct 10 11:13:28 PM 2025 AUC 0.920899768992999
#
# Fri Oct 10 11:13:41 PM 2025 AUC 0.924776992851856
#
# Fri Oct 10 11:15:28 PM 2025 AUC 0.922787104769246
#
# Fri Oct 10 11:16:49 PM 2025 AUC 0.927732742956656
#
# Fri Oct 10 11:18:34 PM 2025 AUC 0.929494004750044
#
# Fri Oct 10 11:18:37 PM 2025 AUC 0.917393710512352
#
# Fri Oct 10 11:19:17 PM 2025 AUC 0.925064849577802
#
# Fri Oct 10 11:20:17 PM 2025 AUC 0.926793283729211
#
# Fri Oct 10 11:20:27 PM 2025 AUC 0.917703533672201
#
# Fri Oct 10 11:21:51 PM 2025 AUC 0.932385961529648
#
# Fri Oct 10 11:22:35 PM 2025 AUC 0.932520347779328
#
# Fri Oct 10 11:23:23 PM 2025 AUC 0.922754873099352
#
# Fri Oct 10 11:23:29 PM 2025 AUC 0.896048587887551
#
# Fri Oct 10 11:24:47 PM 2025 AUC 0.931010984937802
#
# Fri Oct 10 11:26:26 PM 2025 AUC 0.923885315477117
#
# Fri Oct 10 11:26:39 PM 2025 AUC 0.919616899433624
#
# Fri Oct 10 11:28:22 PM 2025 AUC 0.929819743377285
#
# [mbo] 0: num_iterations=1195; learning_rate=0.2; num_leaves=1241; max_depth=22; min_data_in_leaf=1019; min_split_gain=0.0811; feature_fraction=0.447; bagging_fraction=0.641; bagging_freq=2; lambda_l1=3.66; lambda_l2=3.15 : y = 0.929 : 100.2 secs : initdesign
#
# [mbo] 0: num_iterations=453; learning_rate=0.266; num_leaves=1699; max_depth=13; min_data_in_leaf=2598; min_split_gain=0.159; feature_fraction=0.932; bagging_fraction=0.618; bagging_freq=6; lambda_l1=2.63; lambda_l2=1.37 : y = 0.926 : 20.8 secs : initdesign
#
# [mbo] 0: num_iterations=887; learning_rate=0.162; num_leaves=764; max_depth=10; min_data_in_leaf=3152; min_split_gain=0.231; feature_fraction=0.541; bagging_fraction=0.729; bagging_freq=6; lambda_l1=3.76; lambda_l2=1.83 : y = 0.928 : 66.1 secs : initdesign
#
# [mbo] 0: num_iterations=1402; learning_rate=0.0339; num_leaves=714; max_depth=7; min_data_in_leaf=5547; min_split_gain=0.129; feature_fraction=0.26; bagging_fraction=0.652; bagging_freq=7; lambda_l1=2.77; lambda_l2=4.06 : y = 0.921 : 80.8 secs : initdesign
#
# [mbo] 0: num_iterations=1568; learning_rate=0.186; num_leaves=1338; max_depth=17; min_data_in_leaf=1453; min_split_gain=0.167; feature_fraction=0.912; bagging_fraction=0.88; bagging_freq=5; lambda_l1=2.56; lambda_l2=2.61 : y = 0.931 : 110.8 secs : initdesign
#
# [mbo] 0: num_iterations=1625; learning_rate=0.294; num_leaves=554; max_depth=9; min_data_in_leaf=1156; min_split_gain=0.0625; feature_fraction=0.555; bagging_fraction=0.849; bagging_freq=3; lambda_l1=2.2; lambda_l2=1.8 : y = 0.929 : 151.6 secs : initdesign
#
# [mbo] 0: num_iterations=695; learning_rate=0.237; num_leaves=1007; max_depth=26; min_data_in_leaf=1337; min_split_gain=0.103; feature_fraction=0.705; bagging_fraction=0.627; bagging_freq=3; lambda_l1=1.52; lambda_l2=3.05 : y = 0.928 : 37.7 secs : initdesign
#
# [mbo] 0: num_iterations=960; learning_rate=0.139; num_leaves=485; max_depth=11; min_data_in_leaf=4273; min_split_gain=0.138; feature_fraction=0.406; bagging_fraction=0.684; bagging_freq=7; lambda_l1=0.942; lambda_l2=0.879 : y = 0.926 : 62.9 secs : initdesign
#
# [mbo] 0: num_iterations=1006; learning_rate=0.133; num_leaves=1645; max_depth=15; min_data_in_leaf=4447; min_split_gain=0.0722; feature_fraction=0.459; bagging_fraction=0.858; bagging_freq=4; lambda_l1=0.845; lambda_l2=3.78 : y = 0.929 : 74.2 secs : initdesign
#
# [mbo] 0: num_iterations=287; learning_rate=0.109; num_leaves=870; max_depth=17; min_data_in_leaf=2586; min_split_gain=0.0559; feature_fraction=0.661; bagging_fraction=0.575; bagging_freq=9; lambda_l1=1.67; lambda_l2=3.21 : y = 0.927 : 12.2 secs : initdesign
#
# [mbo] 0: num_iterations=1090; learning_rate=0.0894; num_leaves=820; max_depth=19; min_data_in_leaf=2222; min_split_gain=0.153; feature_fraction=0.301; bagging_fraction=0.773; bagging_freq=1; lambda_l1=0.727; lambda_l2=0.411 : y = 0.93 : 74.6 secs : initdesign
#
# [mbo] 0: num_iterations=723; learning_rate=0.0402; num_leaves=1504; max_depth=24; min_data_in_leaf=1588; min_split_gain=0.266; feature_fraction=0.758; bagging_fraction=0.966; bagging_freq=5; lambda_l1=1.08; lambda_l2=4.56 : y = 0.932 : 56.2 secs : initdesign
#
# [mbo] 0: num_iterations=1927; learning_rate=0.0659; num_leaves=639; max_depth=20; min_data_in_leaf=3321; min_split_gain=0.0936; feature_fraction=0.855; bagging_fraction=0.867; bagging_freq=6; lambda_l1=3.39; lambda_l2=1.15 : y = 0.931 : 94.0 secs : initdesign
#
# [mbo] 0: num_iterations=61; learning_rate=0.175; num_leaves=190; max_depth=8; min_data_in_leaf=3910; min_split_gain=0.0256; feature_fraction=0.183; bagging_fraction=0.51; bagging_freq=7; lambda_l1=2.92; lambda_l2=2.18 : y = 0.914 : 5.2 secs : initdesign
#
# [mbo] 0: num_iterations=391; learning_rate=0.258; num_leaves=1884; max_depth=17; min_data_in_leaf=4900; min_split_gain=0.133; feature_fraction=0.685; bagging_fraction=0.804; bagging_freq=10; lambda_l1=2.12; lambda_l2=2.15 : y = 0.925 : 16.4 secs : initdesign
#
# [mbo] 0: num_iterations=475; learning_rate=0.0951; num_leaves=1742; max_depth=-1; min_data_in_leaf=876; min_split_gain=0.175; feature_fraction=0.829; bagging_fraction=0.833; bagging_freq=5; lambda_l1=1.95; lambda_l2=3.95 : y = 0.932 : 38.0 secs : initdesign
#
# [mbo] 0: num_iterations=1249; learning_rate=0.271; num_leaves=1135; max_depth=14; min_data_in_leaf=3428; min_split_gain=0.18; feature_fraction=0.489; bagging_fraction=0.535; bagging_freq=7; lambda_l1=4.95; lambda_l2=3.42 : y = 0.923 : 84.2 secs : initdesign
#
# [mbo] 0: num_iterations=1798; learning_rate=0.151; num_leaves=63; max_depth=24; min_data_in_leaf=2064; min_split_gain=0.223; feature_fraction=0.942; bagging_fraction=0.724; bagging_freq=3; lambda_l1=1.38; lambda_l2=2.86 : y = 0.93 : 95.6 secs : initdesign
#
# [mbo] 0: num_iterations=1902; learning_rate=0.158; num_leaves=906; max_depth=12; min_data_in_leaf=4144; min_split_gain=0.237; feature_fraction=0.379; bagging_fraction=0.905; bagging_freq=2; lambda_l1=2.44; lambda_l2=4.72 : y = 0.928 : 131.2 secs : initdesign
#
# [mbo] 0: num_iterations=810; learning_rate=0.0777; num_leaves=1625; max_depth=15; min_data_in_leaf=84; min_split_gain=0.211; feature_fraction=0.347; bagging_fraction=0.608; bagging_freq=10; lambda_l1=2.28; lambda_l2=0.727 : y = 0.935 : 106.9 secs : initdesign
#
# [mbo] 0: num_iterations=1056; learning_rate=0.182; num_leaves=1915; max_depth=29; min_data_in_leaf=2903; min_split_gain=0.00108; feature_fraction=0.616; bagging_fraction=0.937; bagging_freq=2; lambda_l1=4.22; lambda_l2=3.58 : y = 0.93 : 63.5 secs : initdesign
#
# [mbo] 0: num_iterations=353; learning_rate=0.0614; num_leaves=589; max_depth=28; min_data_in_leaf=1994; min_split_gain=0.244; feature_fraction=0.573; bagging_fraction=0.552; bagging_freq=4; lambda_l1=3.94; lambda_l2=3.72 : y = 0.928 : 28.1 secs : initdesign
#
# [mbo] 0: num_iterations=1157; learning_rate=0.129; num_leaves=272; max_depth=5; min_data_in_leaf=409; min_split_gain=0.206; feature_fraction=0.139; bagging_fraction=0.513; bagging_freq=7; lambda_l1=0.265; lambda_l2=2.48 : y = 0.931 : 65.6 secs : initdesign
#
# [mbo] 0: num_iterations=562; learning_rate=0.207; num_leaves=396; max_depth=26; min_data_in_leaf=2785; min_split_gain=0.281; feature_fraction=0.41; bagging_fraction=0.954; bagging_freq=9; lambda_l1=4.81; lambda_l2=4.17 : y = 0.929 : 42.5 secs : initdesign
#
# [mbo] 0: num_iterations=1397; learning_rate=0.219; num_leaves=1837; max_depth=2; min_data_in_leaf=3739; min_split_gain=0.258; feature_fraction=0.34; bagging_fraction=0.978; bagging_freq=3; lambda_l1=4.57; lambda_l2=0.599 : y = 0.929 : 87.1 secs : initdesign
#
# [mbo] 0: num_iterations=788; learning_rate=0.221; num_leaves=1400; max_depth=22; min_data_in_leaf=3994; min_split_gain=0.196; feature_fraction=0.972; bagging_fraction=0.893; bagging_freq=5; lambda_l1=0.507; lambda_l2=0.154 : y = 0.928 : 38.1 secs : initdesign
#
# [mbo] 0: num_iterations=2020; learning_rate=0.102; num_leaves=2047; max_depth=29; min_data_in_leaf=5442; min_split_gain=0.12; feature_fraction=0.308; bagging_fraction=0.742; bagging_freq=10; lambda_l1=3.99; lambda_l2=0.53 : y = 0.926 : 123.9 secs : initdesign
#
# [mbo] 0: num_iterations=1271; learning_rate=0.0265; num_leaves=1464; max_depth=1; min_data_in_leaf=1733; min_split_gain=0.0545; feature_fraction=0.783; bagging_fraction=0.662; bagging_freq=4; lambda_l1=1.31; lambda_l2=1.36 : y = 0.921 : 29.5 secs : initdesign
#
# [mbo] 0: num_iterations=263; learning_rate=0.053; num_leaves=48; max_depth=20; min_data_in_leaf=3667; min_split_gain=0.00867; feature_fraction=0.753; bagging_fraction=0.829; bagging_freq=8; lambda_l1=4.33; lambda_l2=2.7 : y = 0.925 : 13.3 secs : initdesign
#
# [mbo] 0: num_iterations=1535; learning_rate=0.291; num_leaves=1175; max_depth=25; min_data_in_leaf=4678; min_split_gain=0.109; feature_fraction=0.516; bagging_fraction=0.589; bagging_freq=1; lambda_l1=1.79; lambda_l2=3.37 : y = 0.923 : 107.6 secs : initdesign
#
# [mbo] 0: num_iterations=1960; learning_rate=0.049; num_leaves=137; max_depth=0; min_data_in_leaf=4562; min_split_gain=0.0335; feature_fraction=0.89; bagging_fraction=0.815; bagging_freq=4; lambda_l1=1.86; lambda_l2=4.53 : y = 0.928 : 80.0 secs : initdesign
#
# [mbo] 0: num_iterations=1714; learning_rate=0.0838; num_leaves=1273; max_depth=5; min_data_in_leaf=2321; min_split_gain=0.291; feature_fraction=0.595; bagging_fraction=0.695; bagging_freq=10; lambda_l1=3.2; lambda_l2=4.32 : y = 0.929 : 105.7 secs : initdesign
#
# [mbo] 0: num_iterations=41; learning_rate=0.231; num_leaves=366; max_depth=2; min_data_in_leaf=3088; min_split_gain=0.0988; feature_fraction=0.181; bagging_fraction=0.963; bagging_freq=5; lambda_l1=4.7; lambda_l2=1.67 : y = 0.917 : 3.0 secs : initdesign
#
# [mbo] 0: num_iterations=605; learning_rate=0.0122; num_leaves=1786; max_depth=23; min_data_in_leaf=1824; min_split_gain=0.0866; feature_fraction=0.241; bagging_fraction=0.793; bagging_freq=6; lambda_l1=3.61; lambda_l2=2.79 : y = 0.925 : 39.6 secs : initdesign
#
# [mbo] 0: num_iterations=1322; learning_rate=0.284; num_leaves=946; max_depth=0; min_data_in_leaf=5719; min_split_gain=0.198; feature_fraction=0.8; bagging_fraction=0.92; bagging_freq=9; lambda_l1=1.18; lambda_l2=2.35 : y = 0.927 : 60.0 secs : initdesign
#
# [mbo] 0: num_iterations=184; learning_rate=0.169; num_leaves=1047; max_depth=8; min_data_in_leaf=5831; min_split_gain=0.0185; feature_fraction=0.103; bagging_fraction=0.753; bagging_freq=2; lambda_l1=0.658; lambda_l2=0.0624 : y = 0.918 : 10.5 secs : initdesign
#
# [mbo] 0: num_iterations=1473; learning_rate=0.116; num_leaves=208; max_depth=4; min_data_in_leaf=558; min_split_gain=0.295; feature_fraction=0.143; bagging_fraction=0.772; bagging_freq=1; lambda_l1=4.44; lambda_l2=0.913 : y = 0.932 : 84.1 secs : initdesign
#
# [mbo] 0: num_iterations=616; learning_rate=0.121; num_leaves=700; max_depth=3; min_data_in_leaf=488; min_split_gain=0.0453; feature_fraction=0.48; bagging_fraction=0.93; bagging_freq=9; lambda_l1=0.451; lambda_l2=4.87 : y = 0.933 : 43.9 secs : initdesign
#
# [mbo] 0: num_iterations=1752; learning_rate=0.273; num_leaves=1990; max_depth=21; min_data_in_leaf=5244; min_split_gain=0.0376; feature_fraction=0.874; bagging_fraction=0.533; bagging_freq=10; lambda_l1=0.202; lambda_l2=1.57 : y = 0.923 : 47.3 secs : initdesign
#
# [mbo] 0: num_iterations=134; learning_rate=0.00986; num_leaves=1372; max_depth=11; min_data_in_leaf=4995; min_split_gain=0.275; feature_fraction=0.98; bagging_fraction=0.678; bagging_freq=3; lambda_l1=2.97; lambda_l2=2 : y = 0.896 : 6.1 secs : initdesign
#
# [mbo] 0: num_iterations=899; learning_rate=0.245; num_leaves=1107; max_depth=30; min_data_in_leaf=196; min_split_gain=0.252; feature_fraction=0.726; bagging_fraction=0.709; bagging_freq=8; lambda_l1=3.52; lambda_l2=0.29 : y = 0.931 : 78.6 secs : initdesign
#
# [mbo] 0: num_iterations=1652; learning_rate=0.0188; num_leaves=294; max_depth=12; min_data_in_leaf=5995; min_split_gain=0.144; feature_fraction=0.212; bagging_fraction=0.995; bagging_freq=8; lambda_l1=3.07; lambda_l2=1.12 : y = 0.924 : 98.2 secs : initdesign
#
# [mbo] 0: num_iterations=221; learning_rate=0.247; num_leaves=461; max_depth=27; min_data_in_leaf=5172; min_split_gain=0.263; feature_fraction=0.279; bagging_fraction=0.559; bagging_freq=8; lambda_l1=0.0148; lambda_l2=4.36 : y = 0.92 : 13.3 secs : initdesign
#
# [mbo] 0: num_iterations=1838; learning_rate=0.194; num_leaves=1557; max_depth=6; min_data_in_leaf=812; min_split_gain=0.184; feature_fraction=0.639; bagging_fraction=0.593; bagging_freq=1; lambda_l1=4.17; lambda_l2=4.94 : y = 0.93 : 103.7 secs : initdesign
#
# Saved the current state after iteration 1 in the file bayesiana.RDATA.
#
# Fri Oct 10 11:30:54 PM 2025 AUC 0.938632160699561
#
# [mbo] 1: num_iterations=972; learning_rate=0.101; num_leaves=1650; max_depth=26; min_data_in_leaf=75; min_split_gain=0.243; feature_fraction=0.396; bagging_fraction=0.997; bagging_freq=8; lambda_l1=0.974; lambda_l2=2.74 : y = 0.939 : 150.2 secs : infill_ei
#
# Fri Oct 10 11:32:55 PM 2025 AUC 0.935930255130443
#
# [mbo] 2: num_iterations=854; learning_rate=0.0918; num_leaves=700; max_depth=28; min_data_in_leaf=323; min_split_gain=0.233; feature_fraction=0.569; bagging_fraction=0.952; bagging_freq=9; lambda_l1=3.18; lambda_l2=4.34 : y = 0.936 : 120.4 secs : infill_ei
#
# Fri Oct 10 11:34:18 PM 2025 AUC 0.93690180652306
#
# [mbo] 3: num_iterations=776; learning_rate=0.123; num_leaves=1676; max_depth=24; min_data_in_leaf=586; min_split_gain=0.298; feature_fraction=0.362; bagging_fraction=0.963; bagging_freq=10; lambda_l1=1.26; lambda_l2=2.42 : y = 0.937 : 83.0 secs : infill_ei
#
# Fri Oct 10 11:37:21 PM 2025 AUC 0.939315733381104
#
# [mbo] 4: num_iterations=761; learning_rate=0.0961; num_leaves=1725; max_depth=22; min_data_in_leaf=4; min_split_gain=0.213; feature_fraction=0.464; bagging_fraction=0.771; bagging_freq=8; lambda_l1=1.21; lambda_l2=4.7 : y = 0.939 : 182.2 secs : infill_ei
#
# Fri Oct 10 11:41:01 PM 2025 AUC 0.938802674390815
#
# [mbo] 5: num_iterations=671; learning_rate=0.0888; num_leaves=1925; max_depth=30; min_data_in_leaf=17; min_split_gain=0.244; feature_fraction=0.334; bagging_fraction=0.87; bagging_freq=6; lambda_l1=0.0973; lambda_l2=4.62 : y = 0.939 : 219.9 secs : infill_ei
#
# Saved the current state after iteration 6 in the file bayesiana.RDATA.
#
# Fri Oct 10 11:44:06 PM 2025 AUC 0.937075189298162
#
# [mbo] 6: num_iterations=962; learning_rate=0.0953; num_leaves=1994; max_depth=24; min_data_in_leaf=1; min_split_gain=0.299; feature_fraction=0.395; bagging_fraction=0.857; bagging_freq=6; lambda_l1=2.15; lambda_l2=4.96 : y = 0.937 : 183.9 secs : infill_ei
#
# Fri Oct 10 11:47:02 PM 2025 AUC 0.940109178697333
#
# [mbo] 7: num_iterations=783; learning_rate=0.0925; num_leaves=1862; max_depth=18; min_data_in_leaf=50; min_split_gain=0.201; feature_fraction=0.456; bagging_fraction=0.864; bagging_freq=8; lambda_l1=0.348; lambda_l2=3.93 : y = 0.94 : 175.7 secs : infill_ei
#
# Fri Oct 10 11:48:56 PM 2025 AUC 0.93923446285603
#
# [mbo] 8: num_iterations=402; learning_rate=0.117; num_leaves=1892; max_depth=19; min_data_in_leaf=59; min_split_gain=0.22; feature_fraction=0.551; bagging_fraction=0.939; bagging_freq=6; lambda_l1=0.0731; lambda_l2=3.12 : y = 0.939 : 113.2 secs : infill_ei
#
# Fri Oct 10 11:57:44 PM 2025 AUC 0.939695425859414
#
# [mbo] 9: num_iterations=1798; learning_rate=0.112; num_leaves=1851; max_depth=22; min_data_in_leaf=2; min_split_gain=0.191; feature_fraction=0.505; bagging_fraction=0.827; bagging_freq=7; lambda_l1=0.0429; lambda_l2=1.48 : y = 0.94 : 527.8 secs : infill_ei
#
# Saved the current state after iteration 10 in the file bayesiana.RDATA.
#
# Sat Oct 11 12:00:04 AM 2025 AUC 0.93922636507614
#
# [mbo] 10: num_iterations=1121; learning_rate=0.133; num_leaves=2013; max_depth=7; min_data_in_leaf=26; min_split_gain=0.187; feature_fraction=0.586; bagging_fraction=0.895; bagging_freq=8; lambda_l1=0.0994; lambda_l2=1.14 : y = 0.939 : 139.2 secs : infill_ei
#
# Sat Oct 11 12:03:57 AM 2025 AUC 0.939451397228789
#
# [mbo] 11: num_iterations=1041; learning_rate=0.117; num_leaves=2019; max_depth=19; min_data_in_leaf=19; min_split_gain=0.216; feature_fraction=0.515; bagging_fraction=0.751; bagging_freq=6; lambda_l1=0.0319; lambda_l2=0.137 : y = 0.939 : 231.6 secs : infill_ei
#
# Sat Oct 11 12:06:21 AM 2025 AUC 0.936688342888118
#
# [mbo] 12: num_iterations=946; learning_rate=0.107; num_leaves=1915; max_depth=29; min_data_in_leaf=303; min_split_gain=0.152; feature_fraction=0.634; bagging_fraction=0.882; bagging_freq=8; lambda_l1=0.365; lambda_l2=2.65 : y = 0.937 : 143.4 secs : infill_ei
#
# Sat Oct 11 12:14:43 AM 2025 AUC 0.940512008684856
#
# [mbo] 13: num_iterations=1239; learning_rate=0.122; num_leaves=1770; max_depth=13; min_data_in_leaf=1; min_split_gain=0.23; feature_fraction=0.456; bagging_fraction=0.812; bagging_freq=8; lambda_l1=0.0181; lambda_l2=3.88 : y = 0.941 : 501.4 secs : infill_ei
#
# Saved the current state after iteration 14 in the file bayesiana.RDATA.
#
# Sat Oct 11 12:22:21 AM 2025 AUC 0.940032996771759
#
# [mbo] 14: num_iterations=1543; learning_rate=0.123; num_leaves=1765; max_depth=14; min_data_in_leaf=11; min_split_gain=0.224; feature_fraction=0.331; bagging_fraction=0.843; bagging_freq=4; lambda_l1=0.00524; lambda_l2=2.78 : y = 0.94 : 457.5 secs : infill_ei
#
# Sat Oct 11 12:25:43 AM 2025 AUC 0.939798594557834
#
# [mbo] 15: num_iterations=1925; learning_rate=0.116; num_leaves=1018; max_depth=12; min_data_in_leaf=34; min_split_gain=0.226; feature_fraction=0.422; bagging_fraction=0.958; bagging_freq=6; lambda_l1=0.601; lambda_l2=0.446 : y = 0.94 : 201.0 secs : infill_ei
#
# Saved the current state after iteration 16 in the file bayesiana.RDATA.
#
# Sat Oct 11 12:27:56 AM 2025 AUC 0.935856583696023
#
# [mbo] 16: num_iterations=1583; learning_rate=0.146; num_leaves=1897; max_depth=5; min_data_in_leaf=4; min_split_gain=0.242; feature_fraction=0.421; bagging_fraction=0.932; bagging_freq=6; lambda_l1=0.0128; lambda_l2=1.13 : y = 0.936 : 133.0 secs : infill_ei
#
# Sat Oct 11 12:33:24 AM 2025 AUC 0.940477878566493
#
# [mbo] 17: num_iterations=1918; learning_rate=0.0766; num_leaves=1040; max_depth=16; min_data_in_leaf=111; min_split_gain=0.209; feature_fraction=0.439; bagging_fraction=0.898; bagging_freq=6; lambda_l1=0.195; lambda_l2=2.8 : y = 0.94 : 327.3 secs : infill_ei
#
# Sat Oct 11 12:40:31 AM 2025 AUC 0.940909303556212
#
# [mbo] 18: num_iterations=1223; learning_rate=0.103; num_leaves=1276; max_depth=16; min_data_in_leaf=2; min_split_gain=0.215; feature_fraction=0.527; bagging_fraction=0.855; bagging_freq=5; lambda_l1=0.114; lambda_l2=4.45 : y = 0.941 : 426.6 secs : infill_ei
#
# Saved the current state after iteration 19 in the file bayesiana.RDATA.
#
# Sat Oct 11 12:44:06 AM 2025 AUC 0.938210297322679
#
# [mbo] 19: num_iterations=1556; learning_rate=0.0586; num_leaves=185; max_depth=17; min_data_in_leaf=223; min_split_gain=0.217; feature_fraction=0.373; bagging_fraction=0.965; bagging_freq=7; lambda_l1=0.446; lambda_l2=4.87 : y = 0.938 : 213.9 secs : infill_ei
#
# Sat Oct 11 12:54:36 AM 2025 AUC 0.940385813574422
#
# [mbo] 20: num_iterations=1499; learning_rate=0.0704; num_leaves=1600; max_depth=18; min_data_in_leaf=4; min_split_gain=0.199; feature_fraction=0.414; bagging_fraction=0.959; bagging_freq=6; lambda_l1=0.0567; lambda_l2=4.67 : y = 0.94 : 629.3 secs : infill_ei
#
# Saved the current state after iteration 21 in the file bayesiana.RDATA.
#
# Sat Oct 11 12:59:06 AM 2025 AUC 0.939690579098576
#
# [mbo] 21: num_iterations=1521; learning_rate=0.0981; num_leaves=1148; max_depth=17; min_data_in_leaf=3; min_split_gain=0.234; feature_fraction=0.216; bagging_fraction=0.875; bagging_freq=8; lambda_l1=0.166; lambda_l2=1.43 : y = 0.94 : 269.3 secs : infill_ei
#
# Sat Oct 11 01:04:04 AM 2025 AUC 0.938830696400051
#
# [mbo] 22: num_iterations=1913; learning_rate=0.0979; num_leaves=1424; max_depth=16; min_data_in_leaf=2; min_split_gain=0.195; feature_fraction=0.292; bagging_fraction=0.903; bagging_freq=5; lambda_l1=0.594; lambda_l2=4.1 : y = 0.939 : 297.1 secs : infill_ei
#
# Sat Oct 11 01:11:41 AM 2025 AUC 0.940591889147544
#
# [mbo] 23: num_iterations=1581; learning_rate=0.0976; num_leaves=988; max_depth=14; min_data_in_leaf=1; min_split_gain=0.216; feature_fraction=0.639; bagging_fraction=0.869; bagging_freq=8; lambda_l1=0.0328; lambda_l2=1.02 : y = 0.941 : 456.5 secs : infill_ei
#
# Saved the current state after iteration 24 in the file bayesiana.RDATA.
#
# Sat Oct 11 01:17:48 AM 2025 AUC 0.941103289878448
#
# [mbo] 24: num_iterations=1833; learning_rate=0.0692; num_leaves=1068; max_depth=21; min_data_in_leaf=1; min_split_gain=0.21; feature_fraction=0.49; bagging_fraction=0.885; bagging_freq=9; lambda_l1=0.0173; lambda_l2=0.0226 : y = 0.941 : 366.0 secs : infill_ei
#
# Sat Oct 11 01:26:01 AM 2025 AUC 0.94118939329994
#
# [mbo] 25: num_iterations=1667; learning_rate=0.0755; num_leaves=783; max_depth=23; min_data_in_leaf=21; min_split_gain=0.21; feature_fraction=0.465; bagging_fraction=0.818; bagging_freq=5; lambda_l1=0.023; lambda_l2=1.69 : y = 0.941 : 492.4 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Sat Oct 11 01:35:53 AM 2025 AUC 0.940390258446655
#
# [mbo] 26: num_iterations=1855; learning_rate=0.073; num_leaves=796; max_depth=26; min_data_in_leaf=7; min_split_gain=0.24; feature_fraction=0.563; bagging_fraction=0.976; bagging_freq=6; lambda_l1=0.0658; lambda_l2=1.95 : y = 0.94 : 591.5 secs : infill_ei
#
# Sat Oct 11 01:41:05 AM 2025 AUC 0.941024820303016
#
# [mbo] 27: num_iterations=1367; learning_rate=0.0744; num_leaves=1487; max_depth=22; min_data_in_leaf=3; min_split_gain=0.236; feature_fraction=0.487; bagging_fraction=0.99; bagging_freq=5; lambda_l1=0.139; lambda_l2=0.684 : y = 0.941 : 311.0 secs : infill_ei
#
# Saved the current state after iteration 28 in the file bayesiana.RDATA.
#
# Sat Oct 11 01:46:16 AM 2025 AUC 0.941235661707414
#
# [mbo] 28: num_iterations=1738; learning_rate=0.0626; num_leaves=1016; max_depth=18; min_data_in_leaf=9; min_split_gain=0.203; feature_fraction=0.423; bagging_fraction=0.906; bagging_freq=3; lambda_l1=0.266; lambda_l2=0.331 : y = 0.941 : 309.9 secs : infill_ei
#
# Sat Oct 11 01:53:22 AM 2025 AUC 0.940655618155669
#
# [mbo] 29: num_iterations=1387; learning_rate=0.0657; num_leaves=1326; max_depth=20; min_data_in_leaf=1; min_split_gain=0.219; feature_fraction=0.443; bagging_fraction=0.855; bagging_freq=5; lambda_l1=0.202; lambda_l2=2.07 : y = 0.941 : 425.3 secs : infill_ei
#
# Saved the current state after iteration 30 in the file bayesiana.RDATA.
#
# Sat Oct 11 01:57:28 AM 2025 AUC 0.938170749323525
#
# [mbo] 30: num_iterations=1867; learning_rate=0.0864; num_leaves=769; max_depth=21; min_data_in_leaf=16; min_split_gain=0.159; feature_fraction=0.474; bagging_fraction=0.896; bagging_freq=3; lambda_l1=1.23; lambda_l2=0.165 : y = 0.938 : 246.0 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "num_leaves"       "max_depth"
#  [5] "min_data_in_leaf" "min_split_gain"   "feature_fraction" "bagging_fraction"
#  [9] "bagging_freq"     "lambda_l1"        "lambda_l2"        "y"
# [13] "dob"              "eol"              "error.message"    "exec.time"
# [17] "ei"               "error.model"      "train.time"       "prop.type"
# [21] "propose.time"     "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate num_leaves max_depth min_data_in_leaf
#             <int>         <num>      <int>     <int>            <int>
# 1:           1738    0.06263692       1016        18                9
#    min_split_gain feature_fraction bagging_fraction bagging_freq lambda_l1
#             <num>            <num>            <num>        <int>     <num>
# 1:      0.2026331        0.4234697        0.9057145            3 0.2657942
#    lambda_l2
#        <num>
# 1: 0.3312837
# [1] 0.9412357

# %% [markdown]
# ### 2.2.7 Testing

# %%
# Definir las 10 semillas a utilizar
semillas <- c(102191, 202111, 303131, 404243, 505357,
              606469, 707579, 808681, 909793, 1010101)

predicciones_lista <- list()

for(semilla in semillas) {

  cat("\nEntrenando con semilla:", semilla, "\n")

  # Modificar los parámetros para incluir la semilla actual
  param_test <- modifyList(PARAM$lgbm$param_fijos,
                           PARAM$out$lgbm$mejores_hiperparametros)
  param_test$seed <- semilla

  # Entrenar el modelo con la semilla actual
  modelo_test <- lgb.train(
    data = dtrain,
    param = param_test
  )

  # Preparar el dataset de predicción
  dataset_test <- dataset[foto_mes == 202104]

  # Predecir sobre el dataset de test
  prediccion_actual <- predict(
    modelo_test,
    data.matrix(dataset_test[, campos_buenos, with = FALSE])
  )

  # Guardar la predicción en la lista
  predicciones_lista[[as.character(semilla)]] <- prediccion_actual
}


predicciones_promedio <- rowMeans(as.data.table(predicciones_lista))

tb_test <- dataset_test[, .(numero_de_cliente, foto_mes)]
tb_test[, prob := predicciones_promedio] # <-- Usamos el promedio

# Inicializar realidad para test
drealidad_test <- realidad_inicializar(dataset_test, PARAM)

# Calcular ganancias usando realidad_evaluar
resultados_cortes <- data.table()
setorder(tb_test, -prob)

for(envios in PARAM$cortes) {

  tb_test[, Predicted := 0L]
  tb_test[1:envios, Predicted := 1L]

  res <- realidad_evaluar(drealidad_test, tb_test)

  resultados_cortes <- rbind(resultados_cortes,
                             data.table(
                               envios = envios,
                               ganancia_total = res$total,
                               ganancia_public = res$public,
                               ganancia_private = res$private,
                               ganancia_por_envio = res$total / envios
                             ))

  options(scipen = 999)
  cat("Envios=", envios, "\t",
      " TOTAL=", res$total,
      "  Public=", res$public,
      " Private=", res$private,
      "\n",
      sep = "")
}

cat("\nProceso finalizado. Las ganancias mostradas corresponden al promedio de 10 semillas.\n")
# Out:
# Entrenando con semilla: 102191
#
# Entrenando con semilla: 202111
#
# Entrenando con semilla: 303131
#
# Entrenando con semilla: 404243
#
# Entrenando con semilla: 505357
#
# Entrenando con semilla: 606469
#
# Entrenando con semilla: 707579
#
# Entrenando con semilla: 808681
#
# Entrenando con semilla: 909793
#
# Entrenando con semilla: 1010101
# Envios=6000	 TOTAL=337600000  Public=286133333 Private=359657143
# Envios=6500	 TOTAL=345200000  Public=290200000 Private=368771429
# Envios=7000	 TOTAL=354400000  Public=295133333 Private=379800000
# Envios=7500	 TOTAL=354000000  Public=298533333 Private=377771429
# Envios=8000	 TOTAL=362400000  Public=301666667 Private=388428571
# Envios=8500	 TOTAL=362800000  Public=299800000 Private=389800000
# Envios=9000	 TOTAL=364000000  Public=304800000 Private=389371429
# Envios=9500	 TOTAL=369200000  Public=303866667 Private=397200000
# Envios=10000	 TOTAL=368000000  Public=305333333 Private=394857143
# Envios=10500	 TOTAL=372400000  Public=308866667 Private=399628571
# Envios=11000	 TOTAL=367200000  Public=304133333 Private=394228571
# Envios=11500	 TOTAL=364400000  Public=300200000 Private=391914286
# Envios=12000	 TOTAL=365600000  Public=309333333 Private=389714286
# Envios=12500	 TOTAL=362800000  Public=309333333 Private=385714286
# Envios=13000	 TOTAL=360000000  Public=307200000 Private=382628571
# Envios=13500	 TOTAL=359600000  Public=310066667 Private=380828571
# Envios=14000	 TOTAL=359200000  Public=311000000 Private=379857143
# Envios=14500	 TOTAL=357200000  Public=317800000 Private=374085714
# Envios=15000	 TOTAL=352000000  Public=314133333 Private=368228571
# Envios=15500	 TOTAL=346800000  Public=313466667 Private=361085714
# Envios=16000	 TOTAL=344800000  Public=313466667 Private=358228571
# Envios=16500	 TOTAL=342000000  Public=315533333 Private=353342857
# Envios=17000	 TOTAL=338400000  Public=308600000 Private=351171429
# Envios=17500	 TOTAL=332400000  Public=301133333 Private=345800000
# Envios=18000	 TOTAL=324000000  Public=294266667 Private=336742857
# Envios=18500	 TOTAL=320400000  Public=290066667 Private=333400000
# Envios=19000	 TOTAL=316000000  Public=286200000 Private=328771429
#
# Proceso finalizado. Las ganancias mostradas corresponden al promedio de 10 semillas.

# %%
# Encontrar el óptimo
setorder(resultados_cortes, -ganancia_total)
optimo <- resultados_cortes[1]

cat("\n================================================\n")
cat("MEJOR PUNTO DE CORTE EN TEST (202104):\n")
cat("Envíos óptimos:", optimo$envios, "\n")
cat("Ganancia TOTAL:", optimo$ganancia_total, "\n")
cat("Ganancia PUBLIC:", optimo$ganancia_public, "\n")
cat("Ganancia PRIVATE:", optimo$ganancia_private, "\n")
cat("Ganancia por envío:", round(optimo$ganancia_por_envio, 2), "\n")
cat("================================================\n\n")
# Out:
# ================================================
# MEJOR PUNTO DE CORTE EN TEST (202104):
# Envíos óptimos: 10500
# Ganancia TOTAL: 372400000
# Ganancia PUBLIC: 308866667
# Ganancia PRIVATE: 399628571
# Ganancia por envío: 35466.67
# ================================================

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la  optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train_final]
dataset_train[,.N,clase_ternaria]
# Out:
#   clase_ternaria N
# 1 BAJA+1           3447
# 2 BAJA+2           3938
# 3 CONTINUA       642824

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 170029
#
# $max_depth
# [1] 18
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0.2657942
#
# $lambda_l2
# [1] 0.3312837
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.9057145
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 1738
#
# $learning_rate
# [1] 0.06263692
#
# $feature_fraction
# [1] 0.4234697
#
# $num_leaves
# [1] 1016
#
# $min_data_in_leaf
# [1] 9
#
# $min_split_gain
# [1] 0.2026331
#
# $bagging_freq
# [1] 3

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria y mucho menos cross validation.

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
# entreno los lightgbm
# Definir las 10 semillas a utilizar

semillas <- c(102191, 202111, 303131, 404243, 505357,
              606469, 707579, 808681, 909793, 1010101)

# Lista para guardar modelos
modelos_finales <- list()

# Entrenar un modelo por cada semilla
for(i in seq_along(semillas)) {

  semilla <- semillas[i]
  cat(sprintf("[%d/%d] Entrenando modelo con semilla: %d\n",
              i, length(semillas), semilla))

  # Modificar parámetros con la semilla actual
  param_actual <- param_normalizado
  param_actual$seed <- semilla

  # Entrenar el modelo
  modelo <- lgb.train(
    data = dtrain_final,
    param = param_actual
  )

  # Guardar en la lista
  modelos_finales[[as.character(semilla)]] <- modelo
}

cat("\n✓ Entrenamiento completado: 10 modelos entrenados\n")
# Out:
# [1/10] Entrenando modelo con semilla: 102191
# [2/10] Entrenando modelo con semilla: 202111
# [3/10] Entrenando modelo con semilla: 303131
# [4/10] Entrenando modelo con semilla: 404243
# [5/10] Entrenando modelo con semilla: 505357
# [6/10] Entrenando modelo con semilla: 606469
# [7/10] Entrenando modelo con semilla: 707579
# [8/10] Entrenando modelo con semilla: 808681
# [9/10] Entrenando modelo con semilla: 909793
# [10/10] Entrenando modelo con semilla: 1010101
#
# ✓ Entrenamiento completado: 10 modelos entrenados

# %%
# ahora imprimo la importancia de variables
tb_importancia <- as.data.table(lgb.importance(modelos_finales[[1]]))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...
lgb.save(modelos_finales[[1]], "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes %in% PARAM$future]

# Matriz de datos para predicción
datos_future <- data.matrix(dfuture[, campos_buenos, with = FALSE])

# Lista para guardar predicciones
predicciones_lista <- list()

# Predecir con cada modelo
for(i in seq_along(semillas)) {
  semilla <- semillas[i]

  prediccion <- predict(
    modelos_finales[[as.character(semilla)]],
    datos_future
  )

  predicciones_lista[[as.character(semilla)]] <- prediccion
}

# PROMEDIO DE LAS 10 PREDICCIONES
prediccion <- rowMeans(as.data.table(predicciones_lista))

# %%
# inicilizo el dataset  drealidad
drealidad <- realidad_inicializar( dfuture, PARAM)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
PARAM$cortes
# Out:
#  [1]  6000  6500  7000  7500  8000  8500  9000  9500 10000 10500 11000 11500
# [13] 12000 12500 13000 13500 14000 14500 15000 15500 16000 16500 17000 17500
# [25] 18000 18500 19000

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marco los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  res <- realidad_evaluar( drealidad, tb_prediccion)

  options(scipen = 999)
  cat( "Envios=", envios, "\t",
    " TOTAL=", res$total,
    "  Public=", res$public,
    " Private=", res$private,
    "\n",
    sep= ""
  )

}
# Out:
# Envios=6000	 TOTAL=-120000000  Public=-122800000 Private=-118800000
# Envios=6500	 TOTAL=-130000000  Public=-133000000 Private=-128714286
# Envios=7000	 TOTAL=-140000000  Public=-143266667 Private=-138600000
# Envios=7500	 TOTAL=-150000000  Public=-154800000 Private=-147942857
# Envios=8000	 TOTAL=-160000000  Public=-164133333 Private=-158228571
# Envios=8500	 TOTAL=-170000000  Public=-174333333 Private=-168142857
# Envios=9000	 TOTAL=-180000000  Public=-184533333 Private=-178057143
# Envios=9500	 TOTAL=-190000000  Public=-195000000 Private=-187857143
# Envios=10000	 TOTAL=-200000000  Public=-204133333 Private=-198228571
# Envios=10500	 TOTAL=-210000000  Public=-215000000 Private=-207857143
# Envios=11000	 TOTAL=-220000000  Public=-223333333 Private=-218571429
# Envios=11500	 TOTAL=-230000000  Public=-233800000 Private=-228371429
# Envios=12000	 TOTAL=-240000000  Public=-243866667 Private=-238342857
# Envios=12500	 TOTAL=-250000000  Public=-253000000 Private=-248714286
# Envios=13000	 TOTAL=-260000000  Public=-262666667 Private=-258857143
# Envios=13500	 TOTAL=-270000000  Public=-272333333 Private=-269000000
# Envios=14000	 TOTAL=-280000000  Public=-282733333 Private=-278828571
# Envios=14500	 TOTAL=-290000000  Public=-294066667 Private=-288257143
# Envios=15000	 TOTAL=-300000000  Public=-304200000 Private=-298200000
# Envios=15500	 TOTAL=-310000000  Public=-313066667 Private=-308685714
# Envios=16000	 TOTAL=-320000000  Public=-323000000 Private=-318714286
# Envios=16500	 TOTAL=-330000000  Public=-332933333 Private=-328742857
# Envios=17000	 TOTAL=-340000000  Public=-342733333 Private=-338828571
# Envios=17500	 TOTAL=-350000000  Public=-352466667 Private=-348942857
# Envios=18000	 TOTAL=-360000000  Public=-362066667 Private=-359114286
# Envios=18500	 TOTAL=-370000000  Public=-372466667 Private=-368942857
# Envios=19000	 TOTAL=-380000000  Public=-382733333 Private=-378828571

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Oct 11 03:40:09 AM 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
