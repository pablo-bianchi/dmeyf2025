# %% [markdown]
# ## 1 Dataset

# %% [markdown]
# ### 1.1 Feature Engineering

# %% [markdown]
# ### 1.1.1 Generacion de la clase_ternaria

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje **R** Ir al menu, Runtime -> Change Runtime Tipe -> Runtime type -> R

# %%
require( "data.table" )

# leo el dataset
dataset <- fread("/content/datasets/competencia_01_crudo.csv" )

# calculo el periodo0 consecutivo
dsimple <- dataset[, list(
    "pos" = .I,
    numero_de_cliente,
    periodo0 = as.integer(foto_mes/100)*12 +  foto_mes%%100 ) ]


# ordeno
setorder( dsimple, numero_de_cliente, periodo0 )

# calculo topes
periodo_ultimo <- dsimple[, max(periodo0) ]
periodo_anteultimo <- periodo_ultimo - 1


# calculo los leads de orden 1 y 2
dsimple[, c("periodo1", "periodo2") :=
    shift(periodo0, n=1:2, fill=NA, type="lead"),  numero_de_cliente ]

# assign most common class values = "CONTINUA"
dsimple[ periodo0 < periodo_anteultimo, clase_ternaria := "CONTINUA" ]

# calculo BAJA+1
dsimple[ periodo0 < periodo_ultimo &
    ( is.na(periodo1) | periodo0 + 1 < periodo1 ),
    clase_ternaria := "BAJA+1" ]

# calculo BAJA+2
dsimple[ periodo0 < periodo_anteultimo & (periodo0+1 == periodo1 )
    & ( is.na(periodo2) | periodo0 + 2 < periodo2 ),
    clase_ternaria := "BAJA+2" ]


# pego el resultado en el dataset original y grabo
setorder( dsimple, pos )
dataset[, clase_ternaria := dsimple$clase_ternaria ]

fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)
# Out:
# Loading required package: data.table

# %%
setorder( dataset, foto_mes, clase_ternaria, numero_de_cliente)
dataset[, .N, list(foto_mes, clase_ternaria)]
# Out:
#    foto_mes clase_ternaria N
# 1  202101   BAJA+1            622
# 2  202101   BAJA+2            825
# 3  202101   CONTINUA       160080
# 4  202102   BAJA+1            831
# 5  202102   BAJA+2           1032
# 6  202102   CONTINUA       160292
# 7  202103   BAJA+1           1039
# 8  202103   BAJA+2            951
# 9  202103   CONTINUA       161119
# 10 202104   BAJA+1            955
# 11 202104   BAJA+2           1130
# 12 202104   CONTINUA       161333
# 13 202105   NA             162783
# 14 202105   BAJA+1           1134
# 15 202106   NA             164313

# %% [markdown]
# ### 1.1.2 Datadrifting

# %% [markdown]
# #### 1.1.2.1 Tratamiento Aguinaldo

# %%
#Crear una columna temporal con el payroll TOTAL
dataset[, mpayroll_total := fcoalesce(mpayroll, 0) + fcoalesce(mpayroll2, 0)]


#Calcular meses con sueldo total en el semestre
conteo_meses_payroll <- dataset[foto_mes >= 202101 & foto_mes <= 202106,
                                .(meses_trabajados_semestre = sum(mpayroll_total > 0)),
                                by = numero_de_cliente]

#Calcular el sueldo MÁXIMO TOTAL de Enero a Mayo ---
max_payroll_previo <- dataset[foto_mes >= 202101 & foto_mes <= 202105,
                              .(max_payroll_previo = max(mpayroll_total)),
                              by = numero_de_cliente]
max_payroll_previo[is.infinite(max_payroll_previo), max_payroll_previo := 0]


#Uno al dataset
dataset[conteo_meses_payroll, on = .(numero_de_cliente), meses_trabajados_semestre := i.meses_trabajados_semestre]
dataset[max_payroll_previo, on = .(numero_de_cliente), max_payroll_previo := i.max_payroll_previo]

dataset[is.na(meses_trabajados_semestre), meses_trabajados_semestre := 0]
dataset[is.na(max_payroll_previo), max_payroll_previo := 0]


#Columnas a corregir
cols_a_corregir <- c("mpayroll",
                     "mpayroll2",
                     "mtarjeta_visa_consumo",
                     "mtarjeta_master_consumo",
                     "Visa_mconsumototal",
                     "mcaja_ahorro",
                     "mcuentas_saldo",
                     "mpagodeservicios") # La variable mpagodeservicios no estaba en el diccionario, la cambie por mservicios_pagados


#Usamos el umbral de 1.08
dataset[foto_mes == 202106 &
        meses_trabajados_semestre > 0 &
        mpayroll_total > 1.08 * max_payroll_previo,
        (cols_a_corregir) := {
          factor_ajuste <- 1 + (meses_trabajados_semestre / 12)
          lapply(.SD, function(columna) columna / factor_ajuste)
        },
        .SDcols = cols_a_corregir]


#Limpiamos columnas auxiliares
dataset[, `:=`(mpayroll_total = NULL,
               meses_trabajados_semestre = NULL,
               max_payroll_previo = NULL)]

cat("Proceso de corrección finalizado correctamente (considerando mpayroll + mpayroll2).")
# Out:
# Proceso de corrección finalizado correctamente (considerando mpayroll + mpayroll2).

# %% [markdown]
# #### 1.1.2.2 Features

# %%
dataset[, `:=`(
  # Suma de los payrolls
  ingresos_totales = fcoalesce(mpayroll, 0) + fcoalesce(mpayroll2, 0),

  # Suma de los consumos de las dos tarjetas de crédito (incluye pesos y dólares)
  mconsumo_tarjetas_totales = fcoalesce(Visa_mconsumototal, 0) + fcoalesce(Master_mconsumototal, 0),

  # Suma completa de gastos por pagos y débitos
  mgastos_totales = fcoalesce(Visa_mconsumototal, 0) + fcoalesce(Master_mconsumototal, 0) +
                    fcoalesce(mpagodeservicios, 0) +
                    fcoalesce(mcuenta_debitos_automaticos, 0),

  # Suma de todos los montos de inversión (pesos y dólares)
  minversiones_totales = fcoalesce(mplazo_fijo_pesos, 0) + fcoalesce(mplazo_fijo_dolares, 0) +
                         fcoalesce(minversion1_pesos, 0) + fcoalesce(minversion1_dolares, 0) +
                         fcoalesce(minversion2, 0)
)]


# ratios
dataset[, `:=`(
  presion_consumo = ifelse(ingresos_totales > 0, mconsumo_tarjetas_totales / ingresos_totales, 0),
  ratio_uso_limite_visa = ifelse(Visa_mlimitecompra > 0, fcoalesce(Visa_mconsumototal, 0) / Visa_mlimitecompra, 0), #mtarjeta_visa_consumo
  ratio_uso_limite_master = ifelse(Master_mlimitecompra > 0, fcoalesce(Master_mconsumototal, 0) / Master_mlimitecompra, 0), #mtarjeta_master_consumo
  ratio_uso_limite_total = ifelse((fcoalesce(Visa_mlimitecompra, 0) + fcoalesce(Master_mlimitecompra, 0)) > 0,
                                  mconsumo_tarjetas_totales /
                                  (fcoalesce(Visa_mlimitecompra, 0) + fcoalesce(Master_mlimitecompra, 0)), 0),
  ratio_inversion_saldo = ifelse(mcuentas_saldo > 0, minversiones_totales / mcuentas_saldo, 0)
)]

# conteos
dataset[, `:=`(
  total_productos = (fcoalesce(cprestamos_personales, 0L) > 0) + (fcoalesce(cprestamos_prendarios, 0L) > 0) +
                    (fcoalesce(cprestamos_hipotecarios, 0L) > 0) + (fcoalesce(cplazo_fijo, 0L) > 0) +
                    (fcoalesce(cinversion1, 0L) > 0) + (fcoalesce(cinversion2, 0L) > 0) +
                    (fcoalesce(cseguro_vida, 0L) > 0) + (fcoalesce(cseguro_auto, 0L) > 0),

  total_transacciones = fcoalesce(ctarjeta_debito_transacciones, 0L) + fcoalesce(ctarjeta_visa_transacciones, 0L) +
                        fcoalesce(ctarjeta_master_transacciones, 0L) + fcoalesce(ctransferencias_recibidas, 0L) +
                        fcoalesce(ctransferencias_emitidas, 0L) + fcoalesce(chomebanking_transacciones, 0L),

  consumo_div_edad = ifelse(cliente_edad > 0, mconsumo_tarjetas_totales / cliente_edad, 0)
)]

cat("\nFeature Engineering completo. Todas las nuevas variables han sido creadas.\n")
# Out:
# Feature Engineering completo. Todas las nuevas variables han sido creadas.

# %% [markdown]
# #### 1.1.2.3 Ranking

# %%
rank_normalizar_por_mes_monetarias <- function(p_dataset,
                                               p_eliminar_originales = FALSE) {
  columnas_monetarias <- c(
    "mrentabilidad", "mrentabilidad_annual", "mcomisiones", "mactivos_margen",
    "mpasivos_margen", "mcuenta_corriente_adicional", "mcuenta_corriente",
    "mcaja_ahorro", "mcaja_ahorro_adicional", "mcaja_ahorro_dolares",
    "mcuentas_saldo", "mautoservicio", "mtarjeta_visa_consumo",
    "mtarjeta_master_consumo", "mprestamos_personales", "mprestamos_prendarios",
    "mprestamos_hipotecarios", "mplazo_fijo_dolares", "mplazo_fijo_pesos",
    "minversion1_pesos", "minversion1_dolares", "minversion2", "mpayroll",
    "mpayroll2", "mcuenta_debitos_automaticos", "mtarjeta_visa_debitos_automaticos",
    "mttarjeta_master_debitos_automaticos", "mpagodeservicios", "mpagomiscuentas",
    "mcajeros_propios_descuentos", "mtarjeta_visa_descuentos",
    "mtarjeta_master_descuentos", "mcomisiones_mantenimiento", "mcomisiones_otras",
    "mforex_buy", "mforex_sell", "mtransferencias_recibidas", "mtransferencias_emitidas",
    "mextraccion_autoservicio", "mcheques_depositados", "mcheques_emitidos",
    "mcheques_depositados_rechazados", "mcheques_emitidos_rechazados", "matm",
    "matm_other", "Master_mfinanciacion_limite", "Master_msaldototal",
    "Master_msaldopesos", "Master_msaldodolares", "Master_mconsumospesos",
    "Master_mconsumosdolares", "Master_mlimitecompra", "Master_madelantopesos",
    "Master_madelantodolares", "Master_mpagado", "Master_mpagospesos",
    "Master_mpagosdolares", "Master_mconsumototal", "Master_mpagominimo",
    "Visa_mfinanciacion_limite", "Visa_msaldototal", "Visa_msaldopesos",
    "Visa_msaldodolares", "Visa_mconsumospesos", "Visa_mconsumosdolares",
    "Visa_mlimitecompra", "Visa_madelantopesos", "Visa_madelantodolares",
    "Visa_mpagado", "Visa_mpagospesos", "Visa_mpagosdolares", "Visa_mconsumototal",
    "Visa_mpagominimo"
  )

  columnas_a_rankear <- intersect(columnas_monetarias, names(p_dataset))

  cat("Columnas a rankear por mes:", length(columnas_a_rankear), "\n")
  if (length(columnas_a_rankear) == 0) {
    cat("Advertencia: Ninguna de las columnas monetarias especificadas se encontró en el dataset.\n")
    return(invisible(p_dataset))
  }

  for (col in columnas_a_rankear) {
    nuevo_nombre <- paste0("rank_mes_", col)

    p_dataset[, (nuevo_nombre) := {
      v <- .SD[[1]]
      r <- numeric(length(v))

      pos_idx <- which(v > 0)
      neg_idx <- which(v < 0)

      if (length(pos_idx) > 0) {
        r[pos_idx] <- frank(v[pos_idx], ties.method = "average") / length(pos_idx)
      }
      if (length(neg_idx) > 0) {
        r[neg_idx] <- -frank(-v[neg_idx], ties.method = "average") / length(neg_idx)
      }

      r[v == 0] <- 0

      max_r_pos <- max(r[pos_idx], 0, na.rm = TRUE)
      min_r_neg <- min(r[neg_idx], 0, na.rm = TRUE)

      if (max_r_pos > 0) r[pos_idx] <- r[pos_idx] / max_r_pos
      if (min_r_neg < 0) r[neg_idx] <- r[neg_idx] / abs(min_r_neg)

      .(r)
    }, by = foto_mes, .SDcols = col]
  }

  if (p_eliminar_originales) {
    p_dataset[, (columnas_a_rankear) := NULL]
  }

  invisible(p_dataset)
}

# %%
columnas_excluir <- c("numero_de_cliente", "foto_mes", "clase01",
                      "azar", "training", "partition")

dataset <- rank_normalizar_por_mes_monetarias(
  dataset,
  p_eliminar_originales = TRUE  # o FALSE según prefieras
)
# Out:
# Columnas a rankear por mes: 72

# %% [markdown]
# ### 1.1.3 Creación de lags y delta lags

# %%
max_lag <- 1

# selecciono automáticamente todas las columnas numéricas, excepto id y fecha
campos_laguear <- setdiff(
  names(dataset)[sapply(dataset, is.numeric)],
  c("numero_de_cliente", "foto_mes")
)

cat("Máximo lag posible:", max_lag, "\n")
cat("Campos a laggear:", paste(campos_laguear, collapse=", "), "\n")

# genero los lags
dataset[, paste0(rep(campos_laguear, each = max_lag), "_lag", 1:max_lag) :=
          shift(.SD, n = 1:max_lag, type = "lag"),
        by = numero_de_cliente,
        .SDcols = campos_laguear]

# genero los delta lags como var - lagX
for (campo in campos_laguear) {
  for (k in 1:max_lag) {
    dataset[, (paste0(campo, "_delta", k)) :=
              get(campo) - get(paste0(campo, "_lag", k))]
  }
}
# Out:
# Máximo lag posible: 1
# Campos a laggear: active_quarter, cliente_vip, internet, cliente_edad, cliente_antiguedad, cproductos, tcuentas, ccuenta_corriente, ccaja_ahorro, cdescubierto_preacordado, ctarjeta_debito, ctarjeta_debito_transacciones, ctarjeta_visa, ctarjeta_visa_transacciones, ctarjeta_master, ctarjeta_master_transacciones, cprestamos_personales, cprestamos_prendarios, cprestamos_hipotecarios, cplazo_fijo, cinversion1, cinversion2, cseguro_vida, cseguro_auto, cseguro_vivienda, cseguro_accidentes_personales, ccaja_seguridad, cpayroll_trx, cpayroll2_trx, ccuenta_debitos_automaticos, ctarjeta_visa_debitos_automaticos, mttarjeta_visa_debitos_automaticos, ctarjeta_master_debitos_automaticos, cpagodeservicios, cpagomiscuentas, ccajeros_propios_descuentos, ctarjeta_visa_descuentos, ctarjeta_master_descuentos, ccomisiones_mantenimiento, ccomisiones_otras, cforex, cforex_buy, cforex_sell, ctransferencias_recibidas, ctransferencias_emitidas, cextraccion_autoservicio, ccheques_depositados, ccheques_emitidos, ccheques_depositados_rechazados, ccheques_emitidos_rechazados, tcallcenter, ccallcenter_transacciones, thomebanking, chomebanking_transacciones, ccajas_transacciones, ccajas_consultas, ccajas_depositos, ccajas_extracciones, ccajas_otras, catm_trx, catm_trx_other, ctrx_quarter, tmobile_app, cmobile_app_trx, Master_delinquency, Master_status, Master_Fvencimiento, Master_Finiciomora, Master_fultimo_cierre, Master_fechaalta, Master_cconsumos, Master_cadelantosefectivo, Visa_delinquency, Visa_status, Visa_Fvencimiento, Visa_Finiciomora, Visa_fultimo_cierre, Visa_fechaalta, Visa_cconsumos, Visa_cadelantosefectivo, ingresos_totales, mconsumo_tarjetas_totales, mgastos_totales, minversiones_totales, presion_consumo, ratio_uso_limite_visa, ratio_uso_limite_master, ratio_uso_limite_total, ratio_inversion_saldo, total_productos, total_transacciones, consumo_div_edad, rank_mes_mrentabilidad, rank_mes_mrentabilidad_annual, rank_mes_mcomisiones, rank_mes_mactivos_margen, rank_mes_mpasivos_margen, rank_mes_mcuenta_corriente_adicional, rank_mes_mcuenta_corriente, rank_mes_mcaja_ahorro, rank_mes_mcaja_ahorro_adicional, rank_mes_mcaja_ahorro_dolares, rank_mes_mcuentas_saldo, rank_mes_mautoservicio, rank_mes_mtarjeta_visa_consumo, rank_mes_mtarjeta_master_consumo, rank_mes_mprestamos_personales, rank_mes_mprestamos_prendarios, rank_mes_mprestamos_hipotecarios, rank_mes_mplazo_fijo_dolares, rank_mes_mplazo_fijo_pesos, rank_mes_minversion1_pesos, rank_mes_minversion1_dolares, rank_mes_minversion2, rank_mes_mpayroll, rank_mes_mpayroll2, rank_mes_mcuenta_debitos_automaticos, rank_mes_mttarjeta_master_debitos_automaticos, rank_mes_mpagodeservicios, rank_mes_mpagomiscuentas, rank_mes_mcajeros_propios_descuentos, rank_mes_mtarjeta_visa_descuentos, rank_mes_mtarjeta_master_descuentos, rank_mes_mcomisiones_mantenimiento, rank_mes_mcomisiones_otras, rank_mes_mforex_buy, rank_mes_mforex_sell, rank_mes_mtransferencias_recibidas, rank_mes_mtransferencias_emitidas, rank_mes_mextraccion_autoservicio, rank_mes_mcheques_depositados, rank_mes_mcheques_emitidos, rank_mes_mcheques_depositados_rechazados, rank_mes_mcheques_emitidos_rechazados, rank_mes_matm, rank_mes_matm_other, rank_mes_Master_mfinanciacion_limite, rank_mes_Master_msaldototal, rank_mes_Master_msaldopesos, rank_mes_Master_msaldodolares, rank_mes_Master_mconsumospesos, rank_mes_Master_mconsumosdolares, rank_mes_Master_mlimitecompra, rank_mes_Master_madelantopesos, rank_mes_Master_madelantodolares, rank_mes_Master_mpagado, rank_mes_Master_mpagospesos, rank_mes_Master_mpagosdolares, rank_mes_Master_mconsumototal, rank_mes_Master_mpagominimo, rank_mes_Visa_mfinanciacion_limite, rank_mes_Visa_msaldototal, rank_mes_Visa_msaldopesos, rank_mes_Visa_msaldodolares, rank_mes_Visa_mconsumospesos, rank_mes_Visa_mconsumosdolares, rank_mes_Visa_mlimitecompra, rank_mes_Visa_madelantopesos, rank_mes_Visa_madelantodolares, rank_mes_Visa_mpagado, rank_mes_Visa_mpagospesos, rank_mes_Visa_mpagosdolares, rank_mes_Visa_mconsumototal, rank_mes_ ...

# %%
fwrite( dataset,
    file =  "/content/datasets/competencia_01.csv.gz",
    sep = ","
)

# %% [markdown]
# ### 2.2 Optimizacion Hiperparámetros

# %% [markdown]
# Esta parte se debe correr con el runtime en lenguaje R Ir al menu, Runtime -> Change Runtime Type -> Runtime type -> R

# %% [markdown]
# ### 2.2.1 Inicio

# %% [markdown]
# limpio el ambiente de R

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sat Oct 11 22:41:46 2025"

# %%
# limpio la memoria
rm(list=ls(all.names=TRUE)) # remove all objects
gc(full=TRUE, verbose=FALSE) # garbage collection
# Out:
#        used    (Mb) gc trigger (Mb)   max used  (Mb)
# Ncells  735183 39.3   1454697    77.7   1454697   77.7
# Vcells 1397451 10.7 422281817  3221.8 371711721 2836.0

# %% [markdown]
# ### 2.2.2 Carga de Librerias

# %% [markdown]
# Esta parte lleva varios minutos la primera vez en Google Colab

# %%
# cargo las librerias que necesito
require("data.table")
require("parallel")

if(!require("R.utils")) install.packages("R.utils")
require("R.utils")

if( !require("primes") ) install.packages("primes")
require("primes")

if( !require("utils") ) install.packages("utils")
require("utils")

if( !require("rlist") ) install.packages("rlist")
require("rlist")

if( !require("yaml")) install.packages("yaml")
require("yaml")

if( !require("lightgbm") ) install.packages("lightgbm")
require("lightgbm")

if( !require("DiceKriging") ) install.packages("DiceKriging")
require("DiceKriging")

if( !require("mlrMBO") ) install.packages("mlrMBO")
require("mlrMBO")
# Out:
# Loading required package: parallel
#
# Loading required package: R.utils
#
# Loading required package: R.oo
#
# Loading required package: R.methodsS3
#
# R.methodsS3 v1.8.2 (2022-06-13 22:00:14 UTC) successfully loaded. See ?R.methodsS3 for help.
#
# R.oo v1.27.1 (2025-05-02 21:00:05 UTC) successfully loaded. See ?R.oo for help.
#
#
# Attaching package: ‘R.oo’
#
#
# The following object is masked from ‘package:R.methodsS3’:
#
#     throw
#
#
# The following objects are masked from ‘package:methods’:
#
#     getClasses, getMethods
#
#
# The following objects are masked from ‘package:base’:
#
#     attach, detach, load, save
#
#
# R.utils v2.13.0 (2025-02-24 21:20:02 UTC) successfully loaded. See ?R.utils for help.
#
#
# Attaching package: ‘R.utils’
#
#
# The following object is masked from ‘package:utils’:
#
#     timestamp
#
#
# The following objects are masked from ‘package:base’:
#
#     cat, commandArgs, getOption, isOpen, nullfile, parse, use, warnings
#
#
# Loading required package: primes
#
# Loading required package: rlist
#
# Loading required package: yaml
#
# Loading required package: lightgbm
#
# Loading required package: DiceKriging
#
# Loading required package: mlrMBO
#
# Loading required package: mlr
#
# Loading required package: ParamHelpers
#
#
# Attaching package: ‘ParamHelpers’
#
#
# The following object is masked from ‘package:R.utils’:
#
#     isVector
#
#
#
# Attaching package: ‘mlr’
#
#
# The following objects are masked from ‘package:R.utils’:
#
#     resample, setThreshold
#
#
# Loading required package: smoof
#
# Loading required package: checkmate
#
#
# Attaching package: ‘checkmate’
#
#
# The following object is masked from ‘package:DiceKriging’:
#
#     checkNames
#
#
# The following object is masked from ‘package:R.utils’:
#
#     asInt
#
#
#
# Attaching package: ‘smoof’
#
#
# The following objects are masked from ‘package:R.oo’:
#
#     getDescription, getName

# %% [markdown]
# ### 2.2.3 Definicion de Parametros

# %% [markdown]
# aqui debe cargar SU semilla primigenia
# <br>recuerde cambiar el numero de experimento en cada corrida nueva

# %% [markdown]
# #### Nombre experimento y semilla

# %%
PARAM <- list()
PARAM$experimento <- 'C01-41-g'
PARAM$semilla_primigenia <- 170029

# %% [markdown]
# #### Seteo meses

# %%
# training y future
PARAM$train <- c(202101, 202102)  # Para BO
PARAM$train_final <- c(202101, 202102, 202103, 202104)  # Para modelo final
PARAM$future <- c(202106)  # CAMBIO PRINCIPAL
PARAM$test <- c(202104)  # Nuevo: para validar hiperparámetros
PARAM$semilla_kaggle <- 314159
PARAM$cortes <- seq(6000, 19000, by= 500)

# %% [markdown]
# #### Undersampling

# %%
# un undersampling de 0.1  toma solo el 10% de los CONTINUA
# undersampling de 1.0  implica tomar TODOS los datos

PARAM$trainingstrategy$undersampling <- 0.1

# %%
# Parametros LightGBM

PARAM$hyperparametertuning$xval_folds <- 5

# parametros fijos del LightGBM que se pisaran con la parte variable de la BO
PARAM$lgbm$param_fijos <-  list(
  boosting= "gbdt", # puede ir  dart  , ni pruebe random_forest
  objective= "binary",
  metric= "auc",
  first_metric_only= FALSE,
  boost_from_average= TRUE,
  feature_pre_filter= FALSE,
  force_row_wise= TRUE, # para reducir warnings
  verbosity= -100,

  seed= PARAM$semilla_primigenia,

  max_depth= -1L, # -1 significa no limitar,  por ahora lo dejo fijo
  min_gain_to_split= 0, # min_gain_to_split >= 0
  min_sum_hessian_in_leaf= 0.001, #  min_sum_hessian_in_leaf >= 0.0
  lambda_l1= 0.0, # lambda_l1 >= 0.0
  lambda_l2= 0.0, # lambda_l2 >= 0.0
  max_bin= 31L, # lo debo dejar fijo, no participa de la BO

  bagging_fraction= 1.0, # 0.0 < bagging_fraction <= 1.0
  pos_bagging_fraction= 1.0, # 0.0 < pos_bagging_fraction <= 1.0
  neg_bagging_fraction= 1.0, # 0.0 < neg_bagging_fraction <= 1.0
  is_unbalance= FALSE, #
  scale_pos_weight= 1.0, # scale_pos_weight > 0.0

  drop_rate= 0.1, # 0.0 < neg_bagging_fraction <= 1.0
  max_drop= 50, # <=0 means no limit
  skip_drop= 0.5, # 0.0 <= skip_drop <= 1.0

  extra_trees= FALSE,

  num_iterations= 1200,
  learning_rate= 0.02,
  feature_fraction= 0.5,
  num_leaves= 750,
  min_data_in_leaf= 5000
)

# %% [markdown]
# Aqui se definen los hiperparámetros de LightGBM que participan de la Bayesian Optimization
# <br> si es un numero entero debe ir  makeIntegerParam
# <br> si es un numero real (con decimales) debe ir  makeNumericParam
# <br> es muy importante leer cuales son un lower y upper  permitidos y ademas razonables

# %%
# Aqui se cargan los bordes de los hiperparametros de la BO
PARAM$hypeparametertuning$hs <- makeParamSet(
  # Iteraciones / tasa de aprendizaje
  makeIntegerParam("num_iterations", lower = 400L, upper = 2448L),
  makeNumericParam("learning_rate", lower = 0.005, upper = 0.3),

  # Complejidad del árbol
  makeIntegerParam("num_leaves", lower = 8L, upper = 2048L),
  makeIntegerParam("max_depth", lower = -1L, upper = 30L),
  makeIntegerParam("min_data_in_leaf", lower = 1L, upper = 6000L),
  makeNumericParam("min_split_gain", lower = 0.0, upper = 0.3),

  # Submuestreo de features y filas
  makeNumericParam("feature_fraction", lower = 0.1, upper = 1.0),
  makeNumericParam("bagging_fraction", lower = 0.5, upper = 1.0),
  makeIntegerParam("bagging_freq", lower = 1L, upper = 10L),

  # Regularización L1/L2
  makeNumericParam("lambda_l1", lower = 0.0, upper = 7.0),
  makeNumericParam("lambda_l2", lower = 0.0, upper = 5.0)


)

# %% [markdown]
# A mayor cantidad de hiperparámetros, se debe aumentar las iteraciones de la Bayesian Optimization
# <br> 30 es un valor muy tacaño, pero corre rápido
# <br> deberia partir de 50, alcanzando los 100 si se dispone de tiempo

# %%
PARAM$hyperparametertuning$iteraciones <- 100 # iteraciones bayesianas

# %%
# particionar agrega una columna llamada fold a un dataset
#   que consiste en una particion estratificada segun agrupa
# particionar( data=dataset, division=c(70,30),
#  agrupa=clase_ternaria, seed=semilla)   crea una particion 70, 30

particionar <- function(data, division, agrupa= "", campo= "fold", start= 1, seed= NA) {
  if (!is.na(seed)) set.seed(seed, "L'Ecuyer-CMRG")

  bloque <- unlist(mapply(
    function(x, y) {rep(y, x)},division, seq(from= start, length.out= length(division))))

  data[, (campo) := sample(rep(bloque,ceiling(.N / length(bloque))))[1:.N],by= agrupa]
}

# %%
# iniciliazo el dataset de realidad, para medir ganancia
realidad_inicializar <- function( pfuture, pparam) {

  # datos para verificar la ganancia
  drealidad <- pfuture[, list(numero_de_cliente, foto_mes, clase_ternaria)]

  particionar(drealidad,
    division= c(3, 7),
    agrupa= "clase_ternaria",
    seed= PARAM$semilla_kaggle
  )

  return( drealidad )
}

# %%
# evaluo ganancia en los datos de la realidad

realidad_evaluar <- function( prealidad, pprediccion) {

  prealidad[ pprediccion,
    on= c("numero_de_cliente", "foto_mes"),
    predicted:= i.Predicted
  ]

  tbl <- prealidad[, list("qty"=.N), list(fold, predicted, clase_ternaria)]

  res <- list()
  res$public  <- tbl[fold==1 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.3
  res$private <- tbl[fold==2 & predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]/0.7
  res$total <- tbl[predicted==1L, sum(qty*ifelse(clase_ternaria=="BAJA+2", 780000, -20000))]

  prealidad[, predicted:=NULL]
  return( res )
}

# %% [markdown]
# ### 2.2.4  Preprocesamiento

# %%
# carpeta de trabajo

setwd("/content/buckets/b1/exp")
experimento_folder <- paste0("HT", PARAM$experimento)
dir.create(experimento_folder, showWarnings=FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento_folder ))

# %%
# lectura del dataset
dataset <- fread("/content/datasets/competencia_01.csv.gz", stringsAsFactors= TRUE)

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train]

# %%
# paso la clase a binaria que tome valores {0,1}  enteros
#  BAJA+1 y BAJA+2  son  1,   CONTINUA es 0
#  a partir de ahora ya NO puedo cortar  por prob(BAJA+2) > 1/40

dataset_train[,
  clase01 := ifelse(clase_ternaria %in% c("BAJA+2","BAJA+1"), 1L, 0L)
]

# %%
# defino los datos que forma parte del training
# aqui se hace el undersampling de los CONTINUA
# notar que para esto utilizo la SEGUNDA semilla

set.seed(PARAM$semilla_primigenia, kind = "L'Ecuyer-CMRG")
dataset_train[, azar := runif(nrow(dataset_train))]
dataset_train[, training := 0L]

dataset_train[
  foto_mes %in%  PARAM$train &
    (azar <= PARAM$trainingstrategy$undersampling | clase_ternaria %in% c("BAJA+1", "BAJA+2")),
  training := 1L
]

# %%
# los campos que se van a utilizar

campos_buenos <- setdiff(
  colnames(dataset_train),
  c("clase_ternaria", "clase01", "azar", "training")
)

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain <- lgb.Dataset(
  data= data.matrix(dataset_train[training == 1L, campos_buenos, with= FALSE]),
  label= dataset_train[training == 1L, clase01],
  free_raw_data= FALSE
)

nrow(dtrain)
ncol(dtrain)
# Out:
# [1] 35161
# [1] 494

# %% [markdown]
# ### 2.2.5 Configuracion Bayesian Optimization

# %%
# En el argumento x llegan los parmaetros de la bayesiana
#  devuelve la AUC en cross validation del modelo entrenado

EstimarGanancia_AUC_lightgbm <- function(x) {

  # x pisa (o agrega) a param_fijos
  param_completo <- modifyList(PARAM$lgbm$param_fijos, x)

  # entreno LightGBM
  modelocv <- lgb.cv(
    data= dtrain,
    nfold= PARAM$hyperparametertuning$xval_folds,
    stratified= TRUE,
    param= param_completo
  )

  # obtengo la ganancia
  AUC <- modelocv$best_score

  # hago espacio en la memoria
  rm(modelocv)
  gc(full= TRUE, verbose= FALSE)

  message(format(Sys.time(), "%a %b %d %X %Y"), " AUC ", AUC)

  return(AUC)
}

# %%
# Aqui comienza la configuracion de la Bayesian Optimization

# en este archivo quedan la evolucion binaria de la BO
kbayesiana <- "bayesiana.RDATA"

funcion_optimizar <- EstimarGanancia_AUC_lightgbm # la funcion que voy a maximizar

configureMlr(show.learner.output= FALSE)

# configuro la busqueda bayesiana,  los hiperparametros que se van a optimizar
# por favor, no desesperarse por lo complejo

obj.fun <- makeSingleObjectiveFunction(
  fn= funcion_optimizar, # la funcion que voy a maximizar
  minimize= FALSE, # estoy Maximizando la ganancia
  noisy= TRUE,
  par.set= PARAM$hypeparametertuning$hs, # definido al comienzo del programa
  has.simple.signature= FALSE # paso los parametros en una lista
)

# cada 600 segundos guardo el resultado intermedio
ctrl <- makeMBOControl(
  save.on.disk.at.time= 600, # se graba cada 600 segundos
  save.file.path= kbayesiana
) # se graba cada 600 segundos

# indico la cantidad de iteraciones que va a tener la Bayesian Optimization
ctrl <- setMBOControlTermination(
  ctrl,
  iters= PARAM$hyperparametertuning$iteraciones
) # cantidad de iteraciones

# defino el método estandar para la creacion de los puntos iniciales,
# los "No Inteligentes"
ctrl <- setMBOControlInfill(ctrl, crit= makeMBOInfillCritEI())

# establezco la funcion que busca el maximo
surr.km <- makeLearner(
  "regr.km",
  predict.type= "se",
  covtype= "matern3_2",
  control= list(trace= TRUE)
)

# %% [markdown]
# ### 2.2.6 Corrida Bayesian Optimization

# %%
set.seed(PARAM$semilla_primigenia)
# inicio la optimizacion bayesiana, retomando si ya existe
# es la celda mas lenta de todo el notebook

if (!file.exists(kbayesiana)) {
  bayesiana_salida <- mbo(obj.fun, learner= surr.km, control= ctrl)
} else {
  bayesiana_salida <- mboContinue(kbayesiana) # retomo en caso que ya exista
}
# Out:
# Sat Oct 11 22:43:21 2025 AUC 0.932137440626148
#
# [mbo] 1: num_iterations=1095; learning_rate=0.11; num_leaves=803; max_depth=3; min_data_in_leaf=3; min_split_gain=0.233; feature_fraction=0.818; bagging_fraction=0.889; bagging_freq=5; lambda_l1=6.27; lambda_l2=2.26 : y = 0.932 : 54.4 secs : infill_ei
#
# Saved the current state after iteration 2 in the file bayesiana.RDATA.
#
# Sat Oct 11 22:45:15 2025 AUC 0.932598813881851
#
# [mbo] 2: num_iterations=819; learning_rate=0.116; num_leaves=1226; max_depth=19; min_data_in_leaf=1; min_split_gain=0.205; feature_fraction=0.414; bagging_fraction=0.884; bagging_freq=5; lambda_l1=6.71; lambda_l2=4.64 : y = 0.933 : 110.6 secs : infill_ei
#
# Sat Oct 11 22:47:40 2025 AUC 0.932576318451268
#
# [mbo] 3: num_iterations=1217; learning_rate=0.114; num_leaves=1079; max_depth=11; min_data_in_leaf=153; min_split_gain=0.23; feature_fraction=0.346; bagging_fraction=0.838; bagging_freq=7; lambda_l1=5.65; lambda_l2=3.21 : y = 0.933 : 144.0 secs : infill_ei
#
# Sat Oct 11 22:49:04 2025 AUC 0.931318496777941
#
# [mbo] 4: num_iterations=818; learning_rate=0.117; num_leaves=1083; max_depth=8; min_data_in_leaf=210; min_split_gain=0.222; feature_fraction=0.233; bagging_fraction=0.888; bagging_freq=4; lambda_l1=5.83; lambda_l2=3.34 : y = 0.931 : 81.7 secs : infill_ei
#
# Sat Oct 11 22:52:20 2025 AUC 0.933109700932636
#
# [mbo] 5: num_iterations=1306; learning_rate=0.0952; num_leaves=1302; max_depth=19; min_data_in_leaf=3; min_split_gain=0.228; feature_fraction=0.54; bagging_fraction=0.815; bagging_freq=6; lambda_l1=6.81; lambda_l2=1.92 : y = 0.933 : 194.4 secs : infill_ei
#
# Sat Oct 11 22:54:08 2025 AUC 0.932322977329914
#
# [mbo] 6: num_iterations=772; learning_rate=0.098; num_leaves=1140; max_depth=21; min_data_in_leaf=7; min_split_gain=0.247; feature_fraction=0.436; bagging_fraction=0.862; bagging_freq=9; lambda_l1=6.6; lambda_l2=1.2 : y = 0.932 : 106.3 secs : infill_ei
#
# Saved the current state after iteration 7 in the file bayesiana.RDATA.
#
# Sat Oct 11 22:55:58 2025 AUC 0.932649802396715
#
# [mbo] 7: num_iterations=1443; learning_rate=0.0814; num_leaves=933; max_depth=20; min_data_in_leaf=4; min_split_gain=0.197; feature_fraction=0.895; bagging_fraction=0.787; bagging_freq=6; lambda_l1=6.18; lambda_l2=4.27 : y = 0.933 : 106.6 secs : infill_ei
#
# Sat Oct 11 22:59:59 2025 AUC 0.931615355399535
#
# [mbo] 8: num_iterations=1825; learning_rate=0.0801; num_leaves=870; max_depth=12; min_data_in_leaf=7; min_split_gain=0.117; feature_fraction=0.485; bagging_fraction=0.76; bagging_freq=7; lambda_l1=7; lambda_l2=4.76 : y = 0.932 : 239.0 secs : infill_ei
#
# Sat Oct 11 23:01:33 2025 AUC 0.932574735354613
#
# [mbo] 9: num_iterations=1181; learning_rate=0.118; num_leaves=1324; max_depth=25; min_data_in_leaf=12; min_split_gain=0.269; feature_fraction=0.69; bagging_fraction=0.853; bagging_freq=5; lambda_l1=5.64; lambda_l2=4.07 : y = 0.933 : 92.1 secs : infill_ei
#
# Sat Oct 11 23:03:51 2025 AUC 0.931896586884276
#
# [mbo] 10: num_iterations=1567; learning_rate=0.0849; num_leaves=1158; max_depth=18; min_data_in_leaf=326; min_split_gain=0.192; feature_fraction=0.676; bagging_fraction=0.854; bagging_freq=6; lambda_l1=6.39; lambda_l2=1.16 : y = 0.932 : 136.1 secs : infill_ei
#
# Sat Oct 11 23:04:55 2025 AUC 0.933063970657901
#
# [mbo] 11: num_iterations=430; learning_rate=0.0861; num_leaves=1000; max_depth=16; min_data_in_leaf=10; min_split_gain=0.228; feature_fraction=0.663; bagging_fraction=0.829; bagging_freq=7; lambda_l1=6.9; lambda_l2=4.44 : y = 0.933 : 62.0 secs : infill_ei
#
# Saved the current state after iteration 12 in the file bayesiana.RDATA.
#
# Sat Oct 11 23:06:20 2025 AUC 0.932952223470797
#
# [mbo] 12: num_iterations=736; learning_rate=0.101; num_leaves=1124; max_depth=11; min_data_in_leaf=6; min_split_gain=0.262; feature_fraction=0.951; bagging_fraction=0.829; bagging_freq=7; lambda_l1=4.66; lambda_l2=3.07 : y = 0.933 : 81.4 secs : infill_ei
#
# Sat Oct 11 23:08:50 2025 AUC 0.933207034037428
#
# [mbo] 13: num_iterations=898; learning_rate=0.0731; num_leaves=1208; max_depth=17; min_data_in_leaf=8; min_split_gain=0.289; feature_fraction=0.544; bagging_fraction=0.822; bagging_freq=6; lambda_l1=5.89; lambda_l2=2.94 : y = 0.933 : 148.0 secs : infill_ei
#
# Sat Oct 11 23:09:51 2025 AUC 0.93223239083372
#
# [mbo] 14: num_iterations=831; learning_rate=0.123; num_leaves=897; max_depth=12; min_data_in_leaf=2; min_split_gain=0.0252; feature_fraction=0.875; bagging_fraction=0.807; bagging_freq=7; lambda_l1=6.8; lambda_l2=3.89 : y = 0.932 : 59.0 secs : infill_ei
#
# Sat Oct 11 23:11:27 2025 AUC 0.932520360398683
#
# [mbo] 15: num_iterations=980; learning_rate=0.0944; num_leaves=1101; max_depth=17; min_data_in_leaf=2; min_split_gain=0.208; feature_fraction=0.685; bagging_fraction=0.781; bagging_freq=7; lambda_l1=6.74; lambda_l2=3.24 : y = 0.933 : 94.4 secs : infill_ei
#
# Sat Oct 11 23:14:21 2025 AUC 0.932696072696756
#
# [mbo] 16: num_iterations=1367; learning_rate=0.0805; num_leaves=1386; max_depth=9; min_data_in_leaf=6; min_split_gain=0.282; feature_fraction=0.374; bagging_fraction=0.808; bagging_freq=6; lambda_l1=4.8; lambda_l2=1.21 : y = 0.933 : 172.1 secs : infill_ei
#
# Sat Oct 11 23:16:03 2025 AUC 0.934630132881527
#
# [mbo] 17: num_iterations=478; learning_rate=0.058; num_leaves=969; max_depth=23; min_data_in_leaf=7; min_split_gain=0.256; feature_fraction=0.529; bagging_fraction=0.898; bagging_freq=7; lambda_l1=4.58; lambda_l2=4.84 : y = 0.935 : 99.6 secs : infill_ei
#
# Saved the current state after iteration 18 in the file bayesiana.RDATA.
#
# Sat Oct 11 23:18:10 2025 AUC 0.933697960537449
#
# [mbo] 18: num_iterations=893; learning_rate=0.0428; num_leaves=882; max_depth=28; min_data_in_leaf=3; min_split_gain=0.251; feature_fraction=0.166; bagging_fraction=0.974; bagging_freq=7; lambda_l1=3.33; lambda_l2=4.57 : y = 0.934 : 123.2 secs : infill_ei
#
# Sat Oct 11 23:21:30 2025 AUC 0.935052410182558
#
# [mbo] 19: num_iterations=625; learning_rate=0.0242; num_leaves=624; max_depth=27; min_data_in_leaf=3; min_split_gain=0.251; feature_fraction=0.543; bagging_fraction=0.923; bagging_freq=7; lambda_l1=2.73; lambda_l2=4.58 : y = 0.935 : 198.5 secs : infill_ei
#
# Sat Oct 11 23:23:42 2025 AUC 0.935955712992056
#
# [mbo] 20: num_iterations=402; learning_rate=0.0479; num_leaves=768; max_depth=25; min_data_in_leaf=7; min_split_gain=0.299; feature_fraction=0.42; bagging_fraction=0.945; bagging_freq=6; lambda_l1=0.472; lambda_l2=4.59 : y = 0.936 : 129.4 secs : infill_ei
#
# Sat Oct 11 23:26:01 2025 AUC 0.932210892241185
#
# [mbo] 21: num_iterations=489; learning_rate=0.01; num_leaves=1747; max_depth=25; min_data_in_leaf=4; min_split_gain=0.299; feature_fraction=0.211; bagging_fraction=0.891; bagging_freq=7; lambda_l1=0.451; lambda_l2=4.79 : y = 0.932 : 137.0 secs : infill_ei
#
# Sat Oct 11 23:28:24 2025 AUC 0.936188859922833
#
# [mbo] 22: num_iterations=475; learning_rate=0.0679; num_leaves=469; max_depth=24; min_data_in_leaf=5; min_split_gain=0.196; feature_fraction=0.538; bagging_fraction=0.972; bagging_freq=6; lambda_l1=0.688; lambda_l2=3.36 : y = 0.936 : 140.5 secs : infill_ei
#
# Saved the current state after iteration 23 in the file bayesiana.RDATA.
#
# Sat Oct 11 23:34:05 2025 AUC 0.937012669881819
#
# [mbo] 23: num_iterations=978; learning_rate=0.0622; num_leaves=409; max_depth=22; min_data_in_leaf=2; min_split_gain=0.265; feature_fraction=0.521; bagging_fraction=0.958; bagging_freq=6; lambda_l1=0.138; lambda_l2=4.28 : y = 0.937 : 337.1 secs : infill_ei
#
# Sat Oct 11 23:36:08 2025 AUC 0.935336066534228
#
# [mbo] 24: num_iterations=1533; learning_rate=0.0616; num_leaves=19; max_depth=21; min_data_in_leaf=4; min_split_gain=0.266; feature_fraction=0.775; bagging_fraction=0.985; bagging_freq=6; lambda_l1=0.63; lambda_l2=2.69 : y = 0.935 : 120.5 secs : infill_ei
#
# Sat Oct 11 23:38:33 2025 AUC 0.934971357991477
#
# [mbo] 25: num_iterations=957; learning_rate=0.0523; num_leaves=77; max_depth=22; min_data_in_leaf=5; min_split_gain=0.0745; feature_fraction=0.299; bagging_fraction=0.879; bagging_freq=7; lambda_l1=0.354; lambda_l2=3.38 : y = 0.935 : 143.1 secs : infill_ei
#
# Saved the current state after iteration 26 in the file bayesiana.RDATA.
#
# Sat Oct 11 23:42:03 2025 AUC 0.937710880334025
#
# [mbo] 26: num_iterations=643; learning_rate=0.0588; num_leaves=250; max_depth=14; min_data_in_leaf=2; min_split_gain=0.248; feature_fraction=0.533; bagging_fraction=0.957; bagging_freq=5; lambda_l1=0.214; lambda_l2=4.84 : y = 0.938 : 206.1 secs : infill_ei
#
# Sat Oct 11 23:43:52 2025 AUC 0.934261710410666
#
# [mbo] 27: num_iterations=842; learning_rate=0.0355; num_leaves=33; max_depth=12; min_data_in_leaf=8; min_split_gain=0.288; feature_fraction=0.341; bagging_fraction=0.982; bagging_freq=3; lambda_l1=0.0288; lambda_l2=0.769 : y = 0.934 : 106.7 secs : infill_ei
#
# Sat Oct 11 23:46:48 2025 AUC 0.936643477641969
#
# [mbo] 28: num_iterations=597; learning_rate=0.0645; num_leaves=435; max_depth=18; min_data_in_leaf=27; min_split_gain=0.245; feature_fraction=0.872; bagging_fraction=0.997; bagging_freq=7; lambda_l1=0.0461; lambda_l2=4.93 : y = 0.937 : 174.2 secs : infill_ei
#
# Sat Oct 11 23:48:00 2025 AUC 0.934219923636744
#
# [mbo] 29: num_iterations=475; learning_rate=0.0481; num_leaves=52; max_depth=14; min_data_in_leaf=10; min_split_gain=0.271; feature_fraction=0.382; bagging_fraction=0.967; bagging_freq=7; lambda_l1=0.0468; lambda_l2=3.88 : y = 0.934 : 70.1 secs : infill_ei
#
# Sat Oct 11 23:51:12 2025 AUC 0.93557958046584
#
# [mbo] 30: num_iterations=1153; learning_rate=0.0492; num_leaves=135; max_depth=16; min_data_in_leaf=8; min_split_gain=0.192; feature_fraction=0.818; bagging_fraction=0.956; bagging_freq=4; lambda_l1=1.78; lambda_l2=4.79 : y = 0.936 : 188.8 secs : infill_ei
#
# Saved the current state after iteration 31 in the file bayesiana.RDATA.
#
# Sat Oct 11 23:58:35 2025 AUC 0.937624183791183
#
# [mbo] 31: num_iterations=1452; learning_rate=0.0537; num_leaves=464; max_depth=11; min_data_in_leaf=2; min_split_gain=0.225; feature_fraction=0.581; bagging_fraction=0.866; bagging_freq=5; lambda_l1=0.0128; lambda_l2=1.52 : y = 0.938 : 439.2 secs : infill_ei
#
# Sun Oct 12 00:05:43 2025 AUC 0.934534570891367
#
# [mbo] 32: num_iterations=2065; learning_rate=0.0499; num_leaves=433; max_depth=14; min_data_in_leaf=6; min_split_gain=0.172; feature_fraction=0.369; bagging_fraction=0.857; bagging_freq=5; lambda_l1=0.151; lambda_l2=2.31 : y = 0.935 : 426.0 secs : infill_ei
#
# Saved the current state after iteration 33 in the file bayesiana.RDATA.
#
# Sun Oct 12 00:09:54 2025 AUC 0.93555483182842
#
# [mbo] 33: num_iterations=1259; learning_rate=0.0661; num_leaves=336; max_depth=0; min_data_in_leaf=12; min_split_gain=0.298; feature_fraction=0.957; bagging_fraction=0.766; bagging_freq=4; lambda_l1=0.0928; lambda_l2=0.589 : y = 0.936 : 246.8 secs : infill_ei
#
# Sun Oct 12 00:10:28 2025 AUC 0.931827427908256
#
# [mbo] 34: num_iterations=752; learning_rate=0.0672; num_leaves=346; max_depth=3; min_data_in_leaf=2; min_split_gain=0.239; feature_fraction=0.712; bagging_fraction=0.867; bagging_freq=5; lambda_l1=0.195; lambda_l2=4.49 : y = 0.932 : 31.9 secs : infill_ei
#
# Sun Oct 12 00:17:28 2025 AUC 0.938390730127207
#
# [mbo] 35: num_iterations=1132; learning_rate=0.065; num_leaves=929; max_depth=13; min_data_in_leaf=2; min_split_gain=0.151; feature_fraction=0.937; bagging_fraction=0.942; bagging_freq=6; lambda_l1=0.0257; lambda_l2=1.16 : y = 0.938 : 417.1 secs : infill_ei
#
# Saved the current state after iteration 36 in the file bayesiana.RDATA.
#
# Sun Oct 12 00:22:02 2025 AUC 0.935830294028243
#
# [mbo] 36: num_iterations=1049; learning_rate=0.00587; num_leaves=237; max_depth=16; min_data_in_leaf=20; min_split_gain=0.137; feature_fraction=0.992; bagging_fraction=0.767; bagging_freq=5; lambda_l1=0.132; lambda_l2=0.926 : y = 0.936 : 269.7 secs : infill_ei
#
# Sun Oct 12 00:23:45 2025 AUC 0.93580396528221
#
# [mbo] 37: num_iterations=729; learning_rate=0.174; num_leaves=635; max_depth=12; min_data_in_leaf=4; min_split_gain=0.17; feature_fraction=0.733; bagging_fraction=0.958; bagging_freq=5; lambda_l1=0.13; lambda_l2=0.811 : y = 0.936 : 100.3 secs : infill_ei
#
# Sun Oct 12 00:33:23 2025 AUC 0.93807334438805
#
# [mbo] 38: num_iterations=1175; learning_rate=0.0262; num_leaves=742; max_depth=14; min_data_in_leaf=1; min_split_gain=0.0258; feature_fraction=0.856; bagging_fraction=0.998; bagging_freq=5; lambda_l1=0.0358; lambda_l2=1.72 : y = 0.938 : 575.6 secs : infill_ei
#
# Saved the current state after iteration 39 in the file bayesiana.RDATA.
#
# Sun Oct 12 00:36:55 2025 AUC 0.936711996006807
#
# [mbo] 39: num_iterations=1528; learning_rate=0.0627; num_leaves=835; max_depth=8; min_data_in_leaf=5; min_split_gain=0.0853; feature_fraction=0.908; bagging_fraction=0.948; bagging_freq=4; lambda_l1=0.16; lambda_l2=0.308 : y = 0.937 : 208.1 secs : infill_ei
#
# Sun Oct 12 00:42:19 2025 AUC 0.936947254627232
#
# [mbo] 40: num_iterations=1341; learning_rate=0.0541; num_leaves=809; max_depth=14; min_data_in_leaf=3; min_split_gain=0.254; feature_fraction=0.969; bagging_fraction=0.963; bagging_freq=5; lambda_l1=0.155; lambda_l2=0.988 : y = 0.937 : 320.9 secs : infill_ei
#
# Sun Oct 12 00:48:44 2025 AUC 0.938120201165091
#
# [mbo] 41: num_iterations=1251; learning_rate=0.0641; num_leaves=383; max_depth=12; min_data_in_leaf=2; min_split_gain=0.0736; feature_fraction=0.903; bagging_fraction=0.901; bagging_freq=6; lambda_l1=0.0325; lambda_l2=2.23 : y = 0.938 : 381.7 secs : infill_ei
#
# Saved the current state after iteration 42 in the file bayesiana.RDATA.
#
# Sun Oct 12 00:51:54 2025 AUC 0.937638220658464
#
# [mbo] 42: num_iterations=707; learning_rate=0.0374; num_leaves=779; max_depth=12; min_data_in_leaf=8; min_split_gain=0.2; feature_fraction=0.643; bagging_fraction=0.881; bagging_freq=6; lambda_l1=0.058; lambda_l2=1.57 : y = 0.938 : 186.3 secs : infill_ei
#
# Sun Oct 12 00:57:08 2025 AUC 0.9369111672102
#
# [mbo] 43: num_iterations=1015; learning_rate=0.0207; num_leaves=521; max_depth=12; min_data_in_leaf=2; min_split_gain=0.0343; feature_fraction=0.602; bagging_fraction=0.914; bagging_freq=4; lambda_l1=0.0028; lambda_l2=1.08 : y = 0.937 : 311.3 secs : infill_ei
#
# Sun Oct 12 01:01:40 2025 AUC 0.937830981676289
#
# [mbo] 44: num_iterations=1352; learning_rate=0.0925; num_leaves=739; max_depth=10; min_data_in_leaf=11; min_split_gain=0.0408; feature_fraction=0.609; bagging_fraction=0.94; bagging_freq=7; lambda_l1=0.0685; lambda_l2=1.31 : y = 0.938 : 268.9 secs : infill_ei
#
# Saved the current state after iteration 45 in the file bayesiana.RDATA.
#
# Sun Oct 12 01:05:24 2025 AUC 0.938198024325384
#
# [mbo] 45: num_iterations=1250; learning_rate=0.0444; num_leaves=417; max_depth=11; min_data_in_leaf=12; min_split_gain=0.125; feature_fraction=0.88; bagging_fraction=0.944; bagging_freq=6; lambda_l1=0.359; lambda_l2=0.168 : y = 0.938 : 221.4 secs : infill_ei
#
# Sun Oct 12 01:15:31 2025 AUC 0.936416415561182
#
# [mbo] 46: num_iterations=1288; learning_rate=0.096; num_leaves=1224; max_depth=18; min_data_in_leaf=1; min_split_gain=0.0702; feature_fraction=0.644; bagging_fraction=0.995; bagging_freq=6; lambda_l1=0.0211; lambda_l2=4.72 : y = 0.936 : 603.0 secs : infill_ei
#
# Saved the current state after iteration 47 in the file bayesiana.RDATA.
#
# Sun Oct 12 01:21:49 2025 AUC 0.938832222200842
#
# [mbo] 47: num_iterations=1212; learning_rate=0.0522; num_leaves=610; max_depth=13; min_data_in_leaf=9; min_split_gain=0.0871; feature_fraction=0.718; bagging_fraction=0.937; bagging_freq=6; lambda_l1=0.0042; lambda_l2=0.846 : y = 0.939 : 374.2 secs : infill_ei
#
# Sun Oct 12 01:28:44 2025 AUC 0.938241870851607
#
# [mbo] 48: num_iterations=1022; learning_rate=0.0246; num_leaves=420; max_depth=16; min_data_in_leaf=2; min_split_gain=0.0712; feature_fraction=0.771; bagging_fraction=0.968; bagging_freq=8; lambda_l1=0.00311; lambda_l2=1.71 : y = 0.938 : 411.9 secs : infill_ei
#
# Saved the current state after iteration 49 in the file bayesiana.RDATA.
#
# Sun Oct 12 01:31:10 2025 AUC 0.930734611064572
#
# [mbo] 49: num_iterations=970; learning_rate=0.00707; num_leaves=718; max_depth=10; min_data_in_leaf=7; min_split_gain=0.0691; feature_fraction=0.154; bagging_fraction=0.81; bagging_freq=6; lambda_l1=0.041; lambda_l2=1.49 : y = 0.931 : 141.4 secs : infill_ei
#
# Sun Oct 12 01:36:24 2025 AUC 0.938489000143857
#
# [mbo] 50: num_iterations=1373; learning_rate=0.0382; num_leaves=991; max_depth=13; min_data_in_leaf=1; min_split_gain=0.105; feature_fraction=0.773; bagging_fraction=0.927; bagging_freq=10; lambda_l1=0.344; lambda_l2=0.983 : y = 0.938 : 311.1 secs : infill_ei
#
# Sun Oct 12 01:39:16 2025 AUC 0.935745089255087
#
# [mbo] 51: num_iterations=1716; learning_rate=0.0844; num_leaves=474; max_depth=-1; min_data_in_leaf=6; min_split_gain=0.115; feature_fraction=0.861; bagging_fraction=0.809; bagging_freq=10; lambda_l1=0.072; lambda_l2=0.00847 : y = 0.936 : 168.6 secs : infill_ei
#
# Saved the current state after iteration 52 in the file bayesiana.RDATA.
#
# Sun Oct 12 01:48:55 2025 AUC 0.937716019839399
#
# [mbo] 52: num_iterations=1381; learning_rate=0.0438; num_leaves=901; max_depth=21; min_data_in_leaf=5; min_split_gain=0.0145; feature_fraction=0.888; bagging_fraction=0.971; bagging_freq=10; lambda_l1=0.0401; lambda_l2=2.86 : y = 0.938 : 574.0 secs : infill_ei
#
# Sun Oct 12 01:53:37 2025 AUC 0.937645892544762
#
# [mbo] 53: num_iterations=1308; learning_rate=0.0528; num_leaves=671; max_depth=14; min_data_in_leaf=1; min_split_gain=0.00691; feature_fraction=0.687; bagging_fraction=0.996; bagging_freq=10; lambda_l1=0.303; lambda_l2=1.58 : y = 0.938 : 279.8 secs : infill_ei
#
# Saved the current state after iteration 54 in the file bayesiana.RDATA.
#
# Sun Oct 12 01:57:32 2025 AUC 0.934281457766817
#
# [mbo] 54: num_iterations=1957; learning_rate=0.197; num_leaves=1081; max_depth=9; min_data_in_leaf=3; min_split_gain=0.0145; feature_fraction=0.969; bagging_fraction=0.835; bagging_freq=9; lambda_l1=0.0166; lambda_l2=0.434 : y = 0.934 : 230.3 secs : infill_ei
#
# Sun Oct 12 02:02:54 2025 AUC 0.937381744922673
#
# [mbo] 55: num_iterations=1419; learning_rate=0.0322; num_leaves=123; max_depth=22; min_data_in_leaf=10; min_split_gain=0.026; feature_fraction=0.92; bagging_fraction=0.942; bagging_freq=7; lambda_l1=0.00343; lambda_l2=4.93 : y = 0.937 : 319.1 secs : infill_ei
#
# Sun Oct 12 02:11:22 2025 AUC 0.938255715919566
#
# [mbo] 56: num_iterations=1424; learning_rate=0.0316; num_leaves=452; max_depth=13; min_data_in_leaf=1; min_split_gain=0.105; feature_fraction=0.936; bagging_fraction=0.846; bagging_freq=9; lambda_l1=0.0495; lambda_l2=0.602 : y = 0.938 : 504.3 secs : infill_ei
#
# Saved the current state after iteration 57 in the file bayesiana.RDATA.
#
# Sun Oct 12 02:17:12 2025 AUC 0.937992127845446
#
# [mbo] 57: num_iterations=1280; learning_rate=0.0637; num_leaves=521; max_depth=13; min_data_in_leaf=3; min_split_gain=0.112; feature_fraction=0.877; bagging_fraction=0.935; bagging_freq=8; lambda_l1=0.0528; lambda_l2=1.08 : y = 0.938 : 345.8 secs : infill_ei
#
# Sun Oct 12 02:22:58 2025 AUC 0.938795001314541
#
# [mbo] 58: num_iterations=854; learning_rate=0.0421; num_leaves=1533; max_depth=17; min_data_in_leaf=7; min_split_gain=0.0362; feature_fraction=0.767; bagging_fraction=0.897; bagging_freq=9; lambda_l1=0.0669; lambda_l2=1.74 : y = 0.939 : 342.9 secs : infill_ei
#
# Saved the current state after iteration 59 in the file bayesiana.RDATA.
#
# Sun Oct 12 02:29:32 2025 AUC 0.937100690056238
#
# [mbo] 59: num_iterations=726; learning_rate=0.0168; num_leaves=564; max_depth=27; min_data_in_leaf=1; min_split_gain=0.005; feature_fraction=0.858; bagging_fraction=0.93; bagging_freq=7; lambda_l1=0.114; lambda_l2=1.09 : y = 0.937 : 388.3 secs : infill_ei
#
# Sun Oct 12 02:33:17 2025 AUC 0.937385384931997
#
# [mbo] 60: num_iterations=1209; learning_rate=0.0957; num_leaves=1037; max_depth=16; min_data_in_leaf=10; min_split_gain=0.0199; feature_fraction=0.739; bagging_fraction=0.854; bagging_freq=9; lambda_l1=0.095; lambda_l2=0.559 : y = 0.937 : 221.7 secs : infill_ei
#
# Saved the current state after iteration 61 in the file bayesiana.RDATA.
#
# Sun Oct 12 02:41:56 2025 AUC 0.936741456542216
#
# [mbo] 61: num_iterations=888; learning_rate=0.0275; num_leaves=774; max_depth=21; min_data_in_leaf=1; min_split_gain=0.0722; feature_fraction=0.865; bagging_fraction=0.875; bagging_freq=10; lambda_l1=0.168; lambda_l2=4.92 : y = 0.937 : 513.8 secs : infill_ei
#
# Sun Oct 12 02:47:49 2025 AUC 0.935854155030066
#
# [mbo] 62: num_iterations=1553; learning_rate=0.0245; num_leaves=1432; max_depth=23; min_data_in_leaf=8; min_split_gain=0.0436; feature_fraction=0.713; bagging_fraction=0.896; bagging_freq=8; lambda_l1=1.01; lambda_l2=1.09 : y = 0.936 : 349.4 secs : infill_ei
#
# Saved the current state after iteration 63 in the file bayesiana.RDATA.
#
# Sun Oct 12 02:53:29 2025 AUC 0.938169139606974
#
# [mbo] 63: num_iterations=1369; learning_rate=0.0422; num_leaves=1094; max_depth=10; min_data_in_leaf=11; min_split_gain=0.25; feature_fraction=0.9; bagging_fraction=0.838; bagging_freq=7; lambda_l1=0.00895; lambda_l2=0.237 : y = 0.938 : 334.9 secs : infill_ei
#
# Sun Oct 12 03:03:06 2025 AUC 0.937761676770573
#
# [mbo] 64: num_iterations=1103; learning_rate=0.0375; num_leaves=712; max_depth=19; min_data_in_leaf=2; min_split_gain=0.0276; feature_fraction=0.803; bagging_fraction=0.934; bagging_freq=6; lambda_l1=0.00509; lambda_l2=2 : y = 0.938 : 574.1 secs : infill_ei
#
# Saved the current state after iteration 65 in the file bayesiana.RDATA.
#
# Sun Oct 12 03:09:12 2025 AUC 0.935715898435971
#
# [mbo] 65: num_iterations=634; learning_rate=0.0666; num_leaves=1219; max_depth=24; min_data_in_leaf=3; min_split_gain=0.0119; feature_fraction=0.892; bagging_fraction=0.991; bagging_freq=10; lambda_l1=0.025; lambda_l2=3.63 : y = 0.936 : 360.7 secs : infill_ei
#
# Sun Oct 12 03:11:46 2025 AUC 0.932936001067406
#
# [mbo] 66: num_iterations=1150; learning_rate=0.0756; num_leaves=1980; max_depth=-1; min_data_in_leaf=13; min_split_gain=0.0104; feature_fraction=0.286; bagging_fraction=0.91; bagging_freq=10; lambda_l1=6.75; lambda_l2=0.0274 : y = 0.933 : 149.6 secs : infill_ei
#
# Sun Oct 12 03:17:19 2025 AUC 0.93566279961505
#
# [mbo] 67: num_iterations=2055; learning_rate=0.0397; num_leaves=154; max_depth=-1; min_data_in_leaf=3; min_split_gain=0.00887; feature_fraction=0.777; bagging_fraction=0.864; bagging_freq=6; lambda_l1=0.214; lambda_l2=0.00703 : y = 0.936 : 329.7 secs : infill_ei
#
# Saved the current state after iteration 68 in the file bayesiana.RDATA.
#
# Sun Oct 12 03:19:29 2025 AUC 0.933808421971895
#
# [mbo] 68: num_iterations=623; learning_rate=0.0079; num_leaves=99; max_depth=29; min_data_in_leaf=5; min_split_gain=0.0228; feature_fraction=0.606; bagging_fraction=0.996; bagging_freq=6; lambda_l1=0.0401; lambda_l2=4.62 : y = 0.934 : 125.9 secs : infill_ei
#
# Sun Oct 12 03:25:05 2025 AUC 0.937191042555577
#
# [mbo] 69: num_iterations=1280; learning_rate=0.0305; num_leaves=181; max_depth=30; min_data_in_leaf=8; min_split_gain=0.24; feature_fraction=0.956; bagging_fraction=0.83; bagging_freq=10; lambda_l1=0.00879; lambda_l2=0.499 : y = 0.937 : 332.2 secs : infill_ei
#
# Sun Oct 12 03:29:22 2025 AUC 0.938841760046929
#
# [mbo] 70: num_iterations=741; learning_rate=0.0201; num_leaves=833; max_depth=16; min_data_in_leaf=12; min_split_gain=0.143; feature_fraction=0.998; bagging_fraction=0.882; bagging_freq=10; lambda_l1=0.0898; lambda_l2=0.257 : y = 0.939 : 253.3 secs : infill_ei
#
# Saved the current state after iteration 71 in the file bayesiana.RDATA.
#
# Sun Oct 12 03:35:13 2025 AUC 0.938205393763903
#
# [mbo] 71: num_iterations=663; learning_rate=0.0512; num_leaves=990; max_depth=21; min_data_in_leaf=2; min_split_gain=0.231; feature_fraction=0.896; bagging_fraction=0.902; bagging_freq=7; lambda_l1=0.0316; lambda_l2=0.872 : y = 0.938 : 345.7 secs : infill_ei
#
# Sun Oct 12 03:42:59 2025 AUC 0.93758982124586
#
# [mbo] 72: num_iterations=844; learning_rate=0.0407; num_leaves=1305; max_depth=19; min_data_in_leaf=2; min_split_gain=0.208; feature_fraction=0.612; bagging_fraction=0.982; bagging_freq=9; lambda_l1=0.017; lambda_l2=1.87 : y = 0.938 : 461.9 secs : infill_ei
#
# Saved the current state after iteration 73 in the file bayesiana.RDATA.
#
# Sun Oct 12 03:50:03 2025 AUC 0.937345317860946
#
# [mbo] 73: num_iterations=1112; learning_rate=0.0463; num_leaves=1283; max_depth=15; min_data_in_leaf=6; min_split_gain=0.0409; feature_fraction=0.728; bagging_fraction=0.932; bagging_freq=10; lambda_l1=0.00981; lambda_l2=2.14 : y = 0.937 : 419.7 secs : infill_ei
#
# Sun Oct 12 04:01:11 2025 AUC 0.937802368013023
#
# [mbo] 74: num_iterations=1158; learning_rate=0.0232; num_leaves=844; max_depth=24; min_data_in_leaf=1; min_split_gain=0.197; feature_fraction=0.926; bagging_fraction=0.889; bagging_freq=10; lambda_l1=0.0589; lambda_l2=1.07 : y = 0.938 : 664.3 secs : infill_ei
#
# Saved the current state after iteration 75 in the file bayesiana.RDATA.
#
# Sun Oct 12 04:03:06 2025 AUC 0.934937095430964
#
# [mbo] 75: num_iterations=901; learning_rate=0.0549; num_leaves=1963; max_depth=13; min_data_in_leaf=9; min_split_gain=0.0634; feature_fraction=0.865; bagging_fraction=0.998; bagging_freq=8; lambda_l1=2.49; lambda_l2=0.547 : y = 0.935 : 109.9 secs : infill_ei
#
# Sun Oct 12 04:08:11 2025 AUC 0.93326007112503
#
# [mbo] 76: num_iterations=2162; learning_rate=0.0187; num_leaves=1180; max_depth=7; min_data_in_leaf=13; min_split_gain=0.232; feature_fraction=0.597; bagging_fraction=0.99; bagging_freq=10; lambda_l1=0.0152; lambda_l2=0.973 : y = 0.933 : 301.0 secs : infill_ei
#
# Sun Oct 12 04:09:20 2025 AUC 0.931188641838357
#
# [mbo] 77: num_iterations=1122; learning_rate=0.228; num_leaves=483; max_depth=-1; min_data_in_leaf=2; min_split_gain=0.000791; feature_fraction=0.912; bagging_fraction=0.944; bagging_freq=6; lambda_l1=0.664; lambda_l2=0.058 : y = 0.931 : 64.5 secs : infill_ei
#
# Sun Oct 12 04:17:44 2025 AUC 0.937695586417424
#
# [mbo] 78: num_iterations=1491; learning_rate=0.0383; num_leaves=1095; max_depth=16; min_data_in_leaf=7; min_split_gain=0.129; feature_fraction=0.818; bagging_fraction=0.86; bagging_freq=9; lambda_l1=0.0052; lambda_l2=0.168 : y = 0.938 : 500.6 secs : infill_ei
#
# Saved the current state after iteration 79 in the file bayesiana.RDATA.
#
# Sun Oct 12 04:21:59 2025 AUC 0.936583595353302
#
# [mbo] 79: num_iterations=1372; learning_rate=0.0474; num_leaves=240; max_depth=13; min_data_in_leaf=91; min_split_gain=0.161; feature_fraction=0.595; bagging_fraction=0.977; bagging_freq=5; lambda_l1=0.00527; lambda_l2=2.79 : y = 0.937 : 250.1 secs : infill_ei
#
# Sun Oct 12 04:25:59 2025 AUC 0.938333490975326
#
# [mbo] 80: num_iterations=613; learning_rate=0.0243; num_leaves=484; max_depth=19; min_data_in_leaf=3; min_split_gain=0.0303; feature_fraction=0.929; bagging_fraction=0.91; bagging_freq=10; lambda_l1=0.288; lambda_l2=1.19 : y = 0.938 : 236.1 secs : infill_ei
#
# Sun Oct 12 04:29:46 2025 AUC 0.93798102771009
#
# [mbo] 81: num_iterations=1015; learning_rate=0.0355; num_leaves=864; max_depth=11; min_data_in_leaf=16; min_split_gain=0.0315; feature_fraction=0.727; bagging_fraction=0.902; bagging_freq=9; lambda_l1=0.0304; lambda_l2=0.516 : y = 0.938 : 223.4 secs : infill_ei
#
# Saved the current state after iteration 82 in the file bayesiana.RDATA.
#
# Sun Oct 12 04:33:41 2025 AUC 0.936032312552873
#
# [mbo] 82: num_iterations=849; learning_rate=0.0981; num_leaves=1556; max_depth=16; min_data_in_leaf=8; min_split_gain=0.226; feature_fraction=0.733; bagging_fraction=0.889; bagging_freq=7; lambda_l1=0.0659; lambda_l2=0.892 : y = 0.936 : 230.0 secs : infill_ei
#
# Sun Oct 12 04:45:35 2025 AUC 0.937952165632542
#
# [mbo] 83: num_iterations=1453; learning_rate=0.0236; num_leaves=690; max_depth=13; min_data_in_leaf=1; min_split_gain=0.00879; feature_fraction=0.989; bagging_fraction=0.915; bagging_freq=8; lambda_l1=0.00425; lambda_l2=0.656 : y = 0.938 : 710.5 secs : infill_ei
#
# Saved the current state after iteration 84 in the file bayesiana.RDATA.
#
# Sun Oct 12 04:51:37 2025 AUC 0.937664406274771
#
# [mbo] 84: num_iterations=920; learning_rate=0.0166; num_leaves=360; max_depth=22; min_data_in_leaf=2; min_split_gain=0.0511; feature_fraction=0.825; bagging_fraction=0.961; bagging_freq=9; lambda_l1=0.266; lambda_l2=1.07 : y = 0.938 : 356.7 secs : infill_ei
#
# Sun Oct 12 04:57:04 2025 AUC 0.938334682227084
#
# [mbo] 85: num_iterations=517; learning_rate=0.0502; num_leaves=1549; max_depth=17; min_data_in_leaf=1; min_split_gain=0.028; feature_fraction=0.676; bagging_fraction=0.99; bagging_freq=9; lambda_l1=0.0108; lambda_l2=0.607 : y = 0.938 : 323.6 secs : infill_ei
#
# Saved the current state after iteration 86 in the file bayesiana.RDATA.
#
# Sun Oct 12 05:05:37 2025 AUC 0.935931140258231
#
# [mbo] 86: num_iterations=2321; learning_rate=0.0921; num_leaves=228; max_depth=17; min_data_in_leaf=1; min_split_gain=0.00202; feature_fraction=0.917; bagging_fraction=0.856; bagging_freq=6; lambda_l1=0.103; lambda_l2=4.94 : y = 0.936 : 507.3 secs : infill_ei
#
# Sun Oct 12 05:09:34 2025 AUC 0.936814840497519
#
# [mbo] 87: num_iterations=502; learning_rate=0.0244; num_leaves=1533; max_depth=18; min_data_in_leaf=2; min_split_gain=0.0541; feature_fraction=0.942; bagging_fraction=0.865; bagging_freq=10; lambda_l1=0.321; lambda_l2=1.27 : y = 0.937 : 233.2 secs : infill_ei
#
# Saved the current state after iteration 88 in the file bayesiana.RDATA.
#
# Sun Oct 12 05:17:31 2025 AUC 0.936106584766895
#
# [mbo] 88: num_iterations=1427; learning_rate=0.104; num_leaves=593; max_depth=28; min_data_in_leaf=1; min_split_gain=0.106; feature_fraction=0.79; bagging_fraction=0.889; bagging_freq=8; lambda_l1=0.0633; lambda_l2=4.99 : y = 0.936 : 471.1 secs : infill_ei
#
# Sun Oct 12 05:22:01 2025 AUC 0.936351308545571
#
# [mbo] 89: num_iterations=724; learning_rate=0.0497; num_leaves=360; max_depth=18; min_data_in_leaf=1; min_split_gain=0.00889; feature_fraction=0.769; bagging_fraction=0.972; bagging_freq=6; lambda_l1=0.0668; lambda_l2=1.27 : y = 0.936 : 266.5 secs : infill_ei
#
# Saved the current state after iteration 90 in the file bayesiana.RDATA.
#
# Sun Oct 12 05:25:13 2025 AUC 0.935336510361741
#
# [mbo] 90: num_iterations=1264; learning_rate=0.0146; num_leaves=54; max_depth=26; min_data_in_leaf=5; min_split_gain=0.0315; feature_fraction=0.904; bagging_fraction=0.864; bagging_freq=10; lambda_l1=0.0453; lambda_l2=3.19 : y = 0.935 : 186.2 secs : infill_ei
#
# Sun Oct 12 05:34:19 2025 AUC 0.936507973967689
#
# [mbo] 91: num_iterations=2340; learning_rate=0.0198; num_leaves=240; max_depth=29; min_data_in_leaf=2; min_split_gain=0.234; feature_fraction=0.987; bagging_fraction=0.845; bagging_freq=7; lambda_l1=1.03; lambda_l2=4.21 : y = 0.937 : 541.1 secs : infill_ei
#
# Saved the current state after iteration 92 in the file bayesiana.RDATA.
#
# Sun Oct 12 05:41:55 2025 AUC 0.937467356021429
#
# [mbo] 92: num_iterations=1201; learning_rate=0.0576; num_leaves=1873; max_depth=19; min_data_in_leaf=5; min_split_gain=0.0349; feature_fraction=0.491; bagging_fraction=0.991; bagging_freq=9; lambda_l1=0.033; lambda_l2=2.99 : y = 0.937 : 451.0 secs : infill_ei
#
# Sun Oct 12 05:43:14 2025 AUC 0.931110067210574
#
# [mbo] 93: num_iterations=1870; learning_rate=0.0447; num_leaves=740; max_depth=2; min_data_in_leaf=3; min_split_gain=0.298; feature_fraction=0.997; bagging_fraction=0.834; bagging_freq=10; lambda_l1=3.43; lambda_l2=0.0385 : y = 0.931 : 74.4 secs : infill_ei
#
# Sun Oct 12 05:50:14 2025 AUC 0.937776876581979
#
# [mbo] 94: num_iterations=1010; learning_rate=0.0297; num_leaves=933; max_depth=15; min_data_in_leaf=5; min_split_gain=0.0901; feature_fraction=0.885; bagging_fraction=0.917; bagging_freq=7; lambda_l1=0.02; lambda_l2=1.43 : y = 0.938 : 416.7 secs : infill_ei
#
# Saved the current state after iteration 95 in the file bayesiana.RDATA.
#
# Sun Oct 12 05:56:34 2025 AUC 0.937347173905986
#
# [mbo] 95: num_iterations=728; learning_rate=0.017; num_leaves=811; max_depth=19; min_data_in_leaf=4; min_split_gain=0.162; feature_fraction=0.803; bagging_fraction=0.933; bagging_freq=9; lambda_l1=0.0305; lambda_l2=0.768 : y = 0.937 : 374.3 secs : infill_ei
#
# Sun Oct 12 06:02:24 2025 AUC 0.937033465622564
#
# [mbo] 96: num_iterations=1570; learning_rate=0.0459; num_leaves=900; max_depth=29; min_data_in_leaf=7; min_split_gain=0.146; feature_fraction=0.886; bagging_fraction=0.847; bagging_freq=7; lambda_l1=0.234; lambda_l2=0.861 : y = 0.937 : 345.5 secs : infill_ei
#
# Saved the current state after iteration 97 in the file bayesiana.RDATA.
#
# Sun Oct 12 06:09:58 2025 AUC 0.936997398397357
#
# [mbo] 97: num_iterations=988; learning_rate=0.0465; num_leaves=480; max_depth=28; min_data_in_leaf=1; min_split_gain=0.278; feature_fraction=0.968; bagging_fraction=0.823; bagging_freq=7; lambda_l1=0.0138; lambda_l2=1.2 : y = 0.937 : 449.2 secs : infill_ei
#
# Sun Oct 12 06:15:27 2025 AUC 0.934605968805656
#
# [mbo] 98: num_iterations=2253; learning_rate=0.157; num_leaves=968; max_depth=13; min_data_in_leaf=1; min_split_gain=0.00265; feature_fraction=0.355; bagging_fraction=0.979; bagging_freq=5; lambda_l1=0.168; lambda_l2=2.98 : y = 0.935 : 323.9 secs : infill_ei
#
# Saved the current state after iteration 99 in the file bayesiana.RDATA.
#
# Sun Oct 12 06:25:50 2025 AUC 0.936474424264051
#
# [mbo] 99: num_iterations=1353; learning_rate=0.0717; num_leaves=727; max_depth=23; min_data_in_leaf=3; min_split_gain=0.0176; feature_fraction=0.749; bagging_fraction=0.917; bagging_freq=5; lambda_l1=0.00355; lambda_l2=1.71 : y = 0.936 : 617.7 secs : infill_ei
#
# Saved the current state after iteration 100 in the file bayesiana.RDATA.
#
# Sun Oct 12 06:31:06 2025 AUC 0.937367980134357
#
# [mbo] 100: num_iterations=1923; learning_rate=0.0572; num_leaves=889; max_depth=11; min_data_in_leaf=1; min_split_gain=0.0334; feature_fraction=0.907; bagging_fraction=0.897; bagging_freq=6; lambda_l1=0.318; lambda_l2=1.01 : y = 0.937 : 311.6 secs : infill_ei
#
# Saved the final state in the file bayesiana.RDATA

# %%
tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)
colnames( tb_bayesiana)
# Out:
#  [1] "num_iterations"   "learning_rate"    "num_leaves"       "max_depth"
#  [5] "min_data_in_leaf" "min_split_gain"   "feature_fraction" "bagging_fraction"
#  [9] "bagging_freq"     "lambda_l1"        "lambda_l2"        "y"
# [13] "dob"              "eol"              "error.message"    "exec.time"
# [17] "ei"               "error.model"      "train.time"       "prop.type"
# [21] "propose.time"     "se"               "mean"

# %%
# almaceno los resultados de la Bayesian Optimization
# y capturo los mejores hiperparametros encontrados

tb_bayesiana <- as.data.table(bayesiana_salida$opt.path)

tb_bayesiana[, iter := .I]

# ordeno en forma descendente por AUC = y
setorder(tb_bayesiana, -y)

# grabo para eventualmente poder utilizarlos en OTRA corrida
fwrite( tb_bayesiana,
  file= "BO_log.txt",
  sep= "\t"
)

# los mejores hiperparámetros son los que quedaron en el registro 1 de la tabla
PARAM$out$lgbm$mejores_hiperparametros <- tb_bayesiana[
  1, # el primero es el de mejor AUC
  setdiff(colnames(tb_bayesiana),
    c("y","dob","eol","error.message","exec.time","ei","error.model",
      "train.time","prop.type","propose.time","se","mean","iter")),
  with= FALSE
]


PARAM$out$lgbm$y <- tb_bayesiana[1, y]

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
print(PARAM$out$lgbm$mejores_hiperparametros)
print(PARAM$out$lgbm$y)
# Out:
#    num_iterations learning_rate num_leaves max_depth min_data_in_leaf
#             <int>         <num>      <int>     <int>            <int>
# 1:            741    0.02012014        833        16               12
#    min_split_gain feature_fraction bagging_fraction bagging_freq  lambda_l1
#             <num>            <num>            <num>        <int>      <num>
# 1:      0.1432114        0.9975067        0.8820523           10 0.08981756
#    lambda_l2
#        <num>
# 1:   0.25669
# [1] 0.9388418

# %% [markdown]
# ### 2.2.7 Testing

# %%
# defino 10 semillas
semillas <- c(102191, 202111, 303131, 404243, 505357,
              606469, 707579, 808681, 909793, 1010101)

predicciones_lista <- list()

for(semilla in semillas) {

  cat("\nEntrenando con semilla:", semilla, "\n")

  # Modificar los parámetros para incluir la semilla actual
  param_test <- modifyList(PARAM$lgbm$param_fijos,
                           PARAM$out$lgbm$mejores_hiperparametros)
  param_test$seed <- semilla

  # Entrenar el modelo con la semilla actual
  modelo_test <- lgb.train(
    data = dtrain,
    param = param_test
  )

  # Preparar el dataset de predicción
  dataset_test <- dataset[foto_mes == 202104]

  # Predecir sobre el dataset de test
  prediccion_actual <- predict(
    modelo_test,
    data.matrix(dataset_test[, campos_buenos, with = FALSE])
  )

  # Guardar la predicción en la lista
  predicciones_lista[[as.character(semilla)]] <- prediccion_actual
}


# calculamos el promedio por fila (cliente)
predicciones_promedio <- rowMeans(as.data.table(predicciones_lista))

tb_test <- dataset_test[, .(numero_de_cliente, foto_mes)]
tb_test[, prob := predicciones_promedio] # <-- Usamos el promedio

# Inicializar realidad para test
drealidad_test <- realidad_inicializar(dataset_test, PARAM)

# Calcular ganancias usando realidad_evaluar
resultados_cortes <- data.table()
setorder(tb_test, -prob)

for(envios in PARAM$cortes) {

  tb_test[, Predicted := 0L]
  tb_test[1:envios, Predicted := 1L]

  res <- realidad_evaluar(drealidad_test, tb_test)

  resultados_cortes <- rbind(resultados_cortes,
                             data.table(
                               envios = envios,
                               ganancia_total = res$total,
                               ganancia_public = res$public,
                               ganancia_private = res$private,
                               ganancia_por_envio = res$total / envios
                             ))

  options(scipen = 999)
  cat("Envios=", envios, "\t",
      " TOTAL=", res$total,
      "  Public=", res$public,
      " Private=", res$private,
      "\n",
      sep = "")
}

cat("\nProceso finalizado. Las ganancias mostradas corresponden al promedio de 10 semillas.\n")
# Out:
# Entrenando con semilla: 102191
#
# Entrenando con semilla: 202111
#
# Entrenando con semilla: 303131
#
# Entrenando con semilla: 404243
#
# Entrenando con semilla: 505357
#
# Entrenando con semilla: 606469
#
# Entrenando con semilla: 707579
#
# Entrenando con semilla: 808681
#
# Entrenando con semilla: 909793
#
# Entrenando con semilla: 1010101
# Envios=6000	 TOTAL=333600000  Public=308866667 Private=344200000
# Envios=6500	 TOTAL=342800000  Public=306600000 Private=358314286
# Envios=7000	 TOTAL=361600000  Public=307600000 Private=384742857
# Envios=7500	 TOTAL=366800000  Public=311400000 Private=390542857
# Envios=8000	 TOTAL=372800000  Public=317266667 Private=396600000
# Envios=8500	 TOTAL=376400000  Public=310000000 Private=404857143
# Envios=9000	 TOTAL=380000000  Public=308866667 Private=410485714
# Envios=9500	 TOTAL=378800000  Public=312333333 Private=407285714
# Envios=10000	 TOTAL=375200000  Public=310066667 Private=403114286
# Envios=10500	 TOTAL=376400000  Public=313000000 Private=403571429
# Envios=11000	 TOTAL=369600000  Public=308466667 Private=395800000
# Envios=11500	 TOTAL=369200000  Public=315200000 Private=392342857
# Envios=12000	 TOTAL=365600000  Public=310933333 Private=389028571
# Envios=12500	 TOTAL=362800000  Public=310333333 Private=385285714
# Envios=13000	 TOTAL=361600000  Public=318200000 Private=380200000
# Envios=13500	 TOTAL=361200000  Public=319266667 Private=379171429
# Envios=14000	 TOTAL=356000000  Public=313533333 Private=374200000
# Envios=14500	 TOTAL=350000000  Public=311800000 Private=366371429
# Envios=15000	 TOTAL=347200000  Public=314266667 Private=361314286
# Envios=15500	 TOTAL=342000000  Public=307200000 Private=356914286
# Envios=16000	 TOTAL=338400000  Public=297933333 Private=355742857
# Envios=16500	 TOTAL=337200000  Public=297866667 Private=354057143
# Envios=17000	 TOTAL=330400000  Public=289266667 Private=348028571
# Envios=17500	 TOTAL=326800000  Public=285333333 Private=344571429
# Envios=18000	 TOTAL=322400000  Public=286333333 Private=337857143
# Envios=18500	 TOTAL=318000000  Public=282066667 Private=333400000
# Envios=19000	 TOTAL=309600000  Public=276000000 Private=324000000
#
# Proceso finalizado. Las ganancias mostradas corresponden al promedio de 10 semillas.

# %%
# Encontrar el óptimo
setorder(resultados_cortes, -ganancia_total)
optimo <- resultados_cortes[1]

cat("\n================================================\n")
cat("MEJOR PUNTO DE CORTE EN TEST (202104):\n")
cat("Envíos óptimos:", optimo$envios, "\n")
cat("Ganancia TOTAL:", optimo$ganancia_total, "\n")
cat("Ganancia PUBLIC:", optimo$ganancia_public, "\n")
cat("Ganancia PRIVATE:", optimo$ganancia_private, "\n")
cat("Ganancia por envío:", round(optimo$ganancia_por_envio, 2), "\n")
cat("================================================\n\n")
# Out:
# ================================================
# MEJOR PUNTO DE CORTE EN TEST (202104):
# Envíos óptimos: 9000
# Ganancia TOTAL: 380000000
# Ganancia PUBLIC: 308866667
# Ganancia PRIVATE: 410485714
# Ganancia por envío: 42222.22
# ================================================

# %% [markdown]
# ## 2.3  Produccion

# %% [markdown]
# ### Final Training
# Construyo el modelo final, que es uno solo, no hace ningun tipo de particion < training, validation, testing>]

# %%
setwd("/content/buckets/b1/exp")
experimento <- paste0("exp", PARAM$experimento)
dir.create(experimento, showWarnings= FALSE)
setwd( paste0("/content/buckets/b1/exp/", experimento ))

# %% [markdown]
# #### Final Training Dataset
#
# Aqui esta la gran decision de en qué meses hago el Final Training
# <br> debo utilizar los mejores hiperparámetros que encontré en la  optimización bayesiana

# %%
# clase01
dataset[, clase01 := ifelse(clase_ternaria %in% c("BAJA+1", "BAJA+2"), 1L, 0L)]

# %%
dataset_train <- dataset[foto_mes %in% PARAM$train_final]
dataset_train[,.N,clase_ternaria]
# Out:
#   clase_ternaria N
# 1 BAJA+1           3447
# 2 BAJA+2           3938
# 3 CONTINUA       642824

# %%
# dejo los datos en el formato que necesita LightGBM

dtrain_final <- lgb.Dataset(
  data= data.matrix(dataset_train[, campos_buenos, with= FALSE]),
  label= dataset_train[, clase01]
)

# %% [markdown]
# #### Final Training Hyperparameters

# %%
param_final <- modifyList(PARAM$lgbm$param_fijos,
  PARAM$out$lgbm$mejores_hiperparametros)

param_final
# Out:
# $boosting
# [1] "gbdt"
#
# $objective
# [1] "binary"
#
# $metric
# [1] "auc"
#
# $first_metric_only
# [1] FALSE
#
# $boost_from_average
# [1] TRUE
#
# $feature_pre_filter
# [1] FALSE
#
# $force_row_wise
# [1] TRUE
#
# $verbosity
# [1] -100
#
# $seed
# [1] 170029
#
# $max_depth
# [1] 16
#
# $min_gain_to_split
# [1] 0
#
# $min_sum_hessian_in_leaf
# [1] 0.001
#
# $lambda_l1
# [1] 0.08981756
#
# $lambda_l2
# [1] 0.25669
#
# $max_bin
# [1] 31
#
# $bagging_fraction
# [1] 0.8820523
#
# $pos_bagging_fraction
# [1] 1
#
# $neg_bagging_fraction
# [1] 1
#
# $is_unbalance
# [1] FALSE
#
# $scale_pos_weight
# [1] 1
#
# $drop_rate
# [1] 0.1
#
# $max_drop
# [1] 50
#
# $skip_drop
# [1] 0.5
#
# $extra_trees
# [1] FALSE
#
# $num_iterations
# [1] 741
#
# $learning_rate
# [1] 0.02012014
#
# $feature_fraction
# [1] 0.9975067
#
# $num_leaves
# [1] 833
#
# $min_data_in_leaf
# [1] 12
#
# $min_split_gain
# [1] 0.1432114
#
# $bagging_freq
# [1] 10

# %% [markdown]
# #### Training
# Genero el modelo final, siempre sobre TODOS los datos de  final_train, sin hacer ningun tipo de undersampling de la clase mayoritaria y mucho menos cross validation.

# %%
# este punto es muy SUTIL  y será revisado en la Clase 05

param_normalizado <- copy(param_final)
param_normalizado$min_data_in_leaf <-  round(param_final$min_data_in_leaf / PARAM$trainingstrategy$undersampling)

# %%
# entreno los lightgbm
# Definir las 10 semillas a utilizar

semillas <- c(102191, 202111, 303131, 404243, 505357,
              606469, 707579, 808681, 909793, 1010101)

# Lista para guardar modelos
modelos_finales <- list()

# Entrenar un modelo por cada semilla
for(i in seq_along(semillas)) {

  semilla <- semillas[i]
  cat(sprintf("[%d/%d] Entrenando modelo con semilla: %d\n",
              i, length(semillas), semilla))

  # Modificar parámetros con la semilla actual
  param_actual <- param_normalizado
  param_actual$seed <- semilla

  # Entrenar el modelo
  modelo <- lgb.train(
    data = dtrain_final,
    param = param_actual
  )

  # Guardar en la lista
  modelos_finales[[as.character(semilla)]] <- modelo
}

cat("\n✓ Entrenamiento completado: 10 modelos entrenados\n")
# Out:
# [1/10] Entrenando modelo con semilla: 102191
# [2/10] Entrenando modelo con semilla: 202111
# [3/10] Entrenando modelo con semilla: 303131
# [4/10] Entrenando modelo con semilla: 404243
# [5/10] Entrenando modelo con semilla: 505357
# [6/10] Entrenando modelo con semilla: 606469
# [7/10] Entrenando modelo con semilla: 707579
# [8/10] Entrenando modelo con semilla: 808681
# [9/10] Entrenando modelo con semilla: 909793
# [10/10] Entrenando modelo con semilla: 1010101
#
# ✓ Entrenamiento completado: 10 modelos entrenados

# %%
# ahora imprimo la importancia de variables
tb_importancia <- as.data.table(lgb.importance(modelos_finales[[1]]))
archivo_importancia <- "impo.txt"

fwrite(tb_importancia,
  file= archivo_importancia,
  sep= "\t"
)

# %%
# grabo a disco el modelo en un formato para seres humanos ... ponele ...
lgb.save(modelos_finales[[1]], "modelo.txt" )

# %% [markdown]
# ### Scoring

# %% [markdown]
# Aplico el modelo final a los datos del futuro

# %%
# aplico el modelo a los datos sin clase
dfuture <- dataset[foto_mes %in% PARAM$future]

# Matriz de datos para predicción
datos_future <- data.matrix(dfuture[, campos_buenos, with = FALSE])

# Lista para guardar predicciones
predicciones_lista <- list()

# Predecir con cada modelo
for(i in seq_along(semillas)) {
  semilla <- semillas[i]

  prediccion <- predict(
    modelos_finales[[as.character(semilla)]],
    datos_future
  )

  predicciones_lista[[as.character(semilla)]] <- prediccion
}

# PROMEDIO DE LAS 10 PREDICCIONES
prediccion <- rowMeans(as.data.table(predicciones_lista))

# %%
# inicilizo el dataset  drealidad
drealidad <- realidad_inicializar( dfuture, PARAM)

# %% [markdown]
# #### Tabla Prediccion

# %%
# tabla de prediccion

tb_prediccion <- dfuture[, list(numero_de_cliente, foto_mes)]
tb_prediccion[, prob := prediccion ]

# grabo las probabilidad del modelo
fwrite(tb_prediccion,
  file= "prediccion.txt",
  sep= "\t"
)

# %% [markdown]
# Kaggle Competition Submit

# %%
PARAM$cortes
# Out:
#  [1]  6000  6500  7000  7500  8000  8500  9000  9500 10000 10500 11000 11500
# [13] 12000 12500 13000 13500 14000 14500 15000 15500 16000 16500 17000 17500
# [25] 18000 18500 19000

# %%
# genero archivos con los  "envios" mejores
# suba TODOS los archivos a Kaggle

# ordeno por probabilidad descendente
setorder(tb_prediccion, -prob)

dir.create("kaggle")

for (envios in PARAM$cortes) {

  tb_prediccion[, Predicted := 0L] # seteo inicial a 0
  tb_prediccion[1:envios, Predicted := 1L] # marco los primeros

  archivo_kaggle <- paste0("./kaggle/KA", PARAM$experimento, "_", envios, ".csv")

  # grabo el archivo
  fwrite(tb_prediccion[, list(numero_de_cliente, Predicted)],
    file= archivo_kaggle,
    sep= ","
  )

  res <- realidad_evaluar( drealidad, tb_prediccion)

  options(scipen = 999)
  cat( "Envios=", envios, "\t",
    " TOTAL=", res$total,
    "  Public=", res$public,
    " Private=", res$private,
    "\n",
    sep= ""
  )

}
# Out:
# Envios=6000	 TOTAL=-120000000  Public=-122866667 Private=-118771429
# Envios=6500	 TOTAL=-130000000  Public=-132066667 Private=-129114286
# Envios=7000	 TOTAL=-140000000  Public=-142066667 Private=-139114286
# Envios=7500	 TOTAL=-150000000  Public=-153400000 Private=-148542857
# Envios=8000	 TOTAL=-160000000  Public=-163200000 Private=-158628571
# Envios=8500	 TOTAL=-170000000  Public=-172666667 Private=-168857143
# Envios=9000	 TOTAL=-180000000  Public=-182933333 Private=-178742857
# Envios=9500	 TOTAL=-190000000  Public=-193000000 Private=-188714286
# Envios=10000	 TOTAL=-200000000  Public=-204066667 Private=-198257143
# Envios=10500	 TOTAL=-210000000  Public=-213466667 Private=-208514286
# Envios=11000	 TOTAL=-220000000  Public=-223200000 Private=-218628571
# Envios=11500	 TOTAL=-230000000  Public=-232866667 Private=-228771429
# Envios=12000	 TOTAL=-240000000  Public=-242800000 Private=-238800000
# Envios=12500	 TOTAL=-250000000  Public=-252666667 Private=-248857143
# Envios=13000	 TOTAL=-260000000  Public=-261666667 Private=-259285714
# Envios=13500	 TOTAL=-270000000  Public=-271200000 Private=-269485714
# Envios=14000	 TOTAL=-280000000  Public=-281800000 Private=-279228571
# Envios=14500	 TOTAL=-290000000  Public=-291600000 Private=-289314286
# Envios=15000	 TOTAL=-300000000  Public=-301933333 Private=-299171429
# Envios=15500	 TOTAL=-310000000  Public=-312000000 Private=-309142857
# Envios=16000	 TOTAL=-320000000  Public=-321133333 Private=-319514286
# Envios=16500	 TOTAL=-330000000  Public=-330200000 Private=-329914286
# Envios=17000	 TOTAL=-340000000  Public=-341066667 Private=-339542857
# Envios=17500	 TOTAL=-350000000  Public=-350666667 Private=-349714286
# Envios=18000	 TOTAL=-360000000  Public=-360600000 Private=-359742857
# Envios=18500	 TOTAL=-370000000  Public=-370600000 Private=-369742857
# Envios=19000	 TOTAL=-380000000  Public=-381333333 Private=-379428571

# %%
write_yaml( PARAM, file="PARAM.yml")

# %%
format(Sys.time(), "%a %b %d %X %Y")
# Out:
# [1] "Sun Oct 12 07:54:16 2025"

# %% [markdown]
# Finalmente usted deberá cargar el resultado de su corrida en la Google Sheet Colaborativa,  hoja **TareaHogar04**
# <br> Siéntase libre de agregar las columnas que hagan falta a la planilla
